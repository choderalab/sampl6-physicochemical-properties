# %% [markdown]
# # ChemSpider
#
# Experimental logP records of compounds in fragment-like set was checked by manually querying Chemspider website. Experimental logP values (if exists), were under `Properties/Experimental Physico-chemical Properties/Experimental LogP`. I recorded these values under Chemspider columb in `df_frag_final_chemspider_logP.csv`.

# %%
import pandas as pd
import pickle

# %%
df_chemspider = pd.read_csv("df_frag_final_chemspider_logP.csv")
df_chemspider
# Out:
#     Unnamed: 0  eMolecules ID                     canonical isomeric SMILES  \
# 0            0         490595                 COc1ccc2c(cc(=O)oc2c1)CC(=O)O
# 1            1         532754             c1cc(ccc1c2coc3cc(cc(c3c2=O)O)O)O
# 2            2        4934119          COC(=O)c1ccc(cc1)Nc2c3c([nH]cn3)ncn2
# 3            3        2867544                       c1nc(c2c3c(sc2n1)CCC3)N
# 4            4        2727697               Cc1ccc(cc1Nc2nccc(n2)c3cccnc3)N
# 5            5         719540                  c1ccc(cc1)n2c3c(cn2)c(ncn3)N
# 6            6         493608            c1ccc(cc1)c2cc(=O)c3c(cc(cc3o2)O)O
# 7            7         508324                      COc1cc(c(cc1OC)Br)C(=O)O
# 8            8       37095168                    c1ccc2c(c1)ncn2c3ccc(cc3)O
# 9            9       37053191            c1ccc(cc1)c2[nH]c3ccc(cc3n2)C(=O)N
# 10          10       31653344                    c1ccc(cc1)n2cnc3c2ccc(c3)N
# 11          11        2042282                c1cc(c(c(c1)F)C(=O)Nc2ccncc2)F
# 12          12       13419113              c1ccc(cc1)NC(=O)c2c3ccccc3[nH]n2
# 13          13        5828805            Cc1cccc(c1)Nc2c3cc(c(cc3ncn2)OC)OC
# 14          14       23354217          c1ccc(cc1)C(=O)NCC(=O)Nc2nc3ccccc3s2
# 15          15        1698122         c1cc(ccc1Nc2c(cnc(n2)Nc3ccc(cc3)F)F)F
# 16          16       18893169            c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# 17          17        1865544                COc1cccc(c1)Nc2c3ccccc3ncn2.Cl
# 18          18        1444229                 c1ccc(cc1)CSc2nnc(o2)c3ccncc3
# 19          19        1228629             c1ccc(cc1)Cc2nnc(s2)NC(=O)c3cccs3
# 20          20       18908671         c1ccc(c(c1)NC(=O)c2ccc(o2)Cl)N3CCCCC3
# 21          21       25775231  c1cc(c(cc1c2ccc(o2)/C=C/3\C(=O)NC(=O)S3)Cl)F
# 22          22        5784088       c1cc(ccc1c2nnc3n2nc(cc3)NC4CC4)C(F)(F)F
# 23          23       45809595           CC(C)c1ccc(cc1)/C=C\2/c3ccccc3NC2=O
# 24          24         703997     CCOC(=O)c1c(c2cc(ccc2[nH]c1=O)Cl)c3ccccc3
#
#                                eMolecules SMILES         pKas in [3,11]  \
# 0                  COc1ccc2c(c1)oc(=O)cc2CC(=O)O                [3.621]
# 1            Oc1ccc(cc1)c1coc2c(c1=O)c(O)cc(c2)O  [8.584, 9.84, 10.869]
# 2             COC(=O)c1ccc(cc1)Nc1ncnc2c1nc[nH]2         [3.923, 9.999]
# 3                            Nc1ncnc2c1c1CCCc1s2                [4.048]
# 4              Nc1ccc(c(c1)Nc1nccc(n1)c1cccnc1)C          [3.887, 4.98]
# 5                         Nc1ncnc2c1cnn2c1ccccc1                [3.869]
# 6               Oc1cc(O)c2c(c1)oc(cc2=O)c1ccccc1        [8.416, 10.823]
# 7                       COc1cc(C(=O)O)c(cc1OC)Br                [3.005]
# 8                       Oc1ccc(cc1)n1cnc2c1cccc2          [5.82, 8.709]
# 9             NC(=O)c1ccc2c(c1)nc([nH]2)c1ccccc1                [6.342]
# 10                      Nc1ccc2c(c1)ncn2c1ccccc1                [6.348]
# 11                    O=C(c1c(F)cccc1F)Nc1ccncc1        [4.714, 10.538]
# 12                O=C(c1n[nH]c2c1cccc2)Nc1ccccc1                [8.398]
# 13              COc1cc2c(ncnc2cc1OC)Nc1cccc(c1)C                [4.267]
# 14          O=C(Nc1nc2c(s1)cccc2)CNC(=O)c1ccccc1                [8.672]
# 15         Fc1ccc(cc1)Nc1ncc(c(n1)Nc1ccc(cc1)F)F                [3.892]
# 16              Brc1cncc(c1)C(=O)Nc1cccc2c1nccc2        [4.001, 10.328]
# 17                COc1cccc(c1)Nc1ncnc2c1cccc2.Cl                 [4.05]
# 18                 c1ccc(cc1)CSc1nnc(o1)c1ccncc1                [4.902]
# 19               O=C(c1cccs1)Nc1nnc(s1)Cc1ccccc1                 [7.12]
# 20             Clc1ccc(o1)C(=O)Nc1ccccc1N1CCCCC1                [5.346]
# 21  O=C1S/C(=C/c2ccc(o2)c2ccc(c(c2)Cl)F)/C(=O)N1                [8.052]
# 22       FC(c1ccc(cc1)c1nnc2n1nc(cc2)NC1CC1)(F)F                [4.394]
# 23         O=C1Nc2c(/C/1=C/c1ccc(cc1)C(C)C)cccc2                [3.158]
# 24   CCOC(=O)c1c(=O)[nH]c2c(c1c1ccccc1)cc(cc2)Cl                [8.549]
#
#     XlogP    MolWt  Availability (mg)  Price          group  N_Rot  \
# 0   0.669  234.205             3439.8    223  fragment-like      3
# 1   0.887  270.237             1015.0    168  fragment-like      1
# 2   0.850  269.259              108.0    275  fragment-like      4
# 3   1.043  191.253             1026.0    168  fragment-like      0
# 4   1.297  277.324              101.1    400  fragment-like      3
# 5   1.499  211.223             3430.0    414  fragment-like      1
# 6   1.713  254.238             1056.0    168  fragment-like      1
# 7   1.700  261.069            10134.0    168  fragment-like      3
# 8   2.219  210.231            21650.2    148  fragment-like      1
# 9   2.192  237.257             2000.0    168  fragment-like      2
# 10  2.333  209.247            50213.0    148  fragment-like      1
# 11  2.305  234.202              100.0    168  fragment-like      3
# 12  2.643  237.257              762.8    223  fragment-like      3
# 13  2.595  295.336             1864.0    414  fragment-like      4
# 14  2.718  311.358              149.1    148  fragment-like      6
# 15  2.814  316.281              105.0    168  fragment-like      4
# 16  2.923  328.163              406.0    148  fragment-like      3
# 17  3.139  287.744              119.7    148  fragment-like      3
# 18  3.306  269.322              170.0    168  fragment-like      4
# 19  3.605  301.387              379.0    148  fragment-like      5
# 20  3.795  304.771              424.3    148  fragment-like      4
# 21  3.908  323.727              125.0    168  fragment-like      2
# 22  4.129  319.284             3175.0    414  fragment-like      4
# 23  4.233  263.334              283.7    400  fragment-like      2
# 24  4.517  327.762             1059.0    168  fragment-like      4
#
#     N_UV_chrom Selection  Bin index  Priority Final list  \
# 0           29    picked          3         1       True
# 1           56    picked          4         1       True
# 2           20    picked          4         2       True
# 3           10    picked          5         1       True
# 4           36    picked          7         1       True
# 5           31    picked          8         1       True
# 6           54    picked          9         1       True
# 7           12    picked          9         2       True
# 8           40    picked         11         1       True
# 9           42    picked         11         2       True
# 10          40    picked         12         1       True
# 11          20    picked         12         2       True
# 12          36    picked         13         1       True
# 13          36    picked         13         2       True
# 14          28    picked         14         1       True
# 15          28    picked         14         2       True
# 16          37    picked         15         1       True
# 17          36    picked         16         1       True
# 18          30    picked         17         1       True
# 19          14    picked         18         1       True
# 20          18    picked         19         1       True
# 21          31    picked         20         1       True
# 22          32    picked         21         1       True
# 23          24    picked         22         1       True
# 24          59    picked         23         1       True
#
#                          Chemspider
# 0   1.679 Life Chemicals F1083-0011
# 1           2.958 Vitas-M STK801619
# 2           2.291 Vitas-M STK944571
# 3           2.367 Vitas-M STK894648
# 4   1.628 Life Chemicals F9995-0188
# 5                              None
# 6           2.879 Vitas-M STK801609
# 7           2.626 Vitas-M STK505709
# 8                              None
# 9                              None
# 10                             None
# 11          1.406 Vitas-M STK462431
# 12                             None
# 13                             None
# 14                             None
# 15          4.293 Vitas-M STK699264
# 16                             None
# 17                             None
# 18                             None
# 19                             None
# 20                             None
# 21                             None
# 22                             None
# 23                             None
# 24          5.582 Vitas-M STL054189

# %%
df_chemspider_exp_logP = df_chemspider.loc[df_chemspider["Chemspider"] != "None"]
print("{} chemicals have experimental logP reprted in ChemSpider.".format(df_chemspider_exp_logP.shape[0]))
# Out:
# 10 chemicals have experimental logP reprted in ChemSpider.

# %% [markdown]
# I will save lists of chemicals selected for fragment-like set that have reported experimental logP in ChemSpider in lists (pickle files) for each round.

# %%
frags_with_exp_logP = list(df_chemspider_exp_logP.loc[:,"eMolecules ID"])
pickle.dump(fragments_with_exp_logP, open("fragments_with_exp_logP.pickle", "wb"))

# %%
list = pickle.load(open("fragments_with_exp_logP.pickle", "rb"))
list
# Out:
# [490595,
#  532754,
#  4934119,
#  2867544,
#  2727697,
#  493608,
#  508324,
#  2042282,
#  1698122,
#  703997]
