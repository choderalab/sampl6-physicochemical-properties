# %% [markdown]
# # Calculating Uncertainties in Experimental pKas

# %%
import pandas as pd
import numpy as np
from scipy import stats
import math

def reduce_to_first_significant_digit(quantity, uncertainty):
    first_significant_digit = math.floor(math.log10(abs(uncertainty)))
    quantity = round(quantity, -first_significant_digit)
    uncertainty = round(uncertainty, -first_significant_digit)
    return quantity, uncertainty

# %%
path_to_experimental_results = "pKa_replicate_experimental_results.csv"
path_to_experimental_pKa_values = "pKa_experimental_values.csv"

# %%
df_exp_results = pd.read_csv(path_to_experimental_results)
df_exp_results.head()
# Out:
#   Molecule ID  pKa1  pKa2  pKa3  \
# 0        SM01  9.54   NaN   NaN
# 1        SM01  9.53   NaN   NaN
# 2        SM01  9.53   NaN   NaN
# 3        SM02  5.04   NaN   NaN
# 4        SM02  5.04   NaN   NaN
#
#                                         Assay Type Experiment ID  \
# 0                                    UV-metric pKa     17I-15024
# 1                                    UV-metric pKa     17I-15025
# 2                                    UV-metric pKa     17I-16001
# 3  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17I-22022
# 4  UV-metric psKa, Yasuda-Shedlovsky Extrapolation     17I-22023
#
#   Experimental Molecule ID                    Experiment Report
# 0                      M01   17I-15024_M01_UV-metric pKa_report
# 1                      M01   17I-15025_M01_UV-metric pKa_report
# 2                      M01   17I-16001_M01_UV-metric pKa_report
# 3                      M02  17I-22022_M02_UV-metric psKa_report
# 4                      M02  17I-22023_M02_UV-metric psKa_report

# %%
df_exp_pKa = pd.DataFrame()
df_exp_pKa["Molecule ID"] = np.NaN
df_exp_pKa["pKa1 mean"] = np.NaN
df_exp_pKa["pKa1 SEM"] = np.NaN
df_exp_pKa["pKa2 mean"] = np.NaN
df_exp_pKa["pKa2 SEM"] = np.NaN
df_exp_pKa["pKa3 mean"] = np.NaN
df_exp_pKa["pKa3 SEM"] = np.NaN
df_exp_pKa["Assay Type"] = np.NaN
df_exp_pKa["Experimental Molecule ID"] = np.NaN

df_exp_pKa.head()
# Out:
# Empty DataFrame
# Columns: [Molecule ID, pKa1 mean, pKa1 SEM, pKa2 mean, pKa2 SEM, pKa3 mean, pKa3 SEM, Assay Type, Experimental Molecule ID]
# Index: []

# %%
df_exp_pKa.columns
# Out:
# Index(['Molecule ID', 'pKa1 mean', 'pKa1 SEM', 'pKa2 mean', 'pKa2 SEM',
#        'pKa3 mean', 'pKa3 SEM', 'Assay Type', 'Experimental Molecule ID'],
#       dtype='object')

# %%
# iterate over every 3rd experiment to get molecule IDs
index_range = np.arange(0,df_exp_results.shape[0],3,dtype=int)
for i in index_range:
    molecule_ID = df_exp_results.loc[i,"Molecule ID"]
    assay_type = df_exp_results.loc[i,"Assay Type"]
    exp_molecule_ID = df_exp_results.loc[i,"Experimental Molecule ID"]
    s = pd.Series([molecule_ID, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, assay_type, exp_molecule_ID], index = df_exp_pKa.columns)
    df_exp_pKa = df_exp_pKa.append(s, ignore_index=True)
    
df_exp_pKa
# Out:
#    Molecule ID  pKa1 mean  pKa1 SEM  pKa2 mean  pKa2 SEM  pKa3 mean  pKa3 SEM  \
# 0         SM01        NaN       NaN        NaN       NaN        NaN       NaN
# 1         SM02        NaN       NaN        NaN       NaN        NaN       NaN
# 2         SM03        NaN       NaN        NaN       NaN        NaN       NaN
# 3         SM04        NaN       NaN        NaN       NaN        NaN       NaN
# 4         SM05        NaN       NaN        NaN       NaN        NaN       NaN
# 5         SM06        NaN       NaN        NaN       NaN        NaN       NaN
# 6         SM07        NaN       NaN        NaN       NaN        NaN       NaN
# 7         SM08        NaN       NaN        NaN       NaN        NaN       NaN
# 8         SM09        NaN       NaN        NaN       NaN        NaN       NaN
# 9         SM10        NaN       NaN        NaN       NaN        NaN       NaN
# 10        SM11        NaN       NaN        NaN       NaN        NaN       NaN
# 11        SM12        NaN       NaN        NaN       NaN        NaN       NaN
# 12        SM13        NaN       NaN        NaN       NaN        NaN       NaN
# 13        SM14        NaN       NaN        NaN       NaN        NaN       NaN
# 14        SM15        NaN       NaN        NaN       NaN        NaN       NaN
# 15        SM16        NaN       NaN        NaN       NaN        NaN       NaN
# 16        SM17        NaN       NaN        NaN       NaN        NaN       NaN
# 17        SM18        NaN       NaN        NaN       NaN        NaN       NaN
# 18        SM19        NaN       NaN        NaN       NaN        NaN       NaN
# 19        SM20        NaN       NaN        NaN       NaN        NaN       NaN
# 20        SM21        NaN       NaN        NaN       NaN        NaN       NaN
# 21        SM22        NaN       NaN        NaN       NaN        NaN       NaN
# 22        SM23        NaN       NaN        NaN       NaN        NaN       NaN
# 23        SM24        NaN       NaN        NaN       NaN        NaN       NaN
#
#                                          Assay Type Experimental Molecule ID
# 0                                     UV-metric pKa                      M01
# 1   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M02
# 2   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M03
# 3                                     UV-metric pKa                      M04
# 4   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M05
# 5                                     UV-metric pKa                      M06
# 6                                     UV-metric pKa                      M07
# 7                                     UV-metric pKa                      M08
# 8   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M09
# 9   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M10
# 10                                    UV-metric pKa                      M11
# 11                                    UV-metric pKa                      M12
# 12                                    UV-metric pKa                      M13
# 13                                    UV-metric pKa                      M15
# 14                                    UV-metric pKa                      M16
# 15                                    UV-metric pKa                      M18
# 16                                    UV-metric pKa                      M19
# 17  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D01
# 18  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D02
# 19  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D05
# 20  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D06
# 21  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D07
# 22  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D08
# 23  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D09

# %%
# Calculate mean and SEM for pKa values of each molecule
for i, row in enumerate(df_exp_pKa.iterrows()):
    molecule_ID = row[1]["Molecule ID"]
    
    pKa1_SEM = np.NaN
    pKa2_SEM = np.NaN
    pKa3_SEM = np.NaN

    # Parse pKa values of each replicate experiment for each molecule ID
    df_exp_result = df_exp_results.loc[df_exp_results["Molecule ID"] == molecule_ID]    
    pKa1_array = df_exp_result["pKa1"]
    pKa2_array = df_exp_result["pKa2"]
    pKa3_array = df_exp_result["pKa3"]
    
    # Calculate mean of 3 replicates format(a, '.2f')
    pKa1_mean = float(format(np.mean(pKa1_array), '.2f'))
    pKa2_mean = float(format(np.mean(pKa2_array), '.2f'))
    pKa3_mean = float(format(np.mean(pKa3_array), '.2f'))
    #pKa2_mean = np.mean(pKa2_array)
    #pKa3_mean = np.mean(pKa3_array)
    
    # Calculate standard error of the mean (SEM)
    # ddof=0 provides a maximum likelihood estimate of the variance for normally distributed variables
    pKa1_SEM = stats.sem(pKa1_array, ddof = 0) 
    pKa2_SEM = stats.sem(pKa2_array, ddof = 0) 
    pKa3_SEM = stats.sem(pKa3_array, ddof = 0)
    #print(molecule_ID,pKa1_SEM)
    
    # Reduce SEM values to 1st significat digit
    # Since pKa experimental data was reported in 2 decimal points, 
    # SEM will be reported as 0.01 if calculated SEM value from 3 replicates is lower than 0.01.
    minimum_SEM = float(0.01)

    if pKa1_SEM == 0:
        pKa1_SEM = minimum_SEM
    elif (np.isnan(pKa1_SEM) == False):
        pKa1_SEM = max(minimum_SEM, reduce_to_first_significant_digit(pKa1_mean, pKa1_SEM)[1])
    
    if pKa2_SEM == 0:
        pKa2_SEM = minimum_SEM
    elif np.isnan(pKa2_SEM) == False:
        pKa2_SEM = max(minimum_SEM, reduce_to_first_significant_digit(pKa2_mean, pKa2_SEM)[1])
    
    if pKa3_SEM == 0:
        pKa3_SEM = minimum_SEM
    elif np.isnan(pKa3_SEM) == False:
        pKa3_SEM = max(minimum_SEM, reduce_to_first_significant_digit(pKa3_mean, pKa3_SEM)[1])
    
    # Write mean and SEM values to df_exp_pKa dataframe
    df_exp_pKa.loc[i, "pKa1 mean"] =  str(format(pKa1_mean, '.2f'))
    df_exp_pKa.loc[i, "pKa2 mean"] =  str(format(pKa2_mean, '.2f'))
    df_exp_pKa.loc[i, "pKa3 mean"] =  str(format(pKa3_mean, '.2f'))
    
    df_exp_pKa.loc[i, "pKa1 SEM"] =  str(format(pKa1_SEM, '.2f'))
    df_exp_pKa.loc[i, "pKa2 SEM"] =  str(format(pKa2_SEM, '.2f'))
    df_exp_pKa.loc[i, "pKa3 SEM"] =  str(format(pKa3_SEM, '.2f'))

df_exp_pKa.to_csv(path_to_experimental_pKa_values, index=False) 

df_exp_pKa
# Out:
#    Molecule ID pKa1 mean pKa1 SEM pKa2 mean pKa2 SEM pKa3 mean pKa3 SEM  \
# 0         SM01      9.53     0.01       nan      nan       nan      nan
# 1         SM02      5.03     0.01       nan      nan       nan      nan
# 2         SM03      7.02     0.01       nan      nan       nan      nan
# 3         SM04      6.02     0.01       nan      nan       nan      nan
# 4         SM05      4.59     0.01       nan      nan       nan      nan
# 5         SM06      3.03     0.04     11.74     0.01       nan      nan
# 6         SM07      6.08     0.01       nan      nan       nan      nan
# 7         SM08      4.22     0.01       nan      nan       nan      nan
# 8         SM09      5.37     0.01       nan      nan       nan      nan
# 9         SM10      9.02     0.01       nan      nan       nan      nan
# 10        SM11      3.89     0.01       nan      nan       nan      nan
# 11        SM12      5.28     0.01       nan      nan       nan      nan
# 12        SM13      5.77     0.01       nan      nan       nan      nan
# 13        SM14      2.58     0.01      5.30     0.01       nan      nan
# 14        SM15      4.70     0.01      8.94     0.01       nan      nan
# 15        SM16      5.37     0.01     10.65     0.01       nan      nan
# 16        SM17      3.16     0.01       nan      nan       nan      nan
# 17        SM18      2.15     0.02      9.58     0.03     11.02     0.04
# 18        SM19      9.56     0.02       nan      nan       nan      nan
# 19        SM20      5.70     0.03       nan      nan       nan      nan
# 20        SM21      4.10     0.01       nan      nan       nan      nan
# 21        SM22      2.40     0.02      7.43     0.01       nan      nan
# 22        SM23      5.45     0.01       nan      nan       nan      nan
# 23        SM24      2.60     0.01       nan      nan       nan      nan
#
#                                          Assay Type Experimental Molecule ID
# 0                                     UV-metric pKa                      M01
# 1   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M02
# 2   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M03
# 3                                     UV-metric pKa                      M04
# 4   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M05
# 5                                     UV-metric pKa                      M06
# 6                                     UV-metric pKa                      M07
# 7                                     UV-metric pKa                      M08
# 8   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M09
# 9   UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      M10
# 10                                    UV-metric pKa                      M11
# 11                                    UV-metric pKa                      M12
# 12                                    UV-metric pKa                      M13
# 13                                    UV-metric pKa                      M15
# 14                                    UV-metric pKa                      M16
# 15                                    UV-metric pKa                      M18
# 16                                    UV-metric pKa                      M19
# 17  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D01
# 18  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D02
# 19  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D05
# 20  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D06
# 21  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D07
# 22  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D08
# 23  UV-metric psKa, Yasuda-Shedlovsky Extrapolation                      D09
