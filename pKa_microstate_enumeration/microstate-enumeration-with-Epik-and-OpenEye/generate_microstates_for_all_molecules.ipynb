# %% [markdown]
# # Generating microstates for all molecules
#
# Microstates are defined as tautomer and protomers of a molecule. We enumerated microstates with Epik and OpenEye Quakpac and took the union of results. Even though resonance structures correspond to different canonical isomeric SMILES they are not different microstates. Multiple resonance structures were removed.
#
# To detect multiple resonance structures we compared fixed hydrogen InChI strings. Resonance structures lead to same InChI string but tautomers and protomers have unique InChI strings.

# %%
import pandas as pd
import numpy as np
import os, sys
from openeye.oechem import *
from openeye.oequacpac import *

def prepare_inchi(mol):
    """Create InChI hashes with explicit, fixed hydrogen layer from an OEGraphMol."""
    opts = OEInChIOptions()
    # Do not add hydrogens.
    opts.SetHydrogens(False)
    # Return the fixed hydrogen layer
    opts.SetFixedHLayer(True)
    return OECreateInChI(mol, opts)

# SAMPL6 small molecules
df_sm =pd.read_csv("molecule_ID_and_SMILES.csv")
df_sm
# Out:
#    SAMPL6 Molecule ID                          canonical isomeric SMILES
# 0                SM01                      c1cc2c(cc1O)c3c(o2)C(=O)NCCC3
# 1                SM02              c1ccc2c(c1)c(ncn2)Nc3cccc(c3)C(F)(F)F
# 2                SM03                  c1ccc(cc1)Cc2nnc(s2)NC(=O)c3cccs3
# 3                SM04                   c1ccc2c(c1)c(ncn2)NCc3ccc(cc3)Cl
# 4                SM05              c1ccc(c(c1)NC(=O)c2ccc(o2)Cl)N3CCCCC3
# 5                SM06                 c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# 6                SM07                         c1ccc(cc1)CNc2c3ccccc3ncn2
# 7                SM08        Cc1ccc2c(c1)c(c(c(=O)[nH]2)CC(=O)O)c3ccccc3
# 8                SM09                     COc1cccc(c1)Nc2c3ccccc3ncn2.Cl
# 9                SM10               c1ccc(cc1)C(=O)NCC(=O)Nc2nc3ccccc3s2
# 10               SM11                       c1ccc(cc1)n2c3c(cn2)c(ncn3)N
# 11               SM12                 c1ccc2c(c1)c(ncn2)Nc3cccc(c3)Cl.Cl
# 12               SM13                 Cc1cccc(c1)Nc2c3cc(c(cc3ncn2)OC)OC
# 13               SM14                         c1ccc(cc1)n2cnc3c2ccc(c3)N
# 14               SM15                         c1ccc2c(c1)ncn2c3ccc(cc3)O
# 15               SM16                   c1cc(c(c(c1)Cl)C(=O)Nc2ccncc2)Cl
# 16               SM17                      c1ccc(cc1)CSc2nnc(o2)c3ccncc3
# 17               SM18  c1ccc2c(c1)c(=O)[nH]c(n2)CCC(=O)Nc3ncc(s3)Cc4c...
# 18               SM19        CCOc1ccc2c(c1)sc(n2)NC(=O)Cc3ccc(c(c3)Cl)Cl
# 19               SM20   c1cc(cc(c1)OCc2ccc(cc2Cl)Cl)/C=C/3\C(=O)NC(=O)S3
# 20               SM21          c1cc(cc(c1)Br)Nc2c(cnc(n2)Nc3cccc(c3)Br)F
# 21               SM22                            c1cc2c(cc(c(c2nc1)O)I)I
# 22               SM23  CCOC(=O)c1ccc(cc1)Nc2cc(nc(n2)Nc3ccc(cc3)C(=O)...
# 23               SM24        COc1ccc(cc1)c2c3c(ncnc3oc2c4ccc(cc4)OC)NCCO

# %%
for i,row in df_sm.iterrows():
    molecule_ID = row["SAMPL6 Molecule ID"]
    smiles = row["canonical isomeric SMILES"]
    print(molecule_ID, ":", smiles)
    
    #### ENUMERATE MICROSTATES WITH EPIK ####
    # Using Schrodinger/Suites2016-4
    
    # Create the SMILES file
    # !echo "Creating molecule.smi containing SMILES string..."
    #!echo "c1ccc(cc1)n2c3c(cn2)c(ncn3)N" >> molecule.smi
    with open("molecule.smi", "w") as input_file:
        input_file.write(smiles)
        input_file.write("\n")

    # Convert it to a Maestro file 
    # !echo "Running ligprep to generate molecule.mae input file..."
    # !$SCHRODINGER/ligprep -ismi molecule.smi -omae molecule.mae -WAIT

    # Run Epik to enumerate all "reasonable" protomers/tautomers
    # !echo "Running Epik to enumerate all tautomers within 20 pK units of pH 7..."
    # !$SCHRODINGER/epik -imae molecule.mae -omae epik.mae -pht 20 -ms 100 -ph 7 -WAIT

    # Extract SMILES strings for all protomers/tautomers
    # !echo "Converting output to SMILES and writing epik_microstates.smi"
    # !$SCHRODINGER/utilities/structconvert -imae epik.mae -osmi epik_microstates.smi

    # !cp epik_microstates.smi epik_microstates.csv
    # !echo "Number of predicted microstates:"
    # !wc -l epik_microstates.csv

    # Create Excel file with 2D structures.
    # !echo "Creating Excel spreadsheet with 2D microstate structures..."
    # !python csv2xlsx.py epik_microstates.csv epik_microstates.xlsx

    # !echo "Done!"
    
    
    #### Enumerate microstates with OpenEye QuacPac ####
    # Enumerate tautomers/protomers with OpenEye QuacPac
    # !echo "Generating microstates with OpenEye..."

    ifs = oemolistream()
    if not ifs.open("molecule.smi"):
        OEThrow.Fatal("Unable to open SMI for reading")

    # Tautomer enumeration options
    tautomer_maxCount = 200
    tautomerOptions = OETautomerOptions(tautomer_maxCount)
    tautomerOptions.SetLevel(5)
    tautomerOptions.SetMaxSearchTime(240)
    tautomerOptions.SetCarbonHybridization(False)
    #tautomerOptions.SetRankTautomers(True)

    # Formal charge enumeration options
    charge_maxCount = 200
    chargeOptions = OEFormalChargeOptions(charge_maxCount)

    mol = OEGraphMol()

    # Unique microstate SMILES will be stored in a set
    smiles_set = set()

    while OEReadMolecule(ifs, mol):
        OERemoveFormalCharge(mol)

        # Enumerate charges first and tautomers for each charged state
        for charged_mol in OEEnumerateFormalCharges(mol, chargeOptions):
            for tautomer in OEEnumerateTautomers(charged_mol, tautomerOptions):
                smiles = OEMolToSmiles(tautomer)
                smiles_set.add(smiles) # unique SMILES are added to the set

        # Enumerate tautomers first and charges after for each tautomer
        for tautomer in OEEnumerateTautomers(mol, tautomerOptions):
            for charged_tautomer in OEEnumerateFormalCharges(tautomer, chargeOptions):
                smiles = OEMolToSmiles(charged_tautomer)
                smiles_set.add(smiles) # unique SMILES are added to the set

    with open("oe_microstates.smi", "w") as output:
        for smiles in smiles_set:
            output.write(smiles)
            output.write("\n")

    print("Done!")

    # !wc -l oe_microstates.smi
    # !cp oe_microstates.smi oe_microstates.csv

    # Clean up
    # !trash molecule.smi

    
    #### Merge Epik and OpenEye generated microstates ####
    
    # Create a set to store Canonical Isomeric SMILES of unique microstates
    microstates_set = set()

    # Convert SMILES of Epik output to OE Canonical Isomeric SMILES

    df_epik_microstates = pd.read_csv("epik_microstates.csv", header=None)
    df_epik_microstates.columns = ["Epik output"]
    df_epik_microstates["Canonical Isomeric SMILES"] = None

    for i, row in enumerate(df_epik_microstates.iterrows()):
        smiles = row[1].values[0]

        mol = OEGraphMol()
        OESmilesToMol(mol, smiles)
        canonical_smiles = OEMolToSmiles(mol)

        df_epik_microstates.loc[i, "Canonical Isomeric SMILES"] = canonical_smiles
        microstates_set.add(canonical_smiles)


    # Convert OE output to OpenEye Canonical Isomeric SMILES

    df_oe_microstates = pd.read_csv("oe_microstates.csv", header=None)
    df_oe_microstates.columns = ["OpenEye output"]
    df_oe_microstates["Canonical Isomeric SMILES"] = None

    for i, row in enumerate(df_oe_microstates.iterrows()):
        smiles = row[1].values[0]

        mol = OEGraphMol()
        OESmilesToMol(mol, smiles)
        canonical_smiles = OEMolToSmiles(mol)

        df_oe_microstates.loc[i, "Canonical Isomeric SMILES"] = canonical_smiles
        microstates_set.add(canonical_smiles)

    # Number of microstates with unique canonical isomeric SMILES.
    # It may still include replicates due to resonance structures.
    print("Number of generated canonical isomeric SMILES (microstates + resonance str.): ", len(microstates_set))
    
    
    #### Remove duplicate resonance structures of the same microstate ####
    
    # Canonical isomeric SMILES are different for tautomers, protomers and resonance structures. 
    # We will only consider tautomers and protomers as unique microstates in this study.
    
    inchi_set = set()
    smiles_for_removal_set = set()

    for smiles in microstates_set:
        mol = OEGraphMol()
        OESmilesToMol(mol, smiles)
        inchi = prepare_inchi(mol)

        #if the same InChI is already in InChI set, drop microstate from microstates set.
        if inchi in inchi_set:
            print("Duplicate resonance structure detected. Remove:", smiles)
            smiles_for_removal_set.add(smiles)

        else:
            inchi_set.add(inchi)

    for smiles in smiles_for_removal_set:
        microstates_set.remove(smiles)

    print(len(microstates_set), " microstates were generated for ", molecule_ID, "." )
    
    
    #### Write generated microstates ####
    
    with open("{}_microstate_SMILES.smi".format(molecule_ID), "w") as output:
        for smiles in microstates_set:
            output.write(smiles)
            output.write("\n")
        
    df = pd.read_csv("{}_microstate_SMILES.smi".format(molecule_ID), header =None)
    df.columns = ["Canonical Isomeric SMILES"]
    df["Microstate ID"] = None

    for i, row in enumerate(df.iterrows()):
        id = molecule_ID+"_micro"+str(i+1).zfill(3) 
        df.loc[i, "Microstate ID"]=id

    df_microstate_ID = pd.DataFrame()
    df_microstate_ID["microstate ID"] = df["Microstate ID"] 
    df_microstate_ID["canonical isomeric SMILES"] = df["Canonical Isomeric SMILES"]
    df_microstate_ID.to_csv("{}_microstates.csv".format(molecule_ID), index=False)


    # save csv file with microstate ID and SMILES
    df.to_csv("{}_microstate_IDs_with_2D_depiction.csv".format(molecule_ID), index=False)

    # create excel file with 2D structures, microstate IDs and SMILES
    df["microstate ID"] = df["Microstate ID"]
    df["canonical isomeric SMILES"] = df["Canonical Isomeric SMILES"]

    csv_file_name="{}_microstate_IDs_with_2D_depiction.csv".format(molecule_ID)
    xlsx_file_name= "{}_microstate_IDs_with_2D_depiction.xlsx".format(molecule_ID)
    df.to_csv(csv_file_name, index=False)

    # !python csv2xlsx.py $csv_file_name $xlsx_file_name
    # !trash $csv_file_name
    
    # save csv for type 3 output format

    df_microstate_populations = pd.DataFrame()
    df_microstate_populations["microstate ID"]=df["microstate ID"]

    # pH range [2, 12] with 0.1 increments
    pH_range = np.arange(2,12.1,0.1)

    # make columns for each pH point
    for pH in np.nditer(pH_range):
        pH_header = "{0:.2f}".format(float(pH))
        df_microstate_populations[pH_header]=None

    df_microstate_populations.to_csv("{}_microstate_fractional_populations.csv".format(molecule_ID), index=False)

    print("Finished writing microstate files for {}!".format(molecule_ID))
    print("\n")
    print("\n")
# Out:
# SM01 : c1cc2c(cc1O)c3c(o2)C(=O)NCCC3
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4cde
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4cef
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#        8 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        6 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  12
# Duplicate resonance structure detected. Remove: c1cc2c(cc1O)c3c(o2)C(=[NH+]CCC3)[O-]
# Duplicate resonance structure detected. Remove: c1cc2c(cc1[O-])c3c(o2)C(=[NH+]CCC3)[O-]
# 10  microstates were generated for  SM01 .
# Finished writing microstate files for SM01!
#
#
#
#
# SM02 : c1ccc2c(c1)c(ncn2)Nc3cccc(c3)C(F)(F)F
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4d07
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4d19
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       12 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        3 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  14
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(=[NH+]c3cccc(c3)C(F)(F)F)[n-]cn2
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)/c(=[NH+]\c3cccc(c3)C(F)(F)F)/nc[nH]2
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(nc[nH+]2)Nc3cccc(c3)C(F)(F)F
# 11  microstates were generated for  SM02 .
# Finished writing microstate files for SM02!
#
#
#
#
# SM03 : c1ccc(cc1)Cc2nnc(s2)NC(=O)c3cccs3
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4d34
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4d46
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       14 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#       26 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  40
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[n-]c(=NC(=C3C=CC=[S+]3)[O-])s2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[nH]c(=NC(=C3C=CC=[S+]3)[O-])s2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[n-]c([s+]2)N=C(c3cccs3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[nH]c([s+]2)N=C(c3cccs3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2[n-][nH]c(=NC(=O)c3cccs3)[s+]2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2[n-][nH+]c([s+]2)[N-]C(=C3C=CC=[S+]3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[nH]c([s+]2)[N-]C(=C3C=CC=[S+]3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[n-]c([s+]2)[N-]C(=O)c3cccs3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2[n-]nc([s+]2)N=C(c3cccs3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2nnc(s2)[N-]C(=C3C=CC=[S+]3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[nH+]c(s2)N=C(c3cccs3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2nnc(s2)[N-]C(=O)c3cccs3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2[n-][nH+]c([s+]2)N=C(c3cccs3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[nH]c([s+]2)[N-]C(=O)c3cccs3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2[n-]nc([s+]2)[N-]C(=C3C=CC=[S+]3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[nH+]c(s2)[N-]C(=O)c3cccs3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2[n-][n-]c(=NC(=C3C=CC=[S+]3)[O-])[s+]2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)Cc2n[n-]c(=NC(=O)c3cccs3)s2
# 22  microstates were generated for  SM03 .
# Finished writing microstate files for SM03!
#
#
#
#
# SM04 : c1ccc2c(c1)c(ncn2)NCc3ccc(cc3)Cl
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4d5f
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4d70
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       11 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        6 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  16
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)/c(=[NH+]/Cc3ccc(cc3)Cl)/nc[nH]2
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(nc[nH+]2)[N-]Cc3ccc(cc3)Cl
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)/c(=[NH+]\Cc3ccc(cc3)Cl)/nc[nH]2
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(nc[nH+]2)NCc3ccc(cc3)Cl
# 12  microstates were generated for  SM04 .
# Finished writing microstate files for SM04!
#
#
#
#
# SM05 : c1ccc(c(c1)NC(=O)c2ccc(o2)Cl)N3CCCCC3
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4d88
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4d99
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#        9 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        6 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  13
# Duplicate resonance structure detected. Remove: c1ccc(c(c1)[NH+]=C(c2ccc(o2)Cl)[O-])N3CCCCC3
# Duplicate resonance structure detected. Remove: c1ccc(c(c1)[NH+]=C(c2ccc(o2)Cl)[O-])[NH+]3CCCCC3
# 11  microstates were generated for  SM05 .
# Finished writing microstate files for SM05!
#
#
#
#
# SM06 : c1cc2cccnc2c(c1)NC(=O)c3cc(cnc3)Br
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4db0
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4dc2
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       12 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        8 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  16
# Duplicate resonance structure detected. Remove: c1cc2cccnc2c(c1)NC(=O)c3cc(c[nH+]c3)Br
# Duplicate resonance structure detected. Remove: c1cc2ccc[nH+]c2c(c1)[NH+]=C(c3cc(cnc3)Br)[O-]
# Duplicate resonance structure detected. Remove: c1cc2cccnc2c(c1)[NH+]=C(c3cc(cnc3)Br)[O-]
# Duplicate resonance structure detected. Remove: c1cc2ccc[nH+]c2c(c1)[NH+]=C(c3cc(c[nH+]c3)Br)[O-]
# 12  microstates were generated for  SM06 .
# Finished writing microstate files for SM06!
#
#
#
#
# SM07 : c1ccc(cc1)CNc2c3ccccc3ncn2
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4dd9
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4dea
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       11 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        6 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  16
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CN=c2c3ccccc3[nH+]c[n-]2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C[NH+]=c2c3ccccc3[nH]cn2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C/[NH+]=c\2/c3ccccc3[nH]cn2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CNc2c3ccccc3[nH+]cn2
# 12  microstates were generated for  SM07 .
# Finished writing microstate files for SM07!
#
#
#
#
# SM08 : Cc1ccc2c(c1)c(c(c(=O)[nH]2)CC(=O)O)c3ccccc3
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4e02
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4e13
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       12 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        6 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  16
# Duplicate resonance structure detected. Remove: Cc1ccc2c(c1)c(c(c(=O)[nH]2)CC(=[OH+])[O-])c3ccccc3
# Duplicate resonance structure detected. Remove: Cc1ccc2c(c1)c(c(c([nH+]2)O)CC(=O)O)c3ccccc3
# Duplicate resonance structure detected. Remove: Cc1ccc2c(c1)c(c(c(=[OH+])[nH]2)CC(=O)[O-])c3ccccc3
# Duplicate resonance structure detected. Remove: Cc1ccc2c(c1)c(c(c(=O)[nH]2)CC(=O)O)c3ccccc3
# Duplicate resonance structure detected. Remove: Cc1ccc2c(c1)c(c(c([nH+]2)[O-])CC(=O)[O-])c3ccccc3
# Duplicate resonance structure detected. Remove: Cc1ccc2c(c1)c(c(c([nH+]2)[O-])CC(=[OH+])[O-])c3ccccc3
# 10  microstates were generated for  SM08 .
# Finished writing microstate files for SM08!
#
#
#
#
# SM09 : COc1cccc(c1)Nc2c3ccccc3ncn2.Cl
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4e2a
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4e3c
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       12 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        3 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  15
# Duplicate resonance structure detected. Remove: COc1cccc(c1)Nc2c3ccccc3[nH+]cn2
# Duplicate resonance structure detected. Remove: COc1cccc(c1)/[NH+]=c/2\c3ccccc3[nH]cn2
# Duplicate resonance structure detected. Remove: COc1cccc(c1)[NH+]=c2c3ccccc3[n-]cn2.[Cl-]
# 12  microstates were generated for  SM09 .
# Finished writing microstate files for SM09!
#
#
#
#
# SM10 : c1ccc(cc1)C(=O)NCC(=O)Nc2nc3ccccc3s2
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4e53
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4e64
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       33 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#       10 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  43
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C(=[NH+]CC(=O)[N-]c2[nH+]c3ccccc3s2)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C(=[NH+]CC(=O)N=c2[nH]c3ccccc3s2)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C(=[NH+]CC(=Nc2[nH+]c3ccccc3s2)[O-])[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C(=[NH+]CC(=O)[N-]c2[nH]c3ccccc3[s+]2)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C(=O)NCC(=O)[N-]c2[nH]c3ccccc3[s+]2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C(=O)NCC(=Nc2[nH+]c3ccccc3s2)[O-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C(=O)NCC(=Nc2[nH]c3ccccc3[s+]2)[O-]
# 36  microstates were generated for  SM10 .
# Finished writing microstate files for SM10!
#
#
#
#
# SM11 : c1ccc(cc1)n2c3c(cn2)c(ncn3)N
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4e8c
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4e9e
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       11 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#       18 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  27
# Duplicate resonance structure detected. Remove: c1ccc(cc1)n2c3c(cn2)c(=N)[n-]cn3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)[n+]2c3c(c[n-]2)c(ncn3)[NH-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)n2c3c(cn2)c(=[NH2+])[n-]cn3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)n2c3c(cn2)c(=[NH2+])nc[n-]3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)[n+]2c-3[n-]cnc(c3cn2)[NH-]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)[n+]2c3c(c[n-]2)c(=[NH2+])nc[n-]3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)n2c3c(cn2)c(ncn3)N
# Duplicate resonance structure detected. Remove: c1ccc(cc1)n2c3c(cn2)c(=N)nc[n-]3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)[n+]2c3c(c[n-]2)c(=N)nc[n-]3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)[n+]2c3c(c[n-]2)c(=N)[n-]cn3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)[n+]2c-3[n-]cnc(c3cn2)N
# 16  microstates were generated for  SM11 .
# Finished writing microstate files for SM11!
#
#
#
#
# SM12 : c1ccc2c(c1)c(ncn2)Nc3cccc(c3)Cl.Cl
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4eb5
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4ec6
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       12 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        3 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  15
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(=[NH+]c3cccc(c3)Cl)nc[n-]2.[Cl-]
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)/c(=[NH+]\c3cccc(c3)Cl)/nc[nH]2
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)/c(=[NH+]/c3cccc(c3)Cl)/nc[nH]2
# 12  microstates were generated for  SM12 .
# Finished writing microstate files for SM12!
#
#
#
#
# SM13 : Cc1cccc(c1)Nc2c3cc(c(cc3ncn2)OC)OC
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4edd
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4eef
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       12 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        5 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  16
# Duplicate resonance structure detected. Remove: Cc1cccc(c1)/[NH+]=c/2\c3cc(c(cc3[nH]cn2)OC)OC
# Duplicate resonance structure detected. Remove: Cc1cccc(c1)Nc2c3cc(c(cc3[nH+]cn2)OC)OC
# Duplicate resonance structure detected. Remove: Cc1cccc(c1)Nc2c-3cc(c(=[O+]C)cc3[n-]cn2)OC
# Duplicate resonance structure detected. Remove: Cc1cccc(c1)[NH+]=c2c3cc(c(cc3nc[n-]2)OC)OC
# 12  microstates were generated for  SM13 .
# Finished writing microstate files for SM13!
#
#
#
#
# SM14 : c1ccc(cc1)n2cnc3c2ccc(c3)N
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4f06
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4f17
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#        6 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        8 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  10
# Duplicate resonance structure detected. Remove: c1ccc(cc1)n2cnc3c2ccc(c3)[NH3+]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)[n+]2c[nH]c3c2ccc(c3)[NH3+]
# Duplicate resonance structure detected. Remove: c1ccc(cc1)[n+]2c[nH]c3c2ccc(c3)N
# Duplicate resonance structure detected. Remove: c1ccc(cc1)n2cnc3c2ccc(c3)N
# 6  microstates were generated for  SM14 .
# Finished writing microstate files for SM14!
#
#
#
#
# SM15 : c1ccc2c(c1)ncn2c3ccc(cc3)O
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4f2f
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4f40
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#        4 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        8 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  8
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)[n-]c[n+]2c3ccc(cc3)[O-]
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)[nH]c[n+]2c3ccc(cc3)O
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)[n-]c[n+]2c3ccc(cc3)O
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)[nH+]cn2c3ccc(cc3)[O-]
# 4  microstates were generated for  SM15 .
# Finished writing microstate files for SM15!
#
#
#
#
# SM16 : c1cc(c(c(c1)Cl)C(=O)Nc2ccncc2)Cl
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4f57
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4f68
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#        9 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        6 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  12
# Duplicate resonance structure detected. Remove: c1cc(c(c(c1)Cl)C(=[NH+]c2ccncc2)[O-])Cl
# Duplicate resonance structure detected. Remove: c1cc(c(c(c1)Cl)C(=O)Nc2cc[nH+]cc2)Cl
# Duplicate resonance structure detected. Remove: c1cc(c(c(c1)Cl)C(=O)[NH+]=c2cc[n-]cc2)Cl
# Duplicate resonance structure detected. Remove: c1cc(c(c(c1)Cl)C(=O)[NH+]=c2cc[nH]cc2)Cl
# 8  microstates were generated for  SM16 .
# Finished writing microstate files for SM16!
#
#
#
#
# SM17 : c1ccc(cc1)CSc2nnc(o2)c3ccncc3
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4f7f
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4f91
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#        4 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#       14 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  16
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C[S+]=C2N=NC(=C3C=C[N-]C=C3)O2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CSc2n[n-]c([o+]2)c3ccncc3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CSc2nnc(o2)c3cc[nH+]cc3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C[S+]=c2[n-][n-]c([o+]2)c3ccncc3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CSc2n[n-]c([o+]2)c3cc[nH+]cc3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CSc2nnc(o2)c3ccncc3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CSc2[n-]nc([o+]2)c3cc[nH+]cc3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C[S+]=C2N=NC(=C3C=CNC=C3)O2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CSC2=[O+]C(=C3C=C[N-]C=C3)N=N2
# Duplicate resonance structure detected. Remove: c1ccc(cc1)C[S+]=c2[n-][n-]c([o+]2)c3cc[nH+]cc3
# Duplicate resonance structure detected. Remove: c1ccc(cc1)CSc2[n-]nc([o+]2)c3ccncc3
# 5  microstates were generated for  SM17 .
# Finished writing microstate files for SM17!
#
#
#
#
# SM18 : c1ccc2c(c1)c(=O)[nH]c(n2)CCC(=O)Nc3ncc(s3)Cc4ccc(c(c4)F)F
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4fa7
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb4fb9
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#      142 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#       45 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  109
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(nc([nH+]2)CCC(=O)[NH+]=c3[nH]cc(s3)Cc4ccc(c(c4)F)F)[O-]
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(=O)[n-]c([nH+]2)CCC(=[NH+]c3ncc(s3)Cc4ccc(c(c4)F)F)[O-]
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(=O)[n-]c([nH+]2)CCC(=O)Nc3[nH+]cc(s3)Cc4ccc(c(c4)F)F
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(nc([nH+]2)CCC(=O)[NH+]=c3[n-]cc(s3)Cc4ccc(c(c4)F)F)[O-]
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(=O)[n-]c([nH+]2)CCC(=O)[N-]c3[n-]cc([s+]3)Cc4ccc(c(c4)F)F
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(=O)[n-]c([nH+]2)CCC(=O)Nc3[nH]cc([s+]3)Cc4ccc(c(c4)F)F
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(=O)[n-]c([nH+]2)CCC(=[NH+]c3[nH]cc([s+]3)Cc4ccc(c(c4)F)F)[O-]
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(=O)nc([nH]2)CCC(=[NH+]c3ncc(s3)Cc4ccc(c(c4)F)F)[O-]
# Duplicate resonance structure detected. Remove: c1ccc2c(c1)c(nc([nH+]2)CCC(=[NH+]c3ncc(s3)Cc4ccc(c(c4)F)F)[O-])[O-]
# ...
# Duplicate resonance structure detected. Remove: c1cc(cc(c1)Br)Nc2[n-]c(=[NH+]c3cccc(c3)Br)c(cn2)F
# Duplicate resonance structure detected. Remove: c1cc(cc(c1)Br)Nc2[nH]cc(/c(=[NH+]\c3cccc(c3)Br)/n2)F
# Duplicate resonance structure detected. Remove: c1cc(cc(c1)Br)Nc2[n-]cc(c(=[NH+]c3cccc(c3)Br)n2)F
# Duplicate resonance structure detected. Remove: c1cc(cc(c1)Br)Nc2c(cnc(=Nc3cccc(c3)Br)[n-]2)F
# Duplicate resonance structure detected. Remove: c1cc(cc(c1)Br)[NH+]=c2c(c[n-]c(n2)[N-]c3cccc(c3)Br)F
# Duplicate resonance structure detected. Remove: c1cc(cc(c1)Br)Nc2c(cnc(=[NH+]c3cccc(c3)Br)[n-]2)F
# 25  microstates were generated for  SM21 .
# Finished writing microstate files for SM21!
#
#
#
#
# SM22 : c1cc2c(cc(c(c2nc1)O)I)I
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb5174
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb5185
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#        4 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#        4 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  4
# 4  microstates were generated for  SM22 .
# Finished writing microstate files for SM22!
#
#
#
#
# SM23 : CCOC(=O)c1ccc(cc1)Nc2cc(nc(n2)Nc3ccc(cc3)C(=O)OCC)C
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb519c
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb51ae
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       26 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#       74 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  99
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=[NH+]c2cc([nH]c(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])n2)C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH]c(=[NH+]c3ccc(cc3)C(=O)OCC)n2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2[nH]c(c/c(=[NH+]/c3ccc(cc3)C(=O)OCC)/n2)C
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=[NH+]c2[nH]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])n2)C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH+]c(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)N=c2[nH+]c(cc([n-]2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=Nc2[nH]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])n2)C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=[NH+]c2[nH+]c(cc(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=[NH+]c2cc([nH+]c(=Nc3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)Nc2cc([nH+]c(=Nc3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)N=c2[nH+]c(cc([n-]2)[NH+]=C3C=CC(=C([O-])OCC)C=C3)C
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)Nc2cc([nH+]c(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH]c(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=[NH+]c2[nH+]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)N=c2[nH]c(cc(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=[NH+]c2cc([nH]c(=Nc3ccc(cc3)C(=[O+]CC)[O-])n2)C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2[nH+]c(cc(n2)[NH+]=C3C=CC(=C([O-])OCC)C=C3)C
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)[NH+]=c2cc([nH]c(=Nc3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C)[O-]
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)Nc2cc([nH+]c(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2[nH]c(c/c(=[NH+]\c3ccc(cc3)C(=O)OCC)/n2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2[nH+]c(cc([n-]2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)Nc2[nH+]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH]c(=Nc3ccc(cc3)C(=O)OCC)[n-]2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH]c(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2[nH+]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)Nc2cc([nH]c(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])n2)C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH+]c([n-]2)[N-]c3ccc(cc3)C(=O)OCC)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2[nH+]c(cc(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH+]c([n-]2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[N-]c2[nH+]c(cc(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=[NH+]c2cc([nH+]c(n2)[N-]c3ccc(cc3)C(=[O+]CC)[O-])C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2[nH]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])n2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2[nH+]c(cc([n-]2)[NH+]=C3C=CC(=C([O-])OCC)C=C3)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH+]c(n2)Nc3ccc(cc3)C(=O)OCC)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2[nH]c(cc(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[N-]c2[nH+]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)Nc2cc([nH+]c(n2)[N-]c3ccc(cc3)C(=[O+]CC)[O-])C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=[NH+]c2cc([nH+]c(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2[nH+]c(cc(=[NH+]c3ccc(cc3)C(=O)OCC)[n-]2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH]c(n2)[N-]c3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)N=c2[nH]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH+]c(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)Nc2cc([nH]c(=Nc3ccc(cc3)C(=[O+]CC)[O-])n2)C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH+]c(n2)N=C3C=CC(=C([O-])OCC)C=C3)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH+]c([n-]2)[NH+]=C3C=CC(=C([O-])OCC)C=C3)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH+]c(n2)[N-]c3ccc(cc3)C(=O)OCC)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH]c(n2)[N-]c3ccc(cc3)C(=O)OCC)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH]c(=Nc3ccc(cc3)C(=[O+]CC)[O-])n2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH+]c(n2)[N-]c3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH+]c(n2)[NH+]=C3C=CC(=C([O-])OCC)C=C3)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2[nH]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)[NH+]=c2cc([nH]c(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH+]c([n-]2)N=C3C=CC(=C([O-])OCC)C=C3)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[N-]c2[nH]c(cc(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])n2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH+]c(=Nc3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH]c(=Nc3ccc(cc3)C(=[O+]CC)[O-])[n-]2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)Nc2cc([nH]c(=[NH+]c3ccc(cc3)C(=[O+]CC)[O-])n2)C
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH]c(=[NH+]c3ccc(cc3)C(=O)OCC)[n-]2)C
# Duplicate resonance structure detected. Remove: CC[O+]=C(c1ccc(cc1)[NH+]=c2cc([nH+]c([n-]2)[N-]c3ccc(cc3)C(=[O+]CC)[O-])C)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[NH+]=c2cc([nH+]c([n-]2)[N-]c3ccc(cc3)C(=[O+]CC)[O-])C
# Duplicate resonance structure detected. Remove: CCOC(=C1C=CC(=Nc2[nH+]c(cc(n2)Nc3ccc(cc3)C(=[O+]CC)[O-])C)C=C1)[O-]
# Duplicate resonance structure detected. Remove: CCOC(=O)c1ccc(cc1)[N-]c2[nH+]c(cc(n2)[NH+]=C3C=CC(=C([O-])OCC)C=C3)C
# 37  microstates were generated for  SM23 .
# Finished writing microstate files for SM23!
#
#
#
#
# SM24 : COc1ccc(cc1)c2c3c(ncnc3oc2c4ccc(cc4)OC)NCCO
# Creating molecule.smi containing SMILES string...
# Running ligprep to generate molecule.mae input file...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb51f7
#
# Running Epik to enumerate all tautomers within 20 pK units of pH 7...
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# JobId: lski1946-0-59eb5208
#
# Converting output to SMILES and writing epik_microstates.smi
# WARNING There seems to be a user specific host file located at /Users/isikm/.schrodinger/schrodinger.hosts. Support for user specific host files is deprecated and might be removed in a future release. Please use the hosts file from the installation /opt/schrodinger/suites2016-4.
# Converted file: epik_microstates.smi
# Number of predicted microstates:
#       21 epik_microstates.csv
# Creating Excel spreadsheet with 2D microstate structures...
# Done!
# Generating microstates with OpenEye...
# Done!
#       25 oe_microstates.smi
# Number of generated canonical isomeric SMILES (microstates + resonance str.):  43
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c-3c(nc[n-]c3[o+]c2c4ccc(cc4)OC)[N-]CCO
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c([nH]c[nH+]c3=NCCO)oc2c4ccc(cc4)OC
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c-3c([n-]cnc3[o+]c2c4ccc(cc4)OC)[N-]CCO
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c(=NCCO)[n-]cnc3oc2c4ccc(cc4)OC
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c-3c([nH+]c[nH]c3[o+]c2c4ccc(cc4)OC)[N-]CCO
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c([nH+]cnc3oc2c4ccc(cc4)OC)NCCO
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c([nH+]cnc3oc2c4ccc(cc4)OC)[N-]CCO
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c(=[NH+]CCO)[nH]c[nH+]c3oc2c4ccc(cc4)OC
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c([nH+]cnc3NCC[O-])oc2c4ccc(cc4)OC
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c-3c([nH+]c[nH]c3[o+]c2c4ccc(cc4)OC)NCCO
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c([nH+]cnc3NCC[OH2+])oc2c4ccc(cc4)OC
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c\3c([nH]cn/c3=[NH+]\CCO)oc2c4ccc(cc4)OC
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c([n-]cnc3=NCCO)oc2c4ccc(cc4)OC
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c-3c([nH+]c[n-]c3[o+]c2c4ccc(cc4)OC)[N-]CCO
# Duplicate resonance structure detected. Remove: COc1ccc(cc1)c2c3c([nH]c[nH+]c3=[NH+]CCO)oc2c4ccc(cc4)OC
# 28  microstates were generated for  SM24 .
# Finished writing microstate files for SM24!

# %%
# Clean up
# !trash lski*
# !trash molecule.mae
# !trash epik.mae
# !trash epik.log
