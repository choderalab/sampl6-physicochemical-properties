# %% [markdown]
# # Updating Microstate Lists Based on Manual Correction
#
# This jupyter notebook incorporates a participant's suggested microstates (Robert Fraczkiewicz) and removes dublicated microstates(resonance structures and cis-trans isomers) detected by visual inspection.
#
# Files to be created for 24 molecules:
# * SMX_microstates.csv
# * SMX_microstates_deprecated.csv
# * SMX_microstate_IDs_with_2D_depiction.xlsx

# %%
import pandas as pd
from openeye.oechem import *

# %%
path_to_correction_files = "corrections/"
path_to_corrected_files = "microstate_lists_after_manual_correction/"

# Iterate over 24 molecules
for j in range(24):
    mol_name = "SM"+str(j+1).zfill(2)
    print(mol_name, "...")

    # Read correction file
    correction_file = path_to_correction_files + mol_name + "_correction.csv"
    df_microstates = pd.read_csv(correction_file)

    # Convert all SMILES to canonical isomeric SMILES
    for i, row in enumerate(df_microstates.iterrows()):
        smiles = df_microstates.loc[i,"canonical isomeric SMILES"]

        mol = OEGraphMol()
        OESmilesToMol(mol, smiles)
        canonical_smiles = OEMolToSmiles(mol)

        df_microstates.loc[i, "canonical isomeric SMILES"] = canonical_smiles
    
    # Check if there is any deprecated microstate

    correction = df_microstates["correction"]
    deprecated_boolean = correction.isin(["deprecated"])

    deprecated_label = False
    for b in deprecated_boolean:
        if b == False:
            continue
        if b == True:
            print("Deprecated microstate found.")
            deprecated_label = True


    # Check if there is any added microstate

    correction = df_microstates["correction"]
    added_boolean = correction.isin(["added"])

    added_label = False
    for b in added_boolean:
        if b == False:
            continue
        if b == True:
            print("Added microstate found.")
            added_label = True


    # Write deprecated microstates to a separate file

    if(deprecated_label):
        df_deprecated = df_microstates.loc[df_microstates["correction"] == "deprecated"]
        print("Number of deprecated microstates of {}: {}".format(mol_name, df_deprecated.shape[0]))

        df_deprecated = df_deprecated.rename(columns = {"correction":"remarks"})

        deprecated_microstates_file_name = path_to_corrected_files + mol_name + "_microstates_deprecated.csv"
        df_deprecated.to_csv(deprecated_microstates_file_name, index=False)
        print("Created:" , deprecated_microstates_file_name)
        print("\n")


    # Write new microstates list with deprecated microstates removed and new microstates added.

    if(deprecated_label and added_label):
        df_remaining = df_microstates.loc[df_microstates["correction"] != "deprecated"]
        df_remaining = df_remaining.loc[df_remaining["correction"] != "added"]
        print("Number of remaining microstates of {}: {}".format(mol_name, df_remaining.shape[0]))

        df_added = df_microstates.loc[df_microstates["correction"] == "added"]
        print("Number of new microstates of {}: {}".format(mol_name, df_added.shape[0]))
        
        df_updated = df_microstates.loc[df_microstates["correction"] != "deprecated"]
        print("Total number of microstates in updated list of {}: {}".format(mol_name, df_updated.shape[0]))

    elif(added_label): # no deprecated
        df_remaining = df_microstates.loc[df_remaining["correction"] != "added"]
        print("Number of remaining microstates of {}: {}".format(mol_name, df_remaining.shape[0]))

        df_added = df_microstates.loc[df_microstates["correction"] == "added"]
        print("Number of new microstates of {}: {}".format(mol_name, df_added.shape[0]))

        df_updated = df_microstates
        print("Total number of microstates in updated list of {}: {}".format(mol_name, df_updated.shape[0]))

    elif(deprecated_label): # no added

        df_updated = df_microstates.loc[df_microstates["correction"] != "deprecated"]
        print("Total number of microstates in updated list of {}: {}".format(mol_name, df_updated.shape[0]))

    else:
        df_updated = df_microstates
        print("No correction to microstate list.")
        print("Total number of microstates in updated list of {}: {}".format(mol_name, df_updated.shape[0]))


    df_updated = df_updated.loc[:,("microstate ID","canonical isomeric SMILES")]

    updated_microstates_file_name = path_to_corrected_files + mol_name + "_microstates.csv"
    df_updated.to_csv(updated_microstates_file_name, index=False)
    print("Created:" , updated_microstates_file_name)
    print("\n")


    # Create Excel file with 2D depiction for updated microstates list

    # Organize colums to create csv input file for csv2xlsx.py script
    df_2D_input = pd.DataFrame()
    df_2D_input["Molecule"] = df_updated["canonical isomeric SMILES"]
    df_2D_input["Microstate ID"] = df_updated["microstate ID"]
    df_2D_input["microstate ID"] = df_updated["microstate ID"]
    df_2D_input["canonical isomeric SMILES"] = df_updated["canonical isomeric SMILES"]

    csv_file_name = path_to_corrected_files + "{}_microstate_IDs_with_2D_depiction.csv".format(mol_name)
    xlsx_file_name = path_to_corrected_files + "{}_microstate_IDs_with_2D_depiction.xlsx".format(mol_name)

    df_2D_input.to_csv(csv_file_name, index=False)

    # !python csv2xlsx.py $csv_file_name $xlsx_file_name
    # !trash $csv_file_name
    print("Created: ",xlsx_file_name)
    print(mol_name, ": Done!")
    print("\n")
# Out:
# SM01 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Number of deprecated microstates of SM01: 2
# Created: microstate_lists_after_manual_correction/SM01_microstates_deprecated.csv
#
#
# Total number of microstates in updated list of SM01: 8
# Created: microstate_lists_after_manual_correction/SM01_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM01_microstate_IDs_with_2D_depiction.xlsx
# SM01 : Done!
#
#
# SM02 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM02: 3
# Created: microstate_lists_after_manual_correction/SM02_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM02: 8
# Number of new microstates of SM02: 3
# Total number of microstates in updated list of SM02: 11
# Created: microstate_lists_after_manual_correction/SM02_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM02_microstate_IDs_with_2D_depiction.xlsx
# SM02 : Done!
#
#
# SM03 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM03: 8
# Created: microstate_lists_after_manual_correction/SM03_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM03: 14
# Number of new microstates of SM03: 2
# Total number of microstates in updated list of SM03: 16
# Created: microstate_lists_after_manual_correction/SM03_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM03_microstate_IDs_with_2D_depiction.xlsx
# SM03 : Done!
#
#
# SM04 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM04: 5
# Created: microstate_lists_after_manual_correction/SM04_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM04: 7
# Number of new microstates of SM04: 4
# Total number of microstates in updated list of SM04: 11
# Created: microstate_lists_after_manual_correction/SM04_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM04_microstate_IDs_with_2D_depiction.xlsx
# SM04 : Done!
#
#
# SM05 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Number of deprecated microstates of SM05: 2
# Created: microstate_lists_after_manual_correction/SM05_microstates_deprecated.csv
#
#
# Total number of microstates in updated list of SM05: 9
# Created: microstate_lists_after_manual_correction/SM05_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM05_microstate_IDs_with_2D_depiction.xlsx
# SM05 : Done!
#
#
# SM06 ...
# No correction to microstate list.
# Total number of microstates in updated list of SM06: 12
# Created: microstate_lists_after_manual_correction/SM06_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM06_microstate_IDs_with_2D_depiction.xlsx
# SM06 : Done!
#
#
# SM07 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM07: 5
# Created: microstate_lists_after_manual_correction/SM07_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM07: 7
# Number of new microstates of SM07: 4
# Total number of microstates in updated list of SM07: 11
# Created: microstate_lists_after_manual_correction/SM07_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM07_microstate_IDs_with_2D_depiction.xlsx
# SM07 : Done!
#
#
# SM08 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Number of deprecated microstates of SM08: 3
# Created: microstate_lists_after_manual_correction/SM08_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM08: 7
# Number of new microstates of SM08: 1
# Total number of microstates in updated list of SM08: 8
# Created: microstate_lists_after_manual_correction/SM08_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM08_microstate_IDs_with_2D_depiction.xlsx
# SM08 : Done!
#
#
# SM09 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM09: 4
# Created: microstate_lists_after_manual_correction/SM09_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM09: 8
# Number of new microstates of SM09: 3
# Total number of microstates in updated list of SM09: 11
# Created: microstate_lists_after_manual_correction/SM09_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM09_microstate_IDs_with_2D_depiction.xlsx
# SM09 : Done!
#
#
# SM10 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Number of deprecated microstates of SM10: 4
# Created: microstate_lists_after_manual_correction/SM10_microstates_deprecated.csv
#
#
# Total number of microstates in updated list of SM10: 32
# Created: microstate_lists_after_manual_correction/SM10_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM10_microstate_IDs_with_2D_depiction.xlsx
# SM10 : Done!
#
#
# SM11 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM11: 10
# Created: microstate_lists_after_manual_correction/SM11_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM11: 6
# Number of new microstates of SM11: 14
# Total number of microstates in updated list of SM11: 20
# Created: microstate_lists_after_manual_correction/SM11_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM11_microstate_IDs_with_2D_depiction.xlsx
# SM11 : Done!
#
#
# SM12 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM12: 4
# Created: microstate_lists_after_manual_correction/SM12_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM12: 8
# Number of new microstates of SM12: 3
# Total number of microstates in updated list of SM12: 11
# Created: microstate_lists_after_manual_correction/SM12_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM12_microstate_IDs_with_2D_depiction.xlsx
# SM12 : Done!
#
#
# SM13 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM13: 4
# Created: microstate_lists_after_manual_correction/SM13_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM13: 8
# Number of new microstates of SM13: 3
# Total number of microstates in updated list of SM13: 11
# Created: microstate_lists_after_manual_correction/SM13_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM13_microstate_IDs_with_2D_depiction.xlsx
# SM13 : Done!
#
#
# SM14 ...
# No correction to microstate list.
# Total number of microstates in updated list of SM14: 6
# Created: microstate_lists_after_manual_correction/SM14_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM14_microstate_IDs_with_2D_depiction.xlsx
# SM14 : Done!
#
#
# SM15 ...
# No correction to microstate list.
# Total number of microstates in updated list of SM15: 4
# Created: microstate_lists_after_manual_correction/SM15_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM15_microstate_IDs_with_2D_depiction.xlsx
# SM15 : Done!
#
#
# SM16 ...
# No correction to microstate list.
# Total number of microstates in updated list of SM16: 8
# Created: microstate_lists_after_manual_correction/SM16_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM16_microstate_IDs_with_2D_depiction.xlsx
# SM16 : Done!
#
#
# SM17 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM17: 3
# Created: microstate_lists_after_manual_correction/SM17_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM17: 2
# Number of new microstates of SM17: 6
# Total number of microstates in updated list of SM17: 8
# Created: microstate_lists_after_manual_correction/SM17_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM17_microstate_IDs_with_2D_depiction.xlsx
# SM17 : Done!
#
#
# SM18 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Number of deprecated microstates of SM18: 2
# Created: microstate_lists_after_manual_correction/SM18_microstates_deprecated.csv
#
#
# Total number of microstates in updated list of SM18: 72
# Created: microstate_lists_after_manual_correction/SM18_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM18_microstate_IDs_with_2D_depiction.xlsx
# SM18 : Done!
#
#
# SM19 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Number of deprecated microstates of SM19: 4
# Created: microstate_lists_after_manual_correction/SM19_microstates_deprecated.csv
#
#
# Total number of microstates in updated list of SM19: 15
# Created: microstate_lists_after_manual_correction/SM19_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM19_microstate_IDs_with_2D_depiction.xlsx
# SM19 : Done!
#
#
# SM20 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Number of deprecated microstates of SM20: 2
# Created: microstate_lists_after_manual_correction/SM20_microstates_deprecated.csv
#
#
# Total number of microstates in updated list of SM20: 2
# Created: microstate_lists_after_manual_correction/SM20_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM20_microstate_IDs_with_2D_depiction.xlsx
# SM20 : Done!
#
#
# SM21 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM21: 11
# Created: microstate_lists_after_manual_correction/SM21_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM21: 14
# Number of new microstates of SM21: 11
# Total number of microstates in updated list of SM21: 25
# Created: microstate_lists_after_manual_correction/SM21_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM21_microstate_IDs_with_2D_depiction.xlsx
# SM21 : Done!
#
#
# SM22 ...
# No correction to microstate list.
# Total number of microstates in updated list of SM22: 4
# Created: microstate_lists_after_manual_correction/SM22_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM22_microstate_IDs_with_2D_depiction.xlsx
# SM22 : Done!
#
#
# SM23 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM23: 6
# Created: microstate_lists_after_manual_correction/SM23_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM23: 31
# Number of new microstates of SM23: 11
# Total number of microstates in updated list of SM23: 42
# Created: microstate_lists_after_manual_correction/SM23_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM23_microstate_IDs_with_2D_depiction.xlsx
# SM23 : Done!
#
#
# SM24 ...
# Deprecated microstate found.
# Deprecated microstate found.
# Deprecated microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Added microstate found.
# Number of deprecated microstates of SM24: 3
# Created: microstate_lists_after_manual_correction/SM24_microstates_deprecated.csv
#
#
# Number of remaining microstates of SM24: 25
# Number of new microstates of SM24: 7
# Total number of microstates in updated list of SM24: 32
# Created: microstate_lists_after_manual_correction/SM24_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM24_microstate_IDs_with_2D_depiction.xlsx
# SM24 : Done!

# %% [markdown]
# ## One molecules script for testing

# %%
mol_name = "SM05"
path_to_correction_files = "corrections/"
path_to_corrected_files = "microstate_lists_after_manual_correction/"

# Read correction file
correction_file = path_to_correction_files + mol_name + "_correction.csv"
df_microstates = pd.read_csv(correction_file)

# Convert all SMILES to canonical isomeric SMILES
for i, row in enumerate(df_microstates.iterrows()):
    smiles = df_microstates.loc[i,"canonical isomeric SMILES"]

    mol = OEGraphMol()
    OESmilesToMol(mol, smiles)
    canonical_smiles = OEMolToSmiles(mol)

    df_microstates.loc[i, "canonical isomeric SMILES"] = canonical_smiles
df_microstates
# Out:
#     microstate ID                          canonical isomeric SMILES  \
# 0   SM05_micro001              c1ccc(c(c1)NC(=O)c2ccc(o2)Cl)N3CCCCC3
# 1   SM05_micro002        c1ccc(c(c1)/N=C(/c2ccc(o2)Cl)\[O-])N3CCCCC3
# 2   SM05_micro003     c1ccc(c(c1)[NH2+]C(=[OH+])c2ccc(o2)Cl)N3CCCCC3
# 3   SM05_micro004  c1ccc(c(c1)NC(=C2C=CC(=[O+]2)Cl)[O-])[NH+]3CCCCC3
# 4   SM05_micro005      c1ccc(c(c1)NC(=[OH+])c2ccc(o2)Cl)[NH+]3CCCCC3
# 5   SM05_micro006    c1ccc(c(c1)/N=C(/c2ccc(o2)Cl)\[O-])[NH+]3CCCCC3
# 6   SM05_micro007      c1ccc(c(c1)NC(=C2C=CC(=[O+]2)Cl)[O-])N3CCCCC3
# 7   SM05_micro008       c1ccc(c(c1)[N-]C(=[OH+])c2ccc(o2)Cl)N3CCCCC3
# 8   SM05_micro009          c1ccc(c(c1)NC(=[OH+])c2ccc(o2)Cl)N3CCCCC3
# 9   SM05_micro010          c1ccc(c(c1)NC(=O)c2ccc(o2)Cl)[NH+]3CCCCC3
# 10  SM05_micro011   c1ccc(c(c1)[N-]C(=[OH+])c2ccc(o2)Cl)[NH+]3CCCCC3
#
#     correction
# 0          NaN
# 1          NaN
# 2          NaN
# 3   deprecated
# 4          NaN
# 5          NaN
# 6   deprecated
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN

# %%
# Check if there is any deprecated microstate

correction = df_microstates["correction"]
deprecated_boolean = correction.isin(["deprecated"])

deprecated_label = False
for b in deprecated_boolean:
    if b == False:
        continue
    if b == True:
        print("Deprecated microstate found.")
        deprecated_label = True
        
        
# Check if there is any added microstate

correction = df_microstates["correction"]
added_boolean = correction.isin(["added"])

added_label = False
for b in added_boolean:
    if b == False:
        continue
    if b == True:
        print("Added microstate found.")
        added_label = True

        
# Write deprecated microstates to a separate file

if(deprecated_label):
    df_deprecated = df_microstates.loc[df_microstates["correction"] == "deprecated"]
    print("Number of deprecated microstates of {}: {}".format(mol_name, df_deprecated.shape[0]))

    df_deprecated = df_deprecated.rename(columns = {"correction":"remarks"})

    deprecated_microstates_file_name = path_to_corrected_files + mol_name + "_microstates_deprecated.csv"
    df_deprecated.to_csv(deprecated_microstates_file_name, index=False)
    print("Created:" , deprecated_microstates_file_name)
    print("\n")

    
# Write new microstates list with deprecated microstates removed and new microstates added.

if(deprecated_label and added_label):
    df_remaining = df_microstates.loc[df_microstates["correction"] != "deprecated"]
    df_remaining = df_remaining.loc[df_remaining["correction"] != "added"]
    print("Number of remaining microstates of {}: {}".format(mol_name, df_remaining.shape[0]))
    
    df_added = df_microstates.loc[df_microstates["correction"] == "added"]
    print("Number of new microstates of {}: {}".format(mol_name, df_added.shape[0]))
    
    df_updated = df_microstates.loc[df_microstates["correction"] != "deprecated"]
    print("Total number of microstates in updated list of {}: {}".format(mol_name, df_updated.shape[0]))

elif(added_label): # no deprecated
    df_remaining = df_microstates.loc[df_remaining["correction"] != "added"]
    print("Number of remaining microstates of {}: {}".format(mol_name, df_remaining.shape[0]))
    
    df_added = df_microstates.loc[df_microstates["correction"] == "added"]
    print("Number of new microstates of {}: {}".format(mol_name, df_added.shape[0]))
    
    df_updated = df_microstates
    print("Total number of microstates in updated list of {}: {}".format(mol_name, df_updated.shape[0]))

elif(deprecated_label): # no added
    
    df_updated = df_microstates.loc[df_microstates["correction"] != "deprecated"]
    print("Total number of microstates in updated list of {}: {}".format(mol_name, df_updated.shape[0]))
    
else:
    df_updated = df_microstates
    print("No correction to microstate list.")
    print("Total number of microstates in updated list of {}: {}".format(mol_name, df_updated.shape[0]))


df_updated = df_updated.loc[:,("microstate ID","canonical isomeric SMILES")]

updated_microstates_file_name = path_to_corrected_files + mol_name + "_microstates.csv"
df_updated.to_csv(updated_microstates_file_name, index=False)
print("Created:" , updated_microstates_file_name)
print("\n")


# Create Excel file with 2D depiction for updated microstates list

# Organize colums to create csv input file for csv2xlsx.py script
df_2D_input = pd.DataFrame()
df_2D_input["Molecule"] = df_updated["canonical isomeric SMILES"]
df_2D_input["Microstate ID"] = df_updated["microstate ID"]
df_2D_input["microstate ID"] = df_updated["microstate ID"]
df_2D_input["canonical isomeric SMILES"] = df_updated["canonical isomeric SMILES"]

csv_file_name = path_to_corrected_files + "{}_microstate_IDs_with_2D_depiction.csv".format(mol_name)
xlsx_file_name = path_to_corrected_files + "{}_microstate_IDs_with_2D_depiction.xlsx".format(mol_name)

df_2D_input.to_csv(csv_file_name, index=False)

# !python csv2xlsx.py $csv_file_name $xlsx_file_name
# !trash $csv_file_name
print("Created: ",xlsx_file_name)
print(mol_name, ": Done!")
print("\n")
# Out:
# Deprecated microstate found.
# Deprecated microstate found.
# Number of deprecated microstates of SM05: 2
# Created: microstate_lists_after_manual_correction/SM05_microstates_deprecated.csv
#
#
# Total number of microstates in updated list of SM05: 9
# Created: microstate_lists_after_manual_correction/SM05_microstates.csv
#
#
# Created:  microstate_lists_after_manual_correction/SM05_microstate_IDs_with_2D_depiction.xlsx
# SM05 : Done!
