# %%
import pandas as pd
import numpy as np

# %%
df_exp = pd.read_csv("experimental_microstates.csv")
df_exp
# Out:
#   Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 0      SM07_micro004       SM07_micro006        SM07       6.08
# 1      SM14_micro001       SM14_micro002        SM14       5.30
# 2      SM14_micro002       SM14_micro003        SM14       2.58
# 3      SM02_micro001       SM02_micro004        SM02       5.03
# 4      SM04_micro003       SM04_micro002        SM04       6.02
# 5      SM09_micro003       SM09_micro001        SM09       5.37
# 6      SM12_micro012       SM12_micro006        SM12       5.28
# 7      SM13_micro005       SM13_micro001        SM13       5.77
# 8      SM15_micro004       SM15_micro002        SM15       8.94
# 9      SM15_micro002       SM15_micro003        SM15       4.70
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 0           0.01  SM07_pKa1                          NMR measurement
# 1           0.01  SM14_pKa2                          NMR measurement
# 2           0.01  SM14_pKa1                          NMR measurement
# 3           0.01  SM02_pKa1  Estimated based on SM07 NMR measurement
# 4           0.01  SM04_pKa1  Estimated based on SM07 NMR measurement
# 5           0.01  SM09_pKa1  Estimated based on SM07 NMR measurement
# 6           0.01  SM12_pKa1  Estimated based on SM07 NMR measurement
# 7           0.01  SM13_pKa1  Estimated based on SM07 NMR measurement
# 8           0.01  SM15_pKa2  Estimated based on SM14 NMR measurement
# 9           0.01  SM15_pKa1  Estimated based on SM14 NMR measurement

# %%
df_pred = pd.read_csv("nb008-976-typeI-epik_microscopic-1-predictions.csv")
df_pred.head(30)
# Out:
#    Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM
# 0        SM01_micro001      SM01_micro005     -0.48     0.90
# 1        SM01_micro001      SM01_micro006      9.60     1.12
# 2        SM01_micro004      SM01_micro002     13.29     2.00
# 3        SM01_micro005      SM01_micro004      9.12     1.12
# 4        SM01_micro005      SM01_micro010     12.93     2.00
# 5        SM01_micro006      SM01_micro004     -0.48     0.90
# 6        SM01_micro010      SM01_micro002      9.40     1.47
# 7        SM02_micro002      SM02_micro011     13.21     0.73
# 8        SM02_micro003      SM02_micro011      5.90     0.86
# 9        SM02_micro004      SM02_micro002      4.05     1.47
# 10       SM02_micro004      SM02_micro007     11.01     2.22
# 11       SM02_micro005      SM02_micro002      3.51     0.86
# 12       SM02_micro005      SM02_micro003      7.42     2.00
# 13       SM02_micro007      SM02_micro011      5.09     1.47
# 14       SM02_micro012      SM02_micro005     -1.76     2.00
# 15       SM03_micro001      SM03_micro004      8.58     2.22
# 16       SM03_micro001      SM03_micro012     -0.03     2.00
# 17       SM03_micro004      SM03_micro002      1.76     2.22
# 18       SM03_micro011      SM03_micro012     -2.64     0.90
# 19       SM03_micro012      SM03_micro002      7.12     2.22
# 20       SM03_micro013      SM03_micro002      4.95     2.22
# 21       SM03_micro016      SM03_micro012     -2.07     2.00
# 22       SM03_micro016      SM03_micro013      5.01     2.00
# 23       SM03_micro020      SM03_micro013      3.57     2.22
# 24       SM03_micro021      SM03_micro001     -0.05     2.00
# 25       SM04_micro002      SM04_micro003      5.60     1.13
# 26       SM04_micro002      SM04_micro004     11.40     2.22
# 27       SM04_micro003      SM04_micro005     13.77     0.73
# 28       SM04_micro004      SM04_micro005      5.14     1.47
# 29       SM04_micro006      SM04_micro003      3.88     2.22

# %%
def microstate_matching(pred_pKas, pred_pKa_SEMs, pred_HA_microstate_IDs, pred_A_microstate_IDs,
                        exp_pKas, exp_pKa_SEMs, exp_HA_microstate_IDs, exp_A_microstate_IDs, exp_pKa_IDs):
    """
    Matches experimental and predicted micoscopic pKas based on reported microstate ID pairs.
    Both microstate IDs and the order should match the experiment, for microscopic pKa match.

    :param pred_pKas:
    :param exp_pKa_means:
    :param exp_pKa_SEMs:
    :param exp_pKa_IDs:
    :return:
    """
    matched = pd.DataFrame()
    
    # Create a list of experimental microstate ID pairs (list of tuples)
    exp_ID_pairs = []
    for i in range(len(exp_HA_microstate_IDs)):
        exp_ID_pair = (exp_HA_microstate_IDs[i], exp_A_microstate_IDs[i])
        exp_ID_pairs.append(exp_ID_pair)
        
    # Iterate through predicted ID pairs to see if it matches to any experimental ID pair.
    for i in range(len(pred_HA_microstate_IDs)):
        pred_ID_pair = (pred_HA_microstate_IDs[i], pred_A_microstate_IDs[i])
        
        # Check for matches in experimental microstate ID pair list
        for j, exp_ID_pair in enumerate(exp_ID_pairs):
            if pred_ID_pair == exp_ID_pair:
                match = {"pKa mean(pred)" : pred_pKas[i], "pKa SEM(pred)": pred_pKa_SEMs[i],
                         'microstate ID of HA(pred)': pred_HA_microstate_IDs[i],
                         'microstate ID of A(pred)': pred_A_microstate_IDs[i], 
                         'pKa mean(exp)': exp_pKas[j], 'pKa SEM(exp)': exp_pKa_SEMs[j], 
                         'microstate ID of HA(exp)': exp_HA_microstate_IDs[j],
                         'microstate ID of A(exp)': exp_A_microstate_IDs[j],
                         'pKa ID': exp_pKa_IDs[j]}
    
                matched = matched.append(match, ignore_index=True)
    
    return matched

# %%
def add_pKa_IDs_to_matching_predictions_microstate_based_matching(df_pred, df_exp):
    """Add pKa ID column to dataframe of predictions based on
    the minimum error match to experimental pKas.

    Args:
        df_pred: Pandas Dataframe of pKa predictions
        df_exp: Pandas Dataframe of experimental pKas (stacked)

    Returns:
        df_pred_matched: A dataframe of predicted pKa values that gave the best match to experimental values.
        Other predicted pKa values are ignored.
        df_pred_unmatched: A dataframe of predicted pKas that were not matched to experimental pKa values

    """

    # iterate over molecule IDs of the submission
    df_pred["pKa ID"] = np.NaN
    
    # Create a column of molecule IDs
    #df_pred["Molecule ID"] = df_pred.index
    df_pred["Molecule ID"] = np.NaN
    for i, row in enumerate(df_pred.iterrows()):
        mol_id = df_pred.loc[i, "Microstate ID of HA"].split("_")[0]
        df_pred.loc[i, "Molecule ID"] = mol_id

    for mol_id, df_pred_mol in df_pred.groupby("Molecule ID"):
        print("mol_id: ", mol_id)
        print("df_pred_mol:\n", df_pred_mol)
        
        df_exp_mol = df_exp[df_exp["Molecule ID"] == mol_id]
        print("df_exp_mol:\n",df_exp_mol)
        # Create numpy array of predicted pKas and SEMS
        pred_pKas = np.array(df_pred_mol["pKa mean"]) # if there is multiple predicted pKas
        pred_pKa_SEMs = np.array(df_pred_mol["pKa SEM"])
        try:
            len(df_pred_mol["pKa mean"])
        except TypeError:
            pred_pKas = np.array([df_pred_mol["pKa mean"]])  # if there is single predicted pKa
            pred_pKa_SEMs = np.array([df_pred_mol["pKa SEM"]])
            
        # Create numpy arrays of microstates IDs of HA and microstate IDs of A
        pred_HA_microstate_IDs = np.array(df_pred_mol["Microstate ID of HA"]) # if there is multiple predicted pKas
        pred_A_microstate_IDs = np.array(df_pred_mol["Microstate ID of A"]) # if there is multiple predicted pKas
        try:
            len(df_pred_mol["Microstate ID of HA"])
        except TypeError:
            pred_HA_microstate_IDs = np.array([df_pred_mol["Microstate ID of HA"]])  # if there is single predicted pKa
            pred_A_microstate_IDs = np.array([df_pred_mol["Microstate ID of A"]])  # if there is single predicted pKa

        # Create numpy array of experimental pKa means, pKa SEM , pKa_ID, experimental microstate ID of HA and H
        exp_pKa_means = np.array(df_exp_mol.loc[:, "pKa (exp)"].values)
        exp_pKa_SEMs = np.array(df_exp_mol.loc[:, "pKa SEM (exp)"].values)
        exp_pKa_IDs = np.array(df_exp_mol.loc[:, "pKa ID"].values)
        exp_HA_microstate_IDs = np.array(df_exp_mol.loc[:, "Microstate ID of HA"].values)
        exp_A_microstate_IDs = np.array(df_exp_mol.loc[:, "Microstate ID of A"].values)

        # Match predicted pKas to experimental pKa that gives the smallest error
        df_pKa_match = microstate_matching(pred_pKas, pred_pKa_SEMs, pred_HA_microstate_IDs, pred_A_microstate_IDs,
                                           exp_pKa_means, exp_pKa_SEMs, exp_HA_microstate_IDs, exp_A_microstate_IDs,
                                           exp_pKa_IDs)
        df_pKa_match["Molecule ID"] = mol_id
        print("df_pKa_match:\n", df_pKa_match)

        # Add matched pKa IDs to prediction data frame
        for index, row in enumerate(df_pKa_match.iterrows()):
            pred_pKa = row[1]["pKa mean(pred)"]
            pKa_ID = row[1]["pKa ID"]

            # store in the correct position in prediction dataframe

            df_pred.loc[(df_pred["Molecule ID"] == mol_id) & (df_pred["pKa mean"] == pred_pKa), "pKa ID"] = pKa_ID

    # Save unmatched pKas in df_pred_unmatched dataframe
    df_pred_unmatched = df_pred.loc[pd.isnull(df_pred["pKa ID"])]

    # Drop predicted pKas that didn't match to experimental values
    df_pred_matched = df_pred.dropna(subset=["pKa ID"]).reset_index(drop=True)

    # If there are multiple microscopic pKas with the same exact value keep only the first one
    df_pred_matched.drop_duplicates(subset="pKa mean", keep="first", inplace=True)

    return df_pred_matched, df_pred_unmatched

# %%
(df_pred_matched, df_pred_unmatched) = add_pKa_IDs_to_matching_predictions_microstate_based_matching(df_pred, df_exp)
# Out:
# mol_id:  SM01
# df_pred_mol:
#    Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 0       SM01_micro001      SM01_micro005     -0.48     0.90     NaN
# 1       SM01_micro001      SM01_micro006      9.60     1.12     NaN
# 2       SM01_micro004      SM01_micro002     13.29     2.00     NaN
# 3       SM01_micro005      SM01_micro004      9.12     1.12     NaN
# 4       SM01_micro005      SM01_micro010     12.93     2.00     NaN
# 5       SM01_micro006      SM01_micro004     -0.48     0.90     NaN
# 6       SM01_micro010      SM01_micro002      9.40     1.47     NaN
#
#   Molecule ID
# 0        SM01
# 1        SM01
# 2        SM01
# 3        SM01
# 4        SM01
# 5        SM01
# 6        SM01
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM02
# df_pred_mol:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 7        SM02_micro002      SM02_micro011     13.21     0.73     NaN
# 8        SM02_micro003      SM02_micro011      5.90     0.86     NaN
# 9        SM02_micro004      SM02_micro002      4.05     1.47     NaN
# 10       SM02_micro004      SM02_micro007     11.01     2.22     NaN
# 11       SM02_micro005      SM02_micro002      3.51     0.86     NaN
# 12       SM02_micro005      SM02_micro003      7.42     2.00     NaN
# 13       SM02_micro007      SM02_micro011      5.09     1.47     NaN
# 14       SM02_micro012      SM02_micro005     -1.76     2.00     NaN
#
#    Molecule ID
# 7         SM02
# 8         SM02
# 9         SM02
# 10        SM02
# 11        SM02
# 12        SM02
# 13        SM02
# 14        SM02
# df_exp_mol:
#    Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 3      SM02_micro001       SM02_micro004        SM02       5.03
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 3           0.01  SM02_pKa1  Estimated based on SM07 NMR measurement
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM03
# df_pred_mol:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 15       SM03_micro001      SM03_micro004      8.58     2.22     NaN
# 16       SM03_micro001      SM03_micro012     -0.03     2.00     NaN
# 17       SM03_micro004      SM03_micro002      1.76     2.22     NaN
# 18       SM03_micro011      SM03_micro012     -2.64     0.90     NaN
# 19       SM03_micro012      SM03_micro002      7.12     2.22     NaN
# 20       SM03_micro013      SM03_micro002      4.95     2.22     NaN
# 21       SM03_micro016      SM03_micro012     -2.07     2.00     NaN
# 22       SM03_micro016      SM03_micro013      5.01     2.00     NaN
# 23       SM03_micro020      SM03_micro013      3.57     2.22     NaN
# 24       SM03_micro021      SM03_micro001     -0.05     2.00     NaN
#
#    Molecule ID
# 15        SM03
# 16        SM03
# 17        SM03
# 18        SM03
# 19        SM03
# 20        SM03
# 21        SM03
# 22        SM03
# 23        SM03
# 24        SM03
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM04
# df_pred_mol:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 25       SM04_micro002      SM04_micro003      5.60     1.13     NaN
# 26       SM04_micro002      SM04_micro004     11.40     2.22     NaN
# 27       SM04_micro003      SM04_micro005     13.77     0.73     NaN
# 28       SM04_micro004      SM04_micro005      5.14     1.47     NaN
# 29       SM04_micro006      SM04_micro003      3.88     2.22     NaN
# 30       SM04_micro006      SM04_micro009     11.03     2.22     NaN
# 31       SM04_micro008      SM04_micro003     -0.47     0.92     NaN
# 32       SM04_micro009      SM04_micro005      6.10     0.86     NaN
# 33       SM04_micro014      SM04_micro006     -2.23     2.00     NaN
#
#    Molecule ID
# 25        SM04
# 26        SM04
# 27        SM04
# 28        SM04
# 29        SM04
# 30        SM04
# 31        SM04
# 32        SM04
# 33        SM04
# df_exp_mol:
#    Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 4      SM04_micro003       SM04_micro002        SM04       6.02
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 4           0.01  SM04_pKa1  Estimated based on SM07 NMR measurement
# df_pKa_match:
#    microstate ID of A(exp) microstate ID of A(pred) microstate ID of HA(exp)  \
# 0           SM04_micro003            SM04_micro003            SM04_micro002
#
#   microstate ID of HA(pred)     pKa ID  pKa SEM(exp)  pKa SEM(pred)  \
# 0             SM04_micro002  SM04_pKa1          0.01           1.13
#
#    pKa mean(exp)  pKa mean(pred) Molecule ID
# 0           6.02             5.6        SM04
# mol_id:  SM05
# df_pred_mol:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 34       SM05_micro001      SM05_micro002     14.19     0.85     NaN
# 35       SM05_micro005      SM05_micro009      5.04     2.22     NaN
# 36       SM05_micro005      SM05_micro010      2.00     0.60     NaN
# 37       SM05_micro005      SM05_micro011     11.14     2.22     NaN
# 38       SM05_micro006      SM05_micro002      7.97     2.22     NaN
# 39       SM05_micro009      SM05_micro001      2.00     0.60     NaN
# 40       SM05_micro010      SM05_micro001      5.35     2.22     NaN
# 41       SM05_micro010      SM05_micro006     12.74     2.22     NaN
#
#    Molecule ID
# 34        SM05
# 35        SM05
# 36        SM05
# 37        SM05
# 38        SM05
# 39        SM05
# 40        SM05
# 41        SM05
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM06
# df_pred_mol:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 42       SM06_micro001      SM06_micro008     10.33     2.22     NaN
# 43       SM06_micro002      SM06_micro004      5.98     2.22     NaN
# 44       SM06_micro002      SM06_micro005      3.69     2.22     NaN
# 45       SM06_micro002      SM06_micro007      2.18     1.12     NaN
# 46       SM06_micro004      SM06_micro009      2.68     2.22     NaN
# 47       SM06_micro004      SM06_micro010      5.86     2.22     NaN
# 48       SM06_micro005      SM06_micro001      2.18     1.12     NaN
# 49       SM06_micro005      SM06_micro010      8.15     2.22     NaN
# 50       SM06_micro006      SM06_micro001      0.67     0.90     NaN
# 51       SM06_micro007      SM06_micro001      4.00     0.73     NaN
# 52       SM06_micro007      SM06_micro009      8.15     2.22     NaN
# 53       SM06_micro009      SM06_micro008      6.17     0.76     NaN
# 54       SM06_micro010      SM06_micro008      2.68     1.12     NaN
# 55       SM06_micro012      SM06_micro003      9.65     2.22     NaN
# 56       SM06_micro012      SM06_micro006      3.95     2.22     NaN
# 57       SM06_micro012      SM06_micro007      0.67     0.90     NaN
#
#    Molecule ID
# 42        SM06
# 43        SM06
# 44        SM06
# 45        SM06
# 46        SM06
# 47        SM06
# 48        SM06
# 49        SM06
# 50        SM06
# 51        SM06
# 52        SM06
# 53        SM06
# 54        SM06
# 55        SM06
# 56        SM06
# 57        SM06
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM07
# df_pred_mol:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 58       SM07_micro002      SM07_micro012      5.14     1.47     NaN
# 59       SM07_micro003      SM07_micro012      6.10     0.86     NaN
# 60       SM07_micro004      SM07_micro012     13.77     0.73     NaN
# 61       SM07_micro006      SM07_micro002     11.40     2.22     NaN
# 62       SM07_micro006      SM07_micro004      5.60     1.13     NaN
# 63       SM07_micro007      SM07_micro003     11.03     2.22     NaN
# 64       SM07_micro007      SM07_micro004      3.88     2.22     NaN
# 65       SM07_micro011      SM07_micro004     -0.47     0.92     NaN
# 66       SM07_micro014      SM07_micro007     -2.17     2.00     NaN
#
#    Molecule ID
# 58        SM07
# 59        SM07
# 60        SM07
# 61        SM07
# 62        SM07
# 63        SM07
# 64        SM07
# 65        SM07
# 66        SM07
# df_exp_mol:
#    Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 0      SM07_micro004       SM07_micro006        SM07       6.08
#
#    pKa SEM (exp)     pKa ID Microstate identification source
# 0           0.01  SM07_pKa1                  NMR measurement
# df_pKa_match:
#    microstate ID of A(exp) microstate ID of A(pred) microstate ID of HA(exp)  \
# 0           SM07_micro004            SM07_micro004            SM07_micro006
#
#   microstate ID of HA(pred)     pKa ID  pKa SEM(exp)  pKa SEM(pred)  \
# 0             SM07_micro006  SM07_pKa1          0.01           1.13
#
#    pKa mean(exp)  pKa mean(pred) Molecule ID
# 0           6.08             5.6        SM07
# mol_id:  SM08
# df_pred_mol:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 67       SM08_micro002      SM08_micro008      3.74     2.22     NaN
# 68       SM08_micro002      SM08_micro010      5.95     2.22     NaN
# 69       SM08_micro002      SM08_micro011      0.31     1.64     NaN
# 70       SM08_micro003      SM08_micro004      4.50     2.22     NaN
# 71       SM08_micro006      SM08_micro004     11.75     2.22     NaN
# 72       SM08_micro008      SM08_micro006      1.18     2.22     NaN
# 73       SM08_micro009      SM08_micro004      7.34     2.22     NaN
# 74       SM08_micro011      SM08_micro003     10.66     2.22     NaN
# 75       SM08_micro011      SM08_micro006      4.11     2.22     NaN
#
#    Molecule ID
# 67        SM08
# 68        SM08
# 69        SM08
# 70        SM08
# 71        SM08
# 72        SM08
# 73        SM08
# 74        SM08
# 75        SM08
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM09
# df_pred_mol:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 76       SM09_micro001      SM09_micro002     10.85     2.22     NaN
# 77       SM09_micro001      SM09_micro003      4.05     1.47     NaN
# 78       SM09_micro002      SM09_micro009      5.02     1.47     NaN
# 79       SM09_micro003      SM09_micro009     13.05     0.73     NaN
# 80       SM09_micro005      SM09_micro003      3.51     0.86     NaN
# 81       SM09_micro005      SM09_micro011      8.16     2.00     NaN
# 82       SM09_micro006      SM09_micro003     -2.43     0.92     NaN
# 83       SM09_micro008      SM09_micro001     -2.43     0.92     NaN
# 84       SM09_micro008      SM09_micro006     -1.51     2.00     NaN
# 85       SM09_micro011      SM09_micro009      5.74     0.86     NaN
# 86       SM09_micro013      SM09_micro005     -1.76     2.00     NaN
# 87       SM09_micro014      SM09_micro005     -2.43     0.92     NaN
#
#    Molecule ID
# 76        SM09
# 77        SM09
# 78        SM09
# 79        SM09
# 80        SM09
# 81        SM09
# 82        SM09
# 83        SM09
# 84        SM09
# 85        SM09
# 86        SM09
# 87        SM09
# df_exp_mol:
#    Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 5      SM09_micro003       SM09_micro001        SM09       5.37
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 5           0.01  SM09_pKa1  Estimated based on SM07 NMR measurement
# df_pKa_match:
#    microstate ID of A(exp) microstate ID of A(pred) microstate ID of HA(exp)  \
# 0           SM09_micro003            SM09_micro003            SM09_micro001
#
#   microstate ID of HA(pred)     pKa ID  pKa SEM(exp)  pKa SEM(pred)  \
# 0             SM09_micro001  SM09_pKa1          0.01           1.47
#
#    pKa mean(exp)  pKa mean(pred) Molecule ID
# 0           5.37            4.05        SM09
# mol_id:  SM10
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 88        SM10_micro003      SM10_micro036     -2.83     0.90     NaN
# 89        SM10_micro004      SM10_micro018      9.78     2.22     NaN
# 90        SM10_micro006      SM10_micro020     14.09     1.40     NaN
# 91        SM10_micro006      SM10_micro023      6.43     0.40     NaN
# 92        SM10_micro008      SM10_micro023     -1.16     0.90     NaN
# 93        SM10_micro020      SM10_micro018      7.21     0.40     NaN
# 94        SM10_micro023      SM10_micro018     14.13     1.40     NaN
# 95        SM10_micro024      SM10_micro006     -1.23     0.90     NaN
# 96        SM10_micro028      SM10_micro006     -0.59     2.00     NaN
# 97        SM10_micro028      SM10_micro036      1.84     2.22     NaN
# 98        SM10_micro032      SM10_micro036     -1.30     0.90     NaN
# 99        SM10_micro036      SM10_micro004     13.19     1.40     NaN
# 100       SM10_micro036      SM10_micro023      8.67     2.22     NaN
#
#     Molecule ID
# 88         SM10
# 89         SM10
# 90         SM10
# 91         SM10
# 92         SM10
# 93         SM10
# 94         SM10
# 95         SM10
# 96         SM10
# 97         SM10
# 98         SM10
# 99         SM10
# 100        SM10
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM11
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 101       SM11_micro005      SM11_micro007     13.11     0.73     NaN
# 102       SM11_micro008      SM11_micro005      3.87     2.00     NaN
# 103       SM11_micro008      SM11_micro028     10.02     2.00     NaN
# 104       SM11_micro009      SM11_micro005     -1.83     2.00     NaN
# 105       SM11_micro011      SM11_micro005      1.39     2.00     NaN
# 106       SM11_micro011      SM11_micro029     10.54     2.22     NaN
# 107       SM11_micro013      SM11_micro005     -2.41     0.92     NaN
# 108       SM11_micro021      SM11_micro011     -1.04     1.30     NaN
# 109       SM11_micro028      SM11_micro007      4.03     2.22     NaN
# 110       SM11_micro029      SM11_micro007      3.24     1.20     NaN
# 111       SM11_micro030      SM11_micro007      1.22     2.22     NaN
# 112       SM11_micro031      SM11_micro008     -0.88     1.30     NaN
# 113       SM11_micro031      SM11_micro009      3.16     2.22     NaN
#
#     Molecule ID
# 101        SM11
# 102        SM11
# 103        SM11
# 104        SM11
# 105        SM11
# 106        SM11
# 107        SM11
# 108        SM11
# 109        SM11
# 110        SM11
# 111        SM11
# 112        SM11
# 113        SM11
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM12
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 114       SM12_micro001      SM12_micro002      7.59     2.00     NaN
# 115       SM12_micro001      SM12_micro012      3.51     0.86     NaN
# 116       SM12_micro002      SM12_micro009      5.72     0.86     NaN
# 117       SM12_micro006      SM12_micro011     10.57     2.22     NaN
# 118       SM12_micro006      SM12_micro012      4.05     1.47     NaN
# 119       SM12_micro011      SM12_micro009      5.01     1.47     NaN
# 120       SM12_micro012      SM12_micro009     12.77     1.12     NaN
# 121       SM12_micro013      SM12_micro001     -1.76     2.00     NaN
#
#     Molecule ID
# 114        SM12
# 115        SM12
# 116        SM12
# 117        SM12
# 118        SM12
# 119        SM12
# 120        SM12
# 121        SM12
# df_exp_mol:
#    Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 6      SM12_micro012       SM12_micro006        SM12       5.28
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 6           0.01  SM12_pKa1  Estimated based on SM07 NMR measurement
# df_pKa_match:
#    microstate ID of A(exp) microstate ID of A(pred) microstate ID of HA(exp)  \
# 0           SM12_micro012            SM12_micro012            SM12_micro006
#
#   microstate ID of HA(pred)     pKa ID  pKa SEM(exp)  pKa SEM(pred)  \
# 0             SM12_micro006  SM12_pKa1          0.01           1.47
#
#    pKa mean(exp)  pKa mean(pred) Molecule ID
# 0           5.28            4.05        SM12
# mol_id:  SM13
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 122       SM13_micro001      SM13_micro005      4.27     2.22     NaN
# 123       SM13_micro001      SM13_micro009     10.91     2.22     NaN
# 124       SM13_micro003      SM13_micro001     -2.07     0.92     NaN
# 125       SM13_micro003      SM13_micro008     -1.29     2.00     NaN
# 126       SM13_micro005      SM13_micro004     13.11     0.73     NaN
# 127       SM13_micro007      SM13_micro004      6.34     2.22     NaN
# 128       SM13_micro008      SM13_micro005     -2.07     0.92     NaN
# 129       SM13_micro009      SM13_micro004      5.31     2.22     NaN
# 130       SM13_micro012      SM13_micro005      3.95     2.22     NaN
# 131       SM13_micro012      SM13_micro007      8.46     2.00     NaN
# 132       SM13_micro013      SM13_micro012     -1.40     2.00     NaN
# 133       SM13_micro014      SM13_micro012     -2.07     0.92     NaN
#
#     Molecule ID
# 122        SM13
# 123        SM13
# 124        SM13
# 125        SM13
# 126        SM13
# 127        SM13
# 128        SM13
# 129        SM13
# 130        SM13
# 131        SM13
# 132        SM13
# 133        SM13
# df_exp_mol:
#    Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 7      SM13_micro005       SM13_micro001        SM13       5.77
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 7           0.01  SM13_pKa1  Estimated based on SM07 NMR measurement
# df_pKa_match:
#    microstate ID of A(exp) microstate ID of A(pred) microstate ID of HA(exp)  \
# 0           SM13_micro005            SM13_micro005            SM13_micro001
#
#   microstate ID of HA(pred)     pKa ID  pKa SEM(exp)  pKa SEM(pred)  \
# 0             SM13_micro001  SM13_pKa1          0.01           2.22
#
#    pKa mean(exp)  pKa mean(pred) Molecule ID
# 0           5.77            4.27        SM13
# mol_id:  SM14
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 134       SM14_micro001      SM14_micro006     15.31     0.70     NaN
# 135       SM14_micro002      SM14_micro001      6.35     2.22     NaN
# 136       SM14_micro002      SM14_micro005     14.74     0.70     NaN
# 137       SM14_micro003      SM14_micro002      0.28     0.92     NaN
# 138       SM14_micro003      SM14_micro004      5.11     2.22     NaN
# 139       SM14_micro004      SM14_micro001      3.37     2.22     NaN
# 140       SM14_micro005      SM14_micro006      6.70     2.22     NaN
#
#     Molecule ID
# 134        SM14
# 135        SM14
# 136        SM14
# 137        SM14
# 138        SM14
# 139        SM14
# 140        SM14
# df_exp_mol:
#    Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 1      SM14_micro001       SM14_micro002        SM14       5.30
# 2      SM14_micro002       SM14_micro003        SM14       2.58
#
#    pKa SEM (exp)     pKa ID Microstate identification source
# 1           0.01  SM14_pKa2                  NMR measurement
# 2           0.01  SM14_pKa1                  NMR measurement
# df_pKa_match:
#    microstate ID of A(exp) microstate ID of A(pred) microstate ID of HA(exp)  \
# 0           SM14_micro001            SM14_micro001            SM14_micro002
# 1           SM14_micro002            SM14_micro002            SM14_micro003
#
#   microstate ID of HA(pred)     pKa ID  pKa SEM(exp)  pKa SEM(pred)  \
# 0             SM14_micro002  SM14_pKa2          0.01           2.22
# 1             SM14_micro003  SM14_pKa1          0.01           0.92
#
#    pKa mean(exp)  pKa mean(pred) Molecule ID
# 0           5.30            6.35        SM14
# 1           2.58            0.28        SM14
# mol_id:  SM15
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 141       SM15_micro001      SM15_micro004      5.74     1.12     NaN
# 142       SM15_micro002      SM15_micro004      8.71     1.06     NaN
# 143       SM15_micro003      SM15_micro001      8.54     1.47     NaN
# 144       SM15_micro003      SM15_micro002      5.82     2.22     NaN
#
#     Molecule ID
# 141        SM15
# 142        SM15
# 143        SM15
# 144        SM15
# df_exp_mol:
#    Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 8      SM15_micro004       SM15_micro002        SM15       8.94
# 9      SM15_micro002       SM15_micro003        SM15       4.70
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 8           0.01  SM15_pKa2  Estimated based on SM14 NMR measurement
# 9           0.01  SM15_pKa1  Estimated based on SM14 NMR measurement
# df_pKa_match:
#    microstate ID of A(exp) microstate ID of A(pred) microstate ID of HA(exp)  \
# 0           SM15_micro004            SM15_micro004            SM15_micro002
# 1           SM15_micro002            SM15_micro002            SM15_micro003
#
#   microstate ID of HA(pred)     pKa ID  pKa SEM(exp)  pKa SEM(pred)  \
# 0             SM15_micro002  SM15_pKa2          0.01           1.06
# 1             SM15_micro003  SM15_pKa1          0.01           2.22
#
#    pKa mean(exp)  pKa mean(pred) Molecule ID
# 0           8.94            8.71        SM15
# 1           4.70            5.82        SM15
# mol_id:  SM16
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 145       SM16_micro002      SM16_micro005      9.85     2.22     NaN
# 146       SM16_micro004      SM16_micro002      4.71     2.22     NaN
# 147       SM16_micro004      SM16_micro007      9.81     2.22     NaN
# 148       SM16_micro006      SM16_micro002     -0.63     0.90     NaN
# 149       SM16_micro007      SM16_micro005      7.67     0.94     NaN
#
#     Molecule ID
# 145        SM16
# 146        SM16
# 147        SM16
# 148        SM16
# 149        SM16
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM17
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 150       SM17_micro011      SM17_micro010       4.9     0.75     NaN
#
#     Molecule ID
# 150        SM17
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM18
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 151       SM18_micro002      SM18_micro005     10.50     2.22     NaN
# 152       SM18_micro002      SM18_micro071      7.94     2.22     NaN
# 153       SM18_micro004      SM18_micro002      2.48     2.22     NaN
# 154       SM18_micro004      SM18_micro025      3.32     2.00     NaN
# 155       SM18_micro004      SM18_micro069      7.93     2.22     NaN
# 156       SM18_micro005      SM18_micro049      8.03     2.22     NaN
# 157       SM18_micro016      SM18_micro065     10.50     2.22     NaN
# 158       SM18_micro016      SM18_micro071      9.38     2.22     NaN
# 159       SM18_micro025      SM18_micro005      7.03     0.40     NaN
# 160       SM18_micro025      SM18_micro032      8.02     2.22     NaN
# 161       SM18_micro026      SM18_micro004      2.29     2.22     NaN
# 162       SM18_micro026      SM18_micro034      2.48     2.22     NaN
# 163       SM18_micro026      SM18_micro056      1.37     2.22     NaN
# 164       SM18_micro026      SM18_micro063      3.32     2.00     NaN
# 165       SM18_micro028      SM18_micro071     -0.93     2.00     NaN
# 166       SM18_micro031      SM18_micro002     -2.13     1.50     NaN
# 167       SM18_micro032      SM18_micro049      7.23     0.40     NaN
# 168       SM18_micro033      SM18_micro049     -0.80     2.00     NaN
# 169       SM18_micro034      SM18_micro002      2.32     2.22     NaN
# 170       SM18_micro034      SM18_micro016      1.40     2.22     NaN
# 171       SM18_micro034      SM18_micro047     10.50     2.22     NaN
# 172       SM18_micro042      SM18_micro032      9.62     2.22     NaN
# 173       SM18_micro042      SM18_micro065      7.03     0.40     NaN
# 174       SM18_micro047      SM18_micro005      2.63     2.22     NaN
# 175       SM18_micro047      SM18_micro065      1.58     2.22     NaN
# 176       SM18_micro054      SM18_micro002     -0.22     0.90     NaN
# 177       SM18_micro056      SM18_micro016      2.48     2.22     NaN
# 178       SM18_micro056      SM18_micro042      3.32     2.00     NaN
# 179       SM18_micro056      SM18_micro069      9.36     2.22     NaN
# 180       SM18_micro057      SM18_micro032     -0.80     2.00     NaN
# 181       SM18_micro058      SM18_micro016     -0.22     0.90     NaN
# 182       SM18_micro060      SM18_micro071      0.19     0.90     NaN
# 183       SM18_micro063      SM18_micro025      2.61     2.22     NaN
# 184       SM18_micro063      SM18_micro042      1.56     2.22     NaN
# 185       SM18_micro063      SM18_micro047      7.03     0.40     NaN
# 186       SM18_micro065      SM18_micro049      9.64     2.22     NaN
# 187       SM18_micro069      SM18_micro032      3.68     2.00     NaN
# 188       SM18_micro069      SM18_micro071      2.70     2.22     NaN
# 189       SM18_micro071      SM18_micro049     10.77     2.22     NaN
# 190       SM18_micro074      SM18_micro016     -1.90     1.64     NaN
# 191       SM18_micro076      SM18_micro004     -2.14     1.50     NaN
#
#     Molecule ID
# 151        SM18
# 152        SM18
# 153        SM18
# 154        SM18
# 155        SM18
# 156        SM18
# 157        SM18
# 158        SM18
# 159        SM18
# 160        SM18
# 161        SM18
# 162        SM18
# 163        SM18
# 164        SM18
# 165        SM18
# 166        SM18
# 167        SM18
# 168        SM18
# 169        SM18
# 170        SM18
# 171        SM18
# 172        SM18
# 173        SM18
# 174        SM18
# 175        SM18
# 176        SM18
# 177        SM18
# 178        SM18
# 179        SM18
# 180        SM18
# 181        SM18
# 182        SM18
# 183        SM18
# 184        SM18
# 185        SM18
# 186        SM18
# 187        SM18
# 188        SM18
# 189        SM18
# 190        SM18
# 191        SM18
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM19
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 192       SM19_micro002      SM19_micro012      6.53     0.40     NaN
# 193       SM19_micro006      SM19_micro002      0.04     2.00     NaN
# 194       SM19_micro006      SM19_micro007      2.04     2.22     NaN
# 195       SM19_micro007      SM19_micro012      9.17     2.22     NaN
# 196       SM19_micro019      SM19_micro007     -0.75     0.90     NaN
#
#     Molecule ID
# 192        SM19
# 193        SM19
# 194        SM19
# 195        SM19
# 196        SM19
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM20
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 197       SM20_micro003      SM20_micro004      8.05     2.22     NaN
#
#     Molecule ID
# 197        SM20
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM21
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 198       SM21_micro001      SM21_micro014     10.48     2.22     NaN
# 199       SM21_micro001      SM21_micro018      8.37     2.00     NaN
# 200       SM21_micro001      SM21_micro020      3.89     2.22     NaN
# 201       SM21_micro003      SM21_micro005      2.55     2.22     NaN
# 202       SM21_micro005      SM21_micro021     13.01     0.73     NaN
# 203       SM21_micro006      SM21_micro012      4.59     2.22     NaN
# 204       SM21_micro012      SM21_micro021     15.15     2.00     NaN
# 205       SM21_micro014      SM21_micro012      5.08     2.22     NaN
# 206       SM21_micro015      SM21_micro021      4.16     2.22     NaN
# 207       SM21_micro018      SM21_micro005      3.71     2.22     NaN
# 208       SM21_micro020      SM21_micro005     14.75     2.00     NaN
# 209       SM21_micro020      SM21_micro012     12.68     2.22     NaN
# 210       SM21_micro024      SM21_micro003      8.37     2.00     NaN
# 211       SM21_micro024      SM21_micro006      8.02     2.00     NaN
# 212       SM21_micro024      SM21_micro020      2.07     2.22     NaN
# 213       SM21_micro025      SM21_micro021      4.47     2.22     NaN
#
#     Molecule ID
# 198        SM21
# 199        SM21
# 200        SM21
# 201        SM21
# 202        SM21
# 203        SM21
# 204        SM21
# 205        SM21
# 206        SM21
# 207        SM21
# 208        SM21
# 209        SM21
# 210        SM21
# 211        SM21
# 212        SM21
# 213        SM21
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM22
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 214       SM22_micro001      SM22_micro004      6.79     0.86     NaN
# 215       SM22_micro002      SM22_micro001      3.51     2.22     NaN
# 216       SM22_micro002      SM22_micro003      5.12     1.06     NaN
# 217       SM22_micro003      SM22_micro004      3.56     1.40     NaN
#
#     Molecule ID
# 214        SM22
# 215        SM22
# 216        SM22
# 217        SM22
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM23
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 218       SM23_micro005      SM23_micro034      7.22     0.75     NaN
# 219       SM23_micro007      SM23_micro011     11.14     2.22     NaN
# 220       SM23_micro007      SM23_micro012      5.99     0.75     NaN
# 221       SM23_micro007      SM23_micro020      8.48     2.00     NaN
# 222       SM23_micro011      SM23_micro034      7.29     0.75     NaN
# 223       SM23_micro012      SM23_micro034     13.34     0.73     NaN
# 224       SM23_micro012      SM23_micro035     14.87     2.00     NaN
# 225       SM23_micro020      SM23_micro035      5.35     2.22     NaN
# 226       SM23_micro021      SM23_micro012     -2.88     0.92     NaN
# 227       SM23_micro022      SM23_micro035      4.22     2.22     NaN
# 228       SM23_micro024      SM23_micro012     -2.09     0.92     NaN
# 229       SM23_micro025      SM23_micro005      7.98     2.00     NaN
# 230       SM23_micro025      SM23_micro012      4.57     0.75     NaN
# 231       SM23_micro025      SM23_micro022      8.48     2.00     NaN
#
#     Molecule ID
# 218        SM23
# 219        SM23
# 220        SM23
# 221        SM23
# 222        SM23
# 223        SM23
# 224        SM23
# 225        SM23
# 226        SM23
# 227        SM23
# 228        SM23
# 229        SM23
# 230        SM23
# 231        SM23
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []
# mol_id:  SM24
# df_pred_mol:
#      Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM  pKa ID  \
# 232       SM24_micro004      SM24_micro006      0.94     0.95     NaN
# 233       SM24_micro006      SM24_micro002     13.37     0.73     NaN
# 234       SM24_micro006      SM24_micro027     15.64     0.53     NaN
# 235       SM24_micro007      SM24_micro002      3.74     2.22     NaN
# 236       SM24_micro009      SM24_micro027      1.03     2.22     NaN
# 237       SM24_micro010      SM24_micro006      6.20     1.13     NaN
# 238       SM24_micro010      SM24_micro023     15.64     0.53     NaN
# 239       SM24_micro010      SM24_micro028     11.01     2.22     NaN
# 240       SM24_micro011      SM24_micro006      3.99     2.22     NaN
# 241       SM24_micro011      SM24_micro007     10.54     2.22     NaN
# 242       SM24_micro011      SM24_micro013     15.64     0.53     NaN
# 243       SM24_micro013      SM24_micro027      3.68     2.22     NaN
# 244       SM24_micro017      SM24_micro006     -1.15     0.92     NaN
# 245       SM24_micro022      SM24_micro004      3.75     2.22     NaN
# 246       SM24_micro022      SM24_micro011      0.94     0.95     NaN
# 247       SM24_micro022      SM24_micro014     10.99     2.22     NaN
# 248       SM24_micro023      SM24_micro027      5.86     1.13     NaN
# 249       SM24_micro024      SM24_micro002      1.37     0.59     NaN
# 250       SM24_micro025      SM24_micro004      5.92     1.13     NaN
# 251       SM24_micro025      SM24_micro005     11.37     2.22     NaN
# 252       SM24_micro025      SM24_micro010      0.94     0.95     NaN
# 253       SM24_micro028      SM24_micro002      3.69     2.22     NaN
#
#     Molecule ID
# 232        SM24
# 233        SM24
# 234        SM24
# 235        SM24
# 236        SM24
# 237        SM24
# 238        SM24
# 239        SM24
# 240        SM24
# 241        SM24
# 242        SM24
# 243        SM24
# 244        SM24
# 245        SM24
# 246        SM24
# 247        SM24
# 248        SM24
# 249        SM24
# 250        SM24
# 251        SM24
# 252        SM24
# 253        SM24
# df_exp_mol:
#  Empty DataFrame
# Columns: [Microstate ID of A, Microstate ID of HA, Molecule ID, pKa (exp), pKa SEM (exp), pKa ID, Microstate identification source]
# Index: []
# df_pKa_match:
#  Empty DataFrame
# Columns: [Molecule ID]
# Index: []

# %%
df_pred_matched
# Out:
#   Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM     pKa ID  \
# 0       SM04_micro002      SM04_micro003      5.60     1.13  SM04_pKa1
# 2       SM09_micro001      SM09_micro003      4.05     1.47  SM09_pKa1
# 4       SM13_micro001      SM13_micro005      4.27     2.22  SM13_pKa1
# 5       SM14_micro002      SM14_micro001      6.35     2.22  SM14_pKa2
# 6       SM14_micro003      SM14_micro002      0.28     0.92  SM14_pKa1
# 7       SM15_micro002      SM15_micro004      8.71     1.06  SM15_pKa2
# 8       SM15_micro003      SM15_micro002      5.82     2.22  SM15_pKa1
#
#   Molecule ID
# 0        SM04
# 2        SM09
# 4        SM13
# 5        SM14
# 6        SM14
# 7        SM15
# 8        SM15

# %%
df_pred_unmatched
# Out:
#     Microstate ID of HA Microstate ID of A  pKa mean  pKa SEM pKa ID  \
# 0         SM01_micro001      SM01_micro005     -0.48     0.90    NaN
# 1         SM01_micro001      SM01_micro006      9.60     1.12    NaN
# 2         SM01_micro004      SM01_micro002     13.29     2.00    NaN
# 3         SM01_micro005      SM01_micro004      9.12     1.12    NaN
# 4         SM01_micro005      SM01_micro010     12.93     2.00    NaN
# 5         SM01_micro006      SM01_micro004     -0.48     0.90    NaN
# 6         SM01_micro010      SM01_micro002      9.40     1.47    NaN
# 7         SM02_micro002      SM02_micro011     13.21     0.73    NaN
# 8         SM02_micro003      SM02_micro011      5.90     0.86    NaN
# 9         SM02_micro004      SM02_micro002      4.05     1.47    NaN
# 10        SM02_micro004      SM02_micro007     11.01     2.22    NaN
# 11        SM02_micro005      SM02_micro002      3.51     0.86    NaN
# 12        SM02_micro005      SM02_micro003      7.42     2.00    NaN
# 13        SM02_micro007      SM02_micro011      5.09     1.47    NaN
# 14        SM02_micro012      SM02_micro005     -1.76     2.00    NaN
# 15        SM03_micro001      SM03_micro004      8.58     2.22    NaN
# 16        SM03_micro001      SM03_micro012     -0.03     2.00    NaN
# 17        SM03_micro004      SM03_micro002      1.76     2.22    NaN
# 18        SM03_micro011      SM03_micro012     -2.64     0.90    NaN
# 19        SM03_micro012      SM03_micro002      7.12     2.22    NaN
# 20        SM03_micro013      SM03_micro002      4.95     2.22    NaN
# 21        SM03_micro016      SM03_micro012     -2.07     2.00    NaN
# 22        SM03_micro016      SM03_micro013      5.01     2.00    NaN
# 23        SM03_micro020      SM03_micro013      3.57     2.22    NaN
# 24        SM03_micro021      SM03_micro001     -0.05     2.00    NaN
# 26        SM04_micro002      SM04_micro004     11.40     2.22    NaN
# 27        SM04_micro003      SM04_micro005     13.77     0.73    NaN
# 28        SM04_micro004      SM04_micro005      5.14     1.47    NaN
# 29        SM04_micro006      SM04_micro003      3.88     2.22    NaN
# 30        SM04_micro006      SM04_micro009     11.03     2.22    NaN
# ..                  ...                ...       ...      ...    ...
# 224       SM23_micro012      SM23_micro035     14.87     2.00    NaN
# 225       SM23_micro020      SM23_micro035      5.35     2.22    NaN
# 226       SM23_micro021      SM23_micro012     -2.88     0.92    NaN
# 227       SM23_micro022      SM23_micro035      4.22     2.22    NaN
# 228       SM23_micro024      SM23_micro012     -2.09     0.92    NaN
# 229       SM23_micro025      SM23_micro005      7.98     2.00    NaN
# 230       SM23_micro025      SM23_micro012      4.57     0.75    NaN
# 231       SM23_micro025      SM23_micro022      8.48     2.00    NaN
# 232       SM24_micro004      SM24_micro006      0.94     0.95    NaN
# 233       SM24_micro006      SM24_micro002     13.37     0.73    NaN
# 234       SM24_micro006      SM24_micro027     15.64     0.53    NaN
# 235       SM24_micro007      SM24_micro002      3.74     2.22    NaN
# 236       SM24_micro009      SM24_micro027      1.03     2.22    NaN
# 237       SM24_micro010      SM24_micro006      6.20     1.13    NaN
# 238       SM24_micro010      SM24_micro023     15.64     0.53    NaN
# 239       SM24_micro010      SM24_micro028     11.01     2.22    NaN
# 240       SM24_micro011      SM24_micro006      3.99     2.22    NaN
# 241       SM24_micro011      SM24_micro007     10.54     2.22    NaN
# 242       SM24_micro011      SM24_micro013     15.64     0.53    NaN
# 243       SM24_micro013      SM24_micro027      3.68     2.22    NaN
# 244       SM24_micro017      SM24_micro006     -1.15     0.92    NaN
# 245       SM24_micro022      SM24_micro004      3.75     2.22    NaN
# 246       SM24_micro022      SM24_micro011      0.94     0.95    NaN
# 247       SM24_micro022      SM24_micro014     10.99     2.22    NaN
# 248       SM24_micro023      SM24_micro027      5.86     1.13    NaN
# 249       SM24_micro024      SM24_micro002      1.37     0.59    NaN
# 250       SM24_micro025      SM24_micro004      5.92     1.13    NaN
# 251       SM24_micro025      SM24_micro005     11.37     2.22    NaN
# 252       SM24_micro025      SM24_micro010      0.94     0.95    NaN
# 253       SM24_micro028      SM24_micro002      3.69     2.22    NaN
#
#     Molecule ID
# 0          SM01
# 1          SM01
# 2          SM01
# 3          SM01
# 4          SM01
# 5          SM01
# 6          SM01
# 7          SM02
# 8          SM02
# 9          SM02
# 10         SM02
# 11         SM02
# 12         SM02
# 13         SM02
# 14         SM02
# 15         SM03
# 16         SM03
# 17         SM03
# 18         SM03
# 19         SM03
# 20         SM03
# 21         SM03
# 22         SM03
# 23         SM03
# 24         SM03
# 26         SM04
# 27         SM04
# 28         SM04
# 29         SM04
# 30         SM04
# ..          ...
# 224        SM23
# 225        SM23
# 226        SM23
# 227        SM23
# 228        SM23
# 229        SM23
# 230        SM23
# 231        SM23
# 232        SM24
# 233        SM24
# 234        SM24
# 235        SM24
# 236        SM24
# 237        SM24
# 238        SM24
# 239        SM24
# 240        SM24
# 241        SM24
# 242        SM24
# 243        SM24
# 244        SM24
# 245        SM24
# 246        SM24
# 247        SM24
# 248        SM24
# 249        SM24
# 250        SM24
# 251        SM24
# 252        SM24
# 253        SM24
#
# [245 rows x 6 columns]
