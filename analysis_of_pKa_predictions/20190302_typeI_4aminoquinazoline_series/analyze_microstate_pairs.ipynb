# %%
import pandas as pd
import numpy as np

# %%
df_exp = pd.read_csv("experimental_microstates.csv")
df_exp
# Out:
#   Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 0      SM07_micro004       SM07_micro006        SM07       6.08
# 1      SM14_micro001       SM14_micro002        SM14       5.30
# 2      SM14_micro002       SM14_micro003        SM14       2.58
# 3      SM02_micro001       SM02_micro004        SM02       5.03
# 4      SM04_micro003       SM04_micro002        SM04       6.02
# 5      SM09_micro003       SM09_micro001        SM09       5.37
# 6      SM12_micro012       SM12_micro006        SM12       5.28
# 7      SM13_micro005       SM13_micro001        SM13       5.77
# 8      SM15_micro004       SM15_micro002        SM15       8.94
# 9      SM15_micro002       SM15_micro003        SM15       4.70
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 0           0.01  SM07_pKa1                          NMR measurement
# 1           0.01  SM14_pKa2                          NMR measurement
# 2           0.01  SM14_pKa1                          NMR measurement
# 3           0.01  SM02_pKa1  Estimated based on SM07 NMR measurement
# 4           0.01  SM04_pKa1  Estimated based on SM07 NMR measurement
# 5           0.01  SM09_pKa1  Estimated based on SM07 NMR measurement
# 6           0.01  SM12_pKa1  Estimated based on SM07 NMR measurement
# 7           0.01  SM13_pKa1  Estimated based on SM07 NMR measurement
# 8           0.01  SM15_pKa2  Estimated based on SM14 NMR measurement
# 9           0.01  SM15_pKa1  Estimated based on SM14 NMR measurement

# %%
df_col = pd.read_csv("typeI_submission_collection.csv")
df_col.head()
# Out:
#    Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 0           0                            0.97      SM01_micro002
# 1           1                            3.65      SM02_micro011
# 2           2                            1.79      SM03_micro014
# 3           3                           -0.79      SM04_micro004
# 4           4                           -3.28      SM05_micro001
#
#   Microstate ID of HA Molecule ID                           name  pKa (calc)  \
# 0       SM01_micro010        SM01  Explicit solvent submission 1       10.50
# 1       SM02_micro002        SM02  Explicit solvent submission 1        8.68
# 2       SM03_micro010        SM03  Explicit solvent submission 1        8.81
# 3       SM04_micro002        SM04  Explicit solvent submission 1        5.23
# 4       SM05_micro009        SM05  Explicit solvent submission 1        1.31
#
#    pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)       participant  \
# 0       9.53  SM01_pKa1             NaN           0.01  Samarjeet Prasad
# 1       5.03  SM02_pKa1             NaN           0.01  Samarjeet Prasad
# 2       7.02  SM03_pKa1             NaN           0.01  Samarjeet Prasad
# 3       6.02  SM04_pKa1             NaN           0.01  Samarjeet Prasad
# 4       4.59  SM05_pKa1             NaN           0.01  Samarjeet Prasad
#
#   receipt_id
# 0      0wfzo
# 1      0wfzo
# 2      0wfzo
# 3      0wfzo
# 4      0wfzo

# %%
df_exp_microstates = df_exp.rename(columns={'Microstate ID of A': 'Exp. Microstate ID of A', 'Microstate ID of HA': 'Exp. Microstate ID of HA'})
df_exp_microstates = df_exp_microstates.drop(columns=['Molecule ID', "pKa (exp)", 'pKa SEM (exp)'])
df_exp_microstates
# Out:
#   Exp. Microstate ID of A Exp. Microstate ID of HA     pKa ID  \
# 0           SM07_micro004            SM07_micro006  SM07_pKa1
# 1           SM14_micro001            SM14_micro002  SM14_pKa2
# 2           SM14_micro002            SM14_micro003  SM14_pKa1
# 3           SM02_micro001            SM02_micro004  SM02_pKa1
# 4           SM04_micro003            SM04_micro002  SM04_pKa1
# 5           SM09_micro003            SM09_micro001  SM09_pKa1
# 6           SM12_micro012            SM12_micro006  SM12_pKa1
# 7           SM13_micro005            SM13_micro001  SM13_pKa1
# 8           SM15_micro004            SM15_micro002  SM15_pKa2
# 9           SM15_micro002            SM15_micro003  SM15_pKa1
#
#           Microstate identification source
# 0                          NMR measurement
# 1                          NMR measurement
# 2                          NMR measurement
# 3  Estimated based on SM07 NMR measurement
# 4  Estimated based on SM07 NMR measurement
# 5  Estimated based on SM07 NMR measurement
# 6  Estimated based on SM07 NMR measurement
# 7  Estimated based on SM07 NMR measurement
# 8  Estimated based on SM14 NMR measurement
# 9  Estimated based on SM14 NMR measurement

# %% [markdown]
# 1. Add experimental microstates to collection
# 2. Drop entries of molecules with unknown experimental microstate
# 3. check for matches and give a score

# %%
df_col_ms = pd.merge(df_col, df_exp_microstates, on="pKa ID", how="outer" )
# Drop rows whose "Exp. Microstate ID of A" column has NaN value
df_col_ms = df_col_ms.dropna(subset=["Exp. Microstate ID of A"])
df_col_ms = df_col_ms.reset_index()
df_col_ms = df_col_ms.drop(columns=['index'])
df_col_ms
# Out:
#      Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 0           1.0                            3.65      SM02_micro011
# 1          31.0                           -1.02      SM02_micro002
# 2          61.0                           -0.62      SM02_micro003
# 3          91.0                           -0.62      SM02_micro003
# 4         122.0                            0.29      SM02_micro002
# 5         151.0                           -2.20      SM02_micro011
# 6         181.0                           -1.01      SM02_micro003
# 7         211.0                           -0.34      SM02_micro003
# 8         243.0                            1.23      SM02_micro002
# 9         273.0                           -0.63      SM02_micro003
# 10        303.0                           -0.86      SM02_micro002
# 11        334.0                           -0.57      SM02_micro003
# 12        363.0                            1.24      SM02_micro002
# 13        394.0                            0.68      SM02_micro002
# 14        424.0                           -0.37      SM02_micro011
# 15        454.0                           -0.50      SM02_micro002
# 16        484.0                           -6.80      SM02_micro011
# 17        512.0                           -0.75      SM02_micro003
# 18        543.0                           -0.33      SM02_micro003
# 19        573.0                           -0.84      SM02_micro003
# 20        604.0                            0.81      SM02_micro002
# 21        640.0                            1.18      SM02_micro002
# 22        665.0                            0.04      SM02_micro002
# 23        694.0                           -1.60      SM02_micro002
# 24        725.0                           -1.21      SM02_micro003
# 25        755.0                           -1.08      SM02_micro002
# 26        785.0                           -0.35      SM02_micro003
# 27        816.0                           -0.38      SM02_micro003
# 28        846.0                            1.18      SM02_micro002
# 29        877.0                           -0.95      SM02_micro011
# ..          ...                             ...                ...
# 220       107.0                           -0.18      SM15_micro004
# 221       136.0                            0.73      SM15_micro002
# 222       166.0                            1.74      SM15_micro004
# 223       197.0                           -0.22      SM15_micro004
# 224       226.0                           -1.64      SM15_micro002
# 225       258.0                           -0.26      SM15_micro002
# 226       289.0                            0.04      SM15_micro004
# 227       318.0                            0.56      SM15_micro002
# 228       349.0                           -0.26      SM15_micro004
# 229       378.0                           -0.26      SM15_micro002
# 230       410.0                            0.54      SM15_micro002
# 231       440.0                            1.00      SM15_micro004
# 232       470.0                           -0.11      SM15_micro004
# 233       498.0                           -2.86      SM15_micro004
# 234       527.0                           -1.93      SM15_micro002
# 235       559.0                            0.07      SM15_micro004
# 236       588.0                            0.07      SM15_micro004
# 237       619.0                            0.68      SM15_micro002
# 238       634.0                            0.54      SM15_micro004
# 239       654.0                           -0.18      SM15_micro002
# 240       709.0                           -2.45      SM15_micro004
# 241       739.0                           -2.08      SM15_micro002
# 242       770.0                           -2.13      SM15_micro002
# 243       801.0                            0.04      SM15_micro004
# 244       832.0                           -0.06      SM15_micro004
# 245       861.0                           -0.40      SM15_micro004
# 246       893.0                          -13.46      SM15_micro002
# 247       923.0                           -0.19      SM15_micro004
# 248         NaN                             NaN                NaN
# 249         NaN                             NaN                NaN
#
#     Microstate ID of HA Molecule ID  \
# 0         SM02_micro002        SM02
# 1         SM02_micro005        SM02
# 2         SM02_micro005        SM02
# 3         SM02_micro005        SM02
# 4         SM02_micro004        SM02
# 5         SM02_micro002        SM02
# 6         SM02_micro005        SM02
# 7         SM02_micro005        SM02
# 8         SM02_micro004        SM02
# 9         SM02_micro005        SM02
# 10        SM02_micro005        SM02
# 11        SM02_micro005        SM02
# 12        SM02_micro004        SM02
# 13        SM02_micro004        SM02
# 14        SM02_micro003        SM02
# 15        SM02_micro004        SM02
# 16        SM02_micro002        SM02
# 17        SM02_micro005        SM02
# 18        SM02_micro005        SM02
# 19        SM02_micro005        SM02
# 20        SM02_micro004        SM02
# 21        SM02_micro004        SM02
# 22        SM02_micro004        SM02
# 23        SM02_micro004        SM02
# 24        SM02_micro005        SM02
# 25        SM02_micro004        SM02
# 26        SM02_micro005        SM02
# 27        SM02_micro005        SM02
# 28        SM02_micro004        SM02
# 29        SM02_micro002        SM02
# ..                  ...         ...
# 220       SM15_micro001        SM15
# 221       SM15_micro003        SM15
# 222       SM15_micro002        SM15
# 223       SM15_micro001        SM15
# 224       SM15_micro003        SM15
# 225       SM15_micro003        SM15
# 226       SM15_micro001        SM15
# 227       SM15_micro003        SM15
# 228       SM15_micro001        SM15
# 229       SM15_micro003        SM15
# 230       SM15_micro003        SM15
# 231       SM15_micro002        SM15
# 232       SM15_micro001        SM15
# 233       SM15_micro002        SM15
# 234       SM15_micro003        SM15
# 235       SM15_micro001        SM15
# 236       SM15_micro001        SM15
# 237       SM15_micro003        SM15
# 238       SM15_micro001        SM15
# 239       SM15_micro003        SM15
# 240       SM15_micro001        SM15
# 241       SM15_micro003        SM15
# 242       SM15_micro003        SM15
# 243       SM15_micro001        SM15
# 244       SM15_micro001        SM15
# 245       SM15_micro001        SM15
# 246       SM15_micro003        SM15
# 247       SM15_micro001        SM15
# 248                 NaN         NaN
# 249                 NaN         NaN
#
#                                                   name  pKa (calc)  pKa (exp)  \
# 0                        Explicit solvent submission 1        8.68       5.03
# 1    EC-RISM/B3LYP/6-311+G(d,p)-P3NI-phi-noThiols-2par        4.01       5.03
# 2           EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-2par        4.41       5.03
# 3           EC-RISM/MP2/cc-pVTZ-P3NI-phi-noThiols-2par        4.41       5.03
# 4                                  OE Gaussian Process        5.32       5.03
# 5                        Explicit solvent submission 3        2.83       5.03
# 6           EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        4.02       5.03
# 7                Vertical scheme for type I submission        4.69       5.03
# 8              ReSCoSS conformations // COSMOtherm pKa        6.26       5.03
# 9      EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-noThiols-2par        4.40       5.03
# 10     EC-RISM/B3LYP/6-311+G(d,p)-P2-phi-noThiols-2par        4.17       5.03
# 11            EC-RISM/MP2/cc-pVTZ-P2-phi-noThiols-2par        4.46       5.03
# 12   ReSCoSS conformations // DSD-BLYP-D3 reranking...        6.27       5.03
# 13              EC-RISM/MP2/cc-pVTZ-P2-q-noThiols-2par        5.71       5.03
# 14                              PCM/B3LYP/6-311+G(d,p)        4.66       5.03
# 15                                               S+pKa        4.53       5.03
# 16                       Explicit solvent submission 4       -1.77       5.03
# 17   Adiabatic scheme with single point correction ...        4.28       5.03
# 18            EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-2par        4.70       5.03
# 19       EC-RISM/MP2/6-311+G(d,p)-P3NI-q-noThiols-2par        4.19       5.03
# 20     EC-RISM/B3LYP/6-311+G(d,p)-P3NI-q-noThiols-2par        5.84       5.03
# 21                                   COSMOlogic_FINE17        6.21       5.03
# 22                                       ACD/pKa GALAS        5.07       5.03
# 23   Direct scheme with single point correction for...        3.43       5.03
# 24              Adiabatic scheme for type I submission        3.82       5.03
# 25                 Direct scheme for type I submission        3.95       5.03
# 26       EC-RISM/MP2/6-311+G(d,p)-P2-phi-noThiols-2par        4.68       5.03
# 27                 EC-RISM/MP2/cc-pVTZ-P2-phi-all-2par        4.65       5.03
# 28   microscopic pKa prediction with Gaussian and g...        6.21       5.03
# 29                       Explicit solvent submission 2        4.08       5.03
# ..                                                 ...         ...        ...
# 220         EC-RISM/MP2/cc-pVTZ-P3NI-phi-noThiols-2par        4.52       4.70
# 221                                OE Gaussian Process        5.43       4.70
# 222                      Explicit solvent submission 3        6.44       4.70
# 223         EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        4.48       4.70
# 224              Vertical scheme for type I submission        3.06       4.70
# 225            ReSCoSS conformations // COSMOtherm pKa        4.44       4.70
# 226    EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-noThiols-2par        4.74       4.70
# 227    EC-RISM/B3LYP/6-311+G(d,p)-P2-phi-noThiols-2par        5.26       4.70
# 228           EC-RISM/MP2/cc-pVTZ-P2-phi-noThiols-2par        4.44       4.70
# 229  ReSCoSS conformations // DSD-BLYP-D3 reranking...        4.44       4.70
# 230             EC-RISM/MP2/cc-pVTZ-P2-q-noThiols-2par        5.24       4.70
# 231                             PCM/B3LYP/6-311+G(d,p)        5.70       4.70
# 232                                              S+pKa        4.59       4.70
# 233                      Explicit solvent submission 4        1.84       4.70
# 234  Adiabatic scheme with single point correction ...        2.77       4.70
# 235           EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-2par        4.77       4.70
# 236      EC-RISM/MP2/6-311+G(d,p)-P3NI-q-noThiols-2par        4.77       4.70
# 237    EC-RISM/B3LYP/6-311+G(d,p)-P3NI-q-noThiols-2par        5.38       4.70
# 238  microscopic pKa prediction with Gaussian and s...        5.24       4.70
# 239                                  COSMOlogic_FINE17        4.52       4.70
# 240  Direct scheme with single point correction for...        2.25       4.70
# 241             Adiabatic scheme for type I submission        2.62       4.70
# 242                Direct scheme for type I submission        2.57       4.70
# 243      EC-RISM/MP2/6-311+G(d,p)-P2-phi-noThiols-2par        4.74       4.70
# 244                EC-RISM/MP2/cc-pVTZ-P2-phi-all-2par        4.64       4.70
# 245  microscopic pKa prediction with Gaussian and g...        4.30       4.70
# 246                      Explicit solvent submission 2       -8.76       4.70
# 247           EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-1par        4.51       4.70
# 248                                                NaN         NaN        NaN
# 249                                                NaN         NaN        NaN
#
#         pKa ID  pKa SEM (calc)  pKa SEM (exp)          participant receipt_id  \
# 0    SM02_pKa1             NaN           0.01     Samarjeet Prasad      0wfzo
# 1    SM02_pKa1            1.77           0.01          Stefan Kast      0xi4b
# 2    SM02_pKa1            1.77           0.01          Stefan Kast      2umai
# 3    SM02_pKa1            1.77           0.01          Stefan Kast      4o0ia
# 4    SM02_pKa1            1.28           0.01       Caitlin Bannan      6tvf8
# 5    SM02_pKa1             NaN           0.01     Samarjeet Prasad      758j8
# 6    SM02_pKa1            1.77           0.01          Stefan Kast      8toyp
# 7    SM02_pKa1             NaN           0.01            Qiao Zeng      arcko
# 8    SM02_pKa1             NaN           0.01       Rainer Wilcken      ccpmw
# 9    SM02_pKa1            1.77           0.01          Stefan Kast      cm2yq
# 10   SM02_pKa1            1.77           0.01          Stefan Kast      cywyk
# 11   SM02_pKa1            1.77           0.01          Stefan Kast      epvmk
# 12   SM02_pKa1             NaN           0.01       Rainer Wilcken      eyetm
# 13   SM02_pKa1            1.77           0.01          Stefan Kast      ftc8w
# 14   SM02_pKa1            2.58           0.01          Stefan Kast      gdqeg
# 15   SM02_pKa1             NaN           0.01  Robert Fraczkiewicz      hdiyq
# 16   SM02_pKa1             NaN           0.01     Samarjeet Prasad      hgn83
# 17   SM02_pKa1             NaN           0.01            Qiao Zeng      ko8yx
# 18   SM02_pKa1            1.77           0.01          Stefan Kast      ktpj5
# 19   SM02_pKa1            1.77           0.01          Stefan Kast      kxztt
# 20   SM02_pKa1            1.77           0.01          Stefan Kast      nxaaw
# 21   SM02_pKa1            0.65           0.01        Chris Loschen      t8ewk
# 22   SM02_pKa1             NaN           0.01      Kiril Lanevskij      v8qph
# 23   SM02_pKa1             NaN           0.01            Qiao Zeng      w4z0e
# 24   SM02_pKa1             NaN           0.01            Qiao Zeng      wcvnu
# 25   SM02_pKa1             NaN           0.01            Qiao Zeng      wexjs
# 26   SM02_pKa1            1.77           0.01          Stefan Kast      wuuvc
# 27   SM02_pKa1            1.77           0.01          Stefan Kast      xnoe0
# 28   SM02_pKa1             NaN           0.01         Bogdan Iorga      y4wws
# 29   SM02_pKa1             NaN           0.01     Samarjeet Prasad      z3btx
# ..         ...             ...            ...                  ...        ...
# 220  SM15_pKa1            1.77           0.01          Stefan Kast      4o0ia
# 221  SM15_pKa1            0.45           0.01       Caitlin Bannan      6tvf8
# 222  SM15_pKa1             NaN           0.01     Samarjeet Prasad      758j8
# 223  SM15_pKa1            1.77           0.01          Stefan Kast      8toyp
# 224  SM15_pKa1             NaN           0.01            Qiao Zeng      arcko
# 225  SM15_pKa1             NaN           0.01       Rainer Wilcken      ccpmw
# 226  SM15_pKa1            1.77           0.01          Stefan Kast      cm2yq
# 227  SM15_pKa1            1.77           0.01          Stefan Kast      cywyk
# 228  SM15_pKa1            1.77           0.01          Stefan Kast      epvmk
# 229  SM15_pKa1             NaN           0.01       Rainer Wilcken      eyetm
# 230  SM15_pKa1            1.77           0.01          Stefan Kast      ftc8w
# 231  SM15_pKa1            2.58           0.01          Stefan Kast      gdqeg
# 232  SM15_pKa1             NaN           0.01  Robert Fraczkiewicz      hdiyq
# 233  SM15_pKa1             NaN           0.01     Samarjeet Prasad      hgn83
# 234  SM15_pKa1             NaN           0.01            Qiao Zeng      ko8yx
# 235  SM15_pKa1            1.77           0.01          Stefan Kast      ktpj5
# 236  SM15_pKa1            1.77           0.01          Stefan Kast      kxztt
# 237  SM15_pKa1            1.77           0.01          Stefan Kast      nxaaw
# 238  SM15_pKa1             NaN           0.01         Bogdan Iorga      qsicn
# 239  SM15_pKa1            0.65           0.01        Chris Loschen      t8ewk
# 240  SM15_pKa1             NaN           0.01            Qiao Zeng      w4z0e
# 241  SM15_pKa1             NaN           0.01            Qiao Zeng      wcvnu
# 242  SM15_pKa1             NaN           0.01            Qiao Zeng      wexjs
# 243  SM15_pKa1            1.77           0.01          Stefan Kast      wuuvc
# 244  SM15_pKa1            1.77           0.01          Stefan Kast      xnoe0
# 245  SM15_pKa1             NaN           0.01         Bogdan Iorga      y4wws
# 246  SM15_pKa1             NaN           0.01     Samarjeet Prasad      z3btx
# 247  SM15_pKa1            1.77           0.01          Stefan Kast      z7fhp
# 248  SM14_pKa2             NaN            NaN                  NaN        NaN
# 249  SM14_pKa1             NaN            NaN                  NaN        NaN
#
#     Exp. Microstate ID of A Exp. Microstate ID of HA  \
# 0             SM02_micro001            SM02_micro004
# 1             SM02_micro001            SM02_micro004
# 2             SM02_micro001            SM02_micro004
# 3             SM02_micro001            SM02_micro004
# 4             SM02_micro001            SM02_micro004
# 5             SM02_micro001            SM02_micro004
# 6             SM02_micro001            SM02_micro004
# 7             SM02_micro001            SM02_micro004
# 8             SM02_micro001            SM02_micro004
# 9             SM02_micro001            SM02_micro004
# 10            SM02_micro001            SM02_micro004
# 11            SM02_micro001            SM02_micro004
# 12            SM02_micro001            SM02_micro004
# 13            SM02_micro001            SM02_micro004
# 14            SM02_micro001            SM02_micro004
# 15            SM02_micro001            SM02_micro004
# 16            SM02_micro001            SM02_micro004
# 17            SM02_micro001            SM02_micro004
# 18            SM02_micro001            SM02_micro004
# 19            SM02_micro001            SM02_micro004
# 20            SM02_micro001            SM02_micro004
# 21            SM02_micro001            SM02_micro004
# 22            SM02_micro001            SM02_micro004
# 23            SM02_micro001            SM02_micro004
# 24            SM02_micro001            SM02_micro004
# 25            SM02_micro001            SM02_micro004
# 26            SM02_micro001            SM02_micro004
# 27            SM02_micro001            SM02_micro004
# 28            SM02_micro001            SM02_micro004
# 29            SM02_micro001            SM02_micro004
# ..                      ...                      ...
# 220           SM15_micro002            SM15_micro003
# 221           SM15_micro002            SM15_micro003
# 222           SM15_micro002            SM15_micro003
# 223           SM15_micro002            SM15_micro003
# 224           SM15_micro002            SM15_micro003
# 225           SM15_micro002            SM15_micro003
# 226           SM15_micro002            SM15_micro003
# 227           SM15_micro002            SM15_micro003
# 228           SM15_micro002            SM15_micro003
# 229           SM15_micro002            SM15_micro003
# 230           SM15_micro002            SM15_micro003
# 231           SM15_micro002            SM15_micro003
# 232           SM15_micro002            SM15_micro003
# 233           SM15_micro002            SM15_micro003
# 234           SM15_micro002            SM15_micro003
# 235           SM15_micro002            SM15_micro003
# 236           SM15_micro002            SM15_micro003
# 237           SM15_micro002            SM15_micro003
# 238           SM15_micro002            SM15_micro003
# 239           SM15_micro002            SM15_micro003
# 240           SM15_micro002            SM15_micro003
# 241           SM15_micro002            SM15_micro003
# 242           SM15_micro002            SM15_micro003
# 243           SM15_micro002            SM15_micro003
# 244           SM15_micro002            SM15_micro003
# 245           SM15_micro002            SM15_micro003
# 246           SM15_micro002            SM15_micro003
# 247           SM15_micro002            SM15_micro003
# 248           SM14_micro001            SM14_micro002
# 249           SM14_micro002            SM14_micro003
#
#             Microstate identification source
# 0    Estimated based on SM07 NMR measurement
# 1    Estimated based on SM07 NMR measurement
# 2    Estimated based on SM07 NMR measurement
# 3    Estimated based on SM07 NMR measurement
# 4    Estimated based on SM07 NMR measurement
# 5    Estimated based on SM07 NMR measurement
# 6    Estimated based on SM07 NMR measurement
# 7    Estimated based on SM07 NMR measurement
# 8    Estimated based on SM07 NMR measurement
# 9    Estimated based on SM07 NMR measurement
# 10   Estimated based on SM07 NMR measurement
# 11   Estimated based on SM07 NMR measurement
# 12   Estimated based on SM07 NMR measurement
# 13   Estimated based on SM07 NMR measurement
# 14   Estimated based on SM07 NMR measurement
# 15   Estimated based on SM07 NMR measurement
# 16   Estimated based on SM07 NMR measurement
# 17   Estimated based on SM07 NMR measurement
# 18   Estimated based on SM07 NMR measurement
# 19   Estimated based on SM07 NMR measurement
# 20   Estimated based on SM07 NMR measurement
# 21   Estimated based on SM07 NMR measurement
# 22   Estimated based on SM07 NMR measurement
# 23   Estimated based on SM07 NMR measurement
# 24   Estimated based on SM07 NMR measurement
# 25   Estimated based on SM07 NMR measurement
# 26   Estimated based on SM07 NMR measurement
# 27   Estimated based on SM07 NMR measurement
# 28   Estimated based on SM07 NMR measurement
# 29   Estimated based on SM07 NMR measurement
# ..                                       ...
# 220  Estimated based on SM14 NMR measurement
# 221  Estimated based on SM14 NMR measurement
# 222  Estimated based on SM14 NMR measurement
# 223  Estimated based on SM14 NMR measurement
# 224  Estimated based on SM14 NMR measurement
# 225  Estimated based on SM14 NMR measurement
# 226  Estimated based on SM14 NMR measurement
# 227  Estimated based on SM14 NMR measurement
# 228  Estimated based on SM14 NMR measurement
# 229  Estimated based on SM14 NMR measurement
# 230  Estimated based on SM14 NMR measurement
# 231  Estimated based on SM14 NMR measurement
# 232  Estimated based on SM14 NMR measurement
# 233  Estimated based on SM14 NMR measurement
# 234  Estimated based on SM14 NMR measurement
# 235  Estimated based on SM14 NMR measurement
# 236  Estimated based on SM14 NMR measurement
# 237  Estimated based on SM14 NMR measurement
# 238  Estimated based on SM14 NMR measurement
# 239  Estimated based on SM14 NMR measurement
# 240  Estimated based on SM14 NMR measurement
# 241  Estimated based on SM14 NMR measurement
# 242  Estimated based on SM14 NMR measurement
# 243  Estimated based on SM14 NMR measurement
# 244  Estimated based on SM14 NMR measurement
# 245  Estimated based on SM14 NMR measurement
# 246  Estimated based on SM14 NMR measurement
# 247  Estimated based on SM14 NMR measurement
# 248                          NMR measurement
# 249                          NMR measurement
#
# [250 rows x 16 columns]

# %%
# Add a score column based on microstate ID match

df_col_ms["Microstate pair match"] = None

for i, row in enumerate(df_col_ms.iterrows()):
    pred_ms_A = row[1]["Microstate ID of A"]
    pred_ms_HA = row[1]["Microstate ID of HA"]
    pred_ms_pair = pred_ms_A + " " + pred_ms_HA
    
    exp_ms_A = row[1]["Exp. Microstate ID of A"]
    exp_ms_HA = row[1]["Exp. Microstate ID of HA"]
    exp_ms_pair = exp_ms_A + " " + exp_ms_HA
    
    if pred_ms_pair == exp_ms_pair:
        df_col_ms.loc[i,"Microstate pair match"] = 1
        print(pred_ms_pair )
        print(exp_ms_pair)
        print("1")
    else:
        df_col_ms.loc[i,"Microstate pair match"] = 0    
        print(pred_ms_pair )
        print(exp_ms_pair)
        print("0")
# Out:
# SM02_micro011 SM02_micro002
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro002
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro003
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro002
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro002
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM04_micro004 SM04_micro002
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro005 SM04_micro003
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro005 SM04_micro004
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro009 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro009 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro005 SM04_micro003
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM07_micro002 SM07_micro006
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro014 SM07_micro016
# SM07_micro004 SM07_micro006
# 0
# SM07_micro012 SM07_micro004
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro012 SM07_micro002
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro012 SM07_micro004
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro012 SM07_micro004
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM09_micro009 SM09_micro003
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro014 SM09_micro015
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro009 SM09_micro011
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro014 SM12_micro015
# SM12_micro012 SM12_micro006
# 0
# SM12_micro009 SM12_micro012
# SM12_micro012 SM12_micro006
# 0
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro009 SM12_micro002
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro009 SM12_micro012
# SM12_micro012 SM12_micro006
# 0
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro009 SM12_micro012
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM13_micro004 SM13_micro007
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro007 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro003 SM13_micro015
# SM13_micro005 SM13_micro001
# 0
# SM13_micro004 SM13_micro009
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro009 SM13_micro001
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro004 SM13_micro007
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro004 SM13_micro005
# SM13_micro005 SM13_micro001
# 0
# SM13_micro007 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro007 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro007 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro004 SM13_micro009
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro002 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro002
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro002
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro002
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b21ac5282cb1> in <module>
#       6     pred_ms_A = row[1]["Microstate ID of A"]
#       7     pred_ms_HA = row[1]["Microstate ID of HA"]
# ----> 8     pred_ms_pair = pred_ms_A + " " + pred_ms_HA
#       9
#      10     exp_ms_A = row[1]["Exp. Microstate ID of A"]
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
df_col_ms.head()
# Out:
#    Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 0         1.0                            3.65      SM02_micro011
# 1        31.0                           -1.02      SM02_micro002
# 2        61.0                           -0.62      SM02_micro003
# 3        91.0                           -0.62      SM02_micro003
# 4       122.0                            0.29      SM02_micro002
#
#   Microstate ID of HA Molecule ID  \
# 0       SM02_micro002        SM02
# 1       SM02_micro005        SM02
# 2       SM02_micro005        SM02
# 3       SM02_micro005        SM02
# 4       SM02_micro004        SM02
#
#                                                 name  pKa (calc)  pKa (exp)  \
# 0                      Explicit solvent submission 1        8.68       5.03
# 1  EC-RISM/B3LYP/6-311+G(d,p)-P3NI-phi-noThiols-2par        4.01       5.03
# 2         EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-2par        4.41       5.03
# 3         EC-RISM/MP2/cc-pVTZ-P3NI-phi-noThiols-2par        4.41       5.03
# 4                                OE Gaussian Process        5.32       5.03
#
#       pKa ID  pKa SEM (calc)  pKa SEM (exp)       participant receipt_id  \
# 0  SM02_pKa1             NaN           0.01  Samarjeet Prasad      0wfzo
# 1  SM02_pKa1            1.77           0.01       Stefan Kast      0xi4b
# 2  SM02_pKa1            1.77           0.01       Stefan Kast      2umai
# 3  SM02_pKa1            1.77           0.01       Stefan Kast      4o0ia
# 4  SM02_pKa1            1.28           0.01    Caitlin Bannan      6tvf8
#
#   Exp. Microstate ID of A Exp. Microstate ID of HA  \
# 0           SM02_micro001            SM02_micro004
# 1           SM02_micro001            SM02_micro004
# 2           SM02_micro001            SM02_micro004
# 3           SM02_micro001            SM02_micro004
# 4           SM02_micro001            SM02_micro004
#
#           Microstate identification source Microstate pair match
# 0  Estimated based on SM07 NMR measurement                     0
# 1  Estimated based on SM07 NMR measurement                     0
# 2  Estimated based on SM07 NMR measurement                     0
# 3  Estimated based on SM07 NMR measurement                     0
# 4  Estimated based on SM07 NMR measurement                     0

# %%
submission_IDs = list(set(df_col_ms["receipt_id"].to_list()))
submission_IDs
# Out:
# [nan,
#  'cm2yq',
#  'arcko',
#  'qsicn',
#  'wuuvc',
#  '6tvf8',
#  'kxztt',
#  'xnoe0',
#  'eyetm',
#  '0wfzo',
#  'epvmk',
#  'wexjs',
#  '8toyp',
#  '2umai',
#  '0xi4b',
#  '758j8',
#  'hdiyq',
#  'cywyk',
#  'z7fhp',
#  '4o0ia',
#  'z3btx',
#  'y4wws',
#  'ko8yx',
#  'nxaaw',
#  'v8qph',
#  'ftc8w',
#  'ccpmw',
#  't8ewk',
#  'ktpj5',
#  'w4z0e',
#  'hgn83',
#  'wcvnu',
#  'gdqeg']

# %%
microstate_pair_relative_accuracy = []
number_of_known_microstate_pairs = 10

for submission_ID in submission_IDs:
    # Take subset of df_col_ms based on submission ID
    df_submission = df_col_ms[df_col_ms["receipt_id"] == submission_ID]
    # Count how many times "Microstate pair match" column has value 1
    pair_match = df_submission["Microstate pair match"].values
    relative_accuracy = (np.sum(pair_match)/number_of_known_microstate_pairs)*100
    print("Relative accuracy of {}:".format(submission_ID), relative_accuracy)
    microstate_pair_relative_accuracy.append(relative_accuracy)
   
microstate_pair_relative_accuracy
# Out:
# Relative accuracy of nan: 0.0
# Relative accuracy of cm2yq: 20.0
# Relative accuracy of arcko: 40.0
# Relative accuracy of qsicn: 10.0
# Relative accuracy of wuuvc: 40.0
# Relative accuracy of 6tvf8: 30.0
# Relative accuracy of kxztt: 30.0
# Relative accuracy of xnoe0: 30.0
# Relative accuracy of eyetm: 40.0
# Relative accuracy of 0wfzo: 20.0
# Relative accuracy of epvmk: 20.0
# Relative accuracy of wexjs: 60.0
# Relative accuracy of 8toyp: 20.0
# Relative accuracy of 2umai: 20.0
# Relative accuracy of 0xi4b: 50.0
# Relative accuracy of 758j8: 0.0
# Relative accuracy of hdiyq: 50.0
# Relative accuracy of cywyk: 40.0
# Relative accuracy of z7fhp: 30.0
# Relative accuracy of 4o0ia: 10.0
# Relative accuracy of z3btx: 20.0
# Relative accuracy of y4wws: 30.0
# Relative accuracy of ko8yx: 40.0
# Relative accuracy of nxaaw: 50.0
# Relative accuracy of v8qph: 40.0
# Relative accuracy of ftc8w: 30.0
# Relative accuracy of ccpmw: 50.0
# Relative accuracy of t8ewk: 40.0
# Relative accuracy of ktpj5: 40.0
# Relative accuracy of w4z0e: 30.0
# Relative accuracy of hgn83: 0.0
# Relative accuracy of wcvnu: 50.0
# Relative accuracy of gdqeg: 0.0
# [0.0,
#  20.0,
#  40.0,
#  10.0,
#  40.0,
#  30.0,
#  30.0,
#  30.0,
#  40.0,
#  20.0,
#  20.0,
#  60.0,
#  20.0,
#  20.0,
#  50.0,
#  0.0,
#  50.0,
#  40.0,
#  30.0,
#  10.0,
#  20.0,
#  30.0,
#  40.0,
#  50.0,
#  40.0,
#  30.0,
#  50.0,
#  40.0,
#  40.0,
#  30.0,
#  0.0,
#  50.0,
#  0.0]

# %%
data = {'Submission ID': submission_IDs, 'Relative accuracy of microstate pairs(%)': microstate_pair_relative_accuracy}
df_rel_acc = pd.DataFrame.from_dict(data)

df_rel_acc = df_rel_acc.sort_values(by="Relative accuracy of microstate pairs(%)", ascending=False) #.reset_index(inplace=True)
df_rel_acc
# Out:
#    Submission ID  Relative accuracy of microstate pairs(%)
# 11         wexjs                                      60.0
# 16         hdiyq                                      50.0
# 26         ccpmw                                      50.0
# 23         nxaaw                                      50.0
# 14         0xi4b                                      50.0
# 31         wcvnu                                      50.0
# 8          eyetm                                      40.0
# 28         ktpj5                                      40.0
# 27         t8ewk                                      40.0
# 2          arcko                                      40.0
# 24         v8qph                                      40.0
# 4          wuuvc                                      40.0
# 22         ko8yx                                      40.0
# 17         cywyk                                      40.0
# 6          kxztt                                      30.0
# 7          xnoe0                                      30.0
# 25         ftc8w                                      30.0
# 21         y4wws                                      30.0
# 18         z7fhp                                      30.0
# 5          6tvf8                                      30.0
# 29         w4z0e                                      30.0
# 20         z3btx                                      20.0
# 1          cm2yq                                      20.0
# 13         2umai                                      20.0
# 12         8toyp                                      20.0
# 10         epvmk                                      20.0
# 9          0wfzo                                      20.0
# 19         4o0ia                                      10.0
# 3          qsicn                                      10.0
# 30         hgn83                                       0.0
# 0            NaN                                       0.0
# 15         758j8                                       0.0
# 32         gdqeg                                       0.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams["figure.figsize"] = [4,4]

# %%
def barplot(df, x_label, y_label, title):
    """Creates bar plot of a given dataframe.

    Args:
        df: Pandas Dataframe that should have columns with columnnames specified in other arguments.
        x_label: str, column name of x axis categories
        y_label: str, column name of y axis values
        title: str, the title of the plot

    """
    # Plot style
    plt.close()
    plt.style.use(["seaborn-talk", "seaborn-whitegrid"])
    plt.rcParams['axes.labelsize'] = 18
    plt.rcParams['xtick.labelsize'] = 14
    plt.rcParams['ytick.labelsize'] = 16
    plt.ylim(0,100)
    #plt.tight_layout()

    # Plot
    data = df
    x = range(len(data[y_label]))
    y = data[y_label]
    plt.bar(x, y)
    plt.xticks(x, data[x_label], rotation=90)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    if len(title) > 70:
        plt.title(title[:70]+"...")
    else:
        plt.title(title)
    plt.tight_layout()

# %%
barplot(df = df_rel_acc, 
        x_label = "Submission ID", 
        y_label = "Relative accuracy of microstate pairs(%)", 
        title = "Relative accuracy of microstate pairs in Type I submissions" )
plt.savefig("TypeI_microstate_pair_relative_accuracy.pdf")

# %%
fig
