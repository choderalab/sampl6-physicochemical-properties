# %%
import numpy as np
import pandas as pd
import scipy.stats as ss

# %%
closest_collection = "typeIII_submission_collection_closest.csv"
hungarian_collection = "typeIII_submission_collection_hungarian.csv"

# %% [markdown]
# ## How many predicted pKas are matched differently between closest and hungarian algorithms?

# %%
df_closest = pd.read_csv(closest_collection,index_col=0)
df_closest.head()
# Out:
#    $\Delta$pKa error (calc - exp) Molecule ID               name  pKa (calc)  \
# 0                            0.18        SM01  COSMOtherm_FINE17        9.71
# 1                            1.18        SM02  COSMOtherm_FINE17        6.21
# 2                           -6.39        SM03  COSMOtherm_FINE17        0.63
# 3                           -0.61        SM04  COSMOtherm_FINE17        5.41
# 4                           -0.06        SM05  COSMOtherm_FINE17        4.53
#
#    pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)    participant  \
# 0       9.53  SM01_pKa1            0.65           0.01  Chris Loschen
# 1       5.03  SM02_pKa1            0.65           0.01  Chris Loschen
# 2       7.02  SM03_pKa1            0.65           0.01  Chris Loschen
# 3       6.02  SM04_pKa1            0.65           0.01  Chris Loschen
# 4       4.59  SM05_pKa1            0.65           0.01  Chris Loschen
#
#   receipt_id
# 0      0hxtm
# 1      0hxtm
# 2      0hxtm
# 3      0hxtm
# 4      0hxtm

# %%
df_hungarian = pd.read_csv(hungarian_collection, index_col=0)
df_hungarian.head()
# Out:
#    $\Delta$pKa error (calc - exp) Molecule ID  \
# 0                            0.61        SM01
# 1                           -0.10        SM02
# 2                            0.50        SM03
# 3                           -0.85        SM04
# 4                           -0.23        SM05
#
#                                                 name  pKa (calc)  pKa (exp)  \
# 0  Full quantum chemical calculation of free ener...       10.14       9.53
# 1  Full quantum chemical calculation of free ener...        4.93       5.03
# 2  Full quantum chemical calculation of free ener...        7.52       7.02
# 3  Full quantum chemical calculation of free ener...        5.17       6.02
# 4  Full quantum chemical calculation of free ener...        4.36       4.59
#
#       pKa ID  pKa SEM (calc)  pKa SEM (exp)     participant receipt_id
# 0  SM01_pKa1            0.35           0.01  Philipp Pracht      xvxzd
# 1  SM02_pKa1            0.27           0.01  Philipp Pracht      xvxzd
# 2  SM03_pKa1            0.31           0.01  Philipp Pracht      xvxzd
# 3  SM04_pKa1            0.28           0.01  Philipp Pracht      xvxzd
# 4  SM05_pKa1            0.27           0.01  Philipp Pracht      xvxzd

# %%
prediction_methods = set(df_closest["name"])
len(prediction_methods)
# Out:
# 34

# %%
# Iterate through prediction methods and create a database that compares hunagarian and closest matching

matched_pKa_list = []

for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:
    
    submission_id = df_closest[df_closest["name"] == method]["receipt_id"].values[0]
    
    df_closest_1method = df_closest[df_closest["name"] == method].reset_index(drop=True)    
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    pKa_IDs = list(df_closest_1method["pKa ID"])
  
    # Iterate through pKa_IDs to check if predicted pKas match
    for pKa_ID in pKa_IDs:
        pKa_exp = df_closest_1method[df_closest_1method["pKa ID"] == pKa_ID]["pKa (exp)"].values[0]
        pKa_pred_closest = df_closest_1method[df_closest_1method["pKa ID"] == pKa_ID]["pKa (calc)"].values[0]
        pKa_pred_hungarian = df_hungarian_1method[df_hungarian_1method["pKa ID"] == pKa_ID]["pKa (calc)"].values
        closest_hungarian_diff = pKa_pred_closest - pKa_pred_hungarian
                
        matched_pKa_row = [pKa_ID, pKa_exp, pKa_pred_closest, pKa_pred_hungarian, closest_hungarian_diff, submission_id]
        matched_pKa_list.append(matched_pKa_row)
        #print(matched_pKa_row)

# Convert to pandas dataframe
df_compare_matching = pd.DataFrame(matched_pKa_list, columns = ['pKa ID', 'pKa (exp)', 
                                               'pKa (pred, closest)', 'pKa (pred, hungarian)',
                                              'closest - hungarian diff.', 'submission ID'])
df_compare_matching.head()
# Out:
#       pKa ID  pKa (exp)  pKa (pred, closest) pKa (pred, hungarian)  \
# 0  SM01_pKa1       9.53                10.01               [10.01]
# 1  SM02_pKa1       5.03                 5.71                [5.71]
# 2  SM03_pKa1       7.02                11.55               [11.55]
# 3  SM04_pKa1       6.02                 6.43                [6.43]
# 4  SM05_pKa1       4.59                 7.32                [7.32]
#
#   closest - hungarian diff. submission ID
# 0                     [0.0]         2ii2g
# 1                     [0.0]         2ii2g
# 2                     [0.0]         2ii2g
# 3                     [0.0]         2ii2g
# 4                     [0.0]         2ii2g

# %%
# Print out pKas that have different matching between hungarian and closest
df_difference_in_matching = df_compare_matching[df_compare_matching["closest - hungarian diff."] != 0]
df_difference_in_matching
# Out:
#         pKa ID  pKa (exp)  pKa (pred, closest) pKa (pred, hungarian)  \
# 27   SM22_pKa1       2.40                 4.82               [-1.34]
# 52   SM18_pKa2       9.58                 9.91                [9.24]
# 85   SM18_pKa3      11.02                10.56               [13.45]
# 146  SM18_pKa2       9.58                 9.26                [7.53]
# 229  SM14_pKa1       2.58                 3.84                [0.47]
# 230  SM14_pKa2       5.30                19.09                [3.84]
# 259  SM14_pKa1       2.58                 3.81                [0.42]
# 260  SM14_pKa2       5.30                18.84                [3.81]
# 311  SM06_pKa1       3.03                 3.94                [1.77]
# 355  SM18_pKa2       9.58                 9.59                [8.38]
# 494  SM14_pKa1       2.58                 3.38               [-1.77]
# 495  SM14_pKa2       5.30                24.63                [3.38]
# 502  SM18_pKa3      11.02                11.53               [11.75]
# 529  SM14_pKa1       2.58                 3.74                [-1.4]
# 530  SM14_pKa2       5.30                18.61                [3.74]
# 542  SM22_pKa1       2.40                 4.23               [-3.77]
# 565  SM18_pKa2       9.58                 9.87                [3.35]
# 615  SM14_pKa1       2.58                 3.94                [0.14]
# 616  SM14_pKa2       5.30                19.65                [3.94]
# 653  SM18_pKa3      11.02                10.97               [13.98]
# 728  SM06_pKa1       3.03                 4.40                [1.38]
# 741  SM18_pKa1       2.15                 1.84                 [0.5]
# 763  SM14_pKa1       2.58                 3.86                [-0.9]
# 764  SM14_pKa2       5.30                23.88                [3.86]
# 793  SM14_pKa1       2.58                 3.94                [0.15]
# 794  SM14_pKa2       5.30                19.58                [3.94]
# 830  SM18_pKa2       9.58                10.02                [8.39]
# 891  SM18_pKa2       9.58                 7.43                 [6.6]
# 920  SM18_pKa2       9.58                 9.51                [7.59]
# 934  SM06_pKa1       3.03                 3.98                [0.98]
#
#     closest - hungarian diff. submission ID
# 27                     [6.16]         2ii2g
# 52       [0.6699999999999999]         nb002
# 85       [-2.889999999999999]         xikp8
# 146      [1.7299999999999995]         yqkga
# 229                    [3.37]         ttjd0
# 230                   [15.25]         ttjd0
# 259                    [3.39]         mpwiy
# 260                   [15.03]         mpwiy
# 311                    [2.17]         hytjn
# 355       [1.209999999999999]         5byn6
# 494                    [5.15]         nb006
# 495                   [21.25]         nb006
# 502    [-0.22000000000000064]         nb006
# 529       [5.140000000000001]         ds62k
# 530                   [14.87]         ds62k
# 542                     [8.0]         ds62k
# 565                    [6.52]         pwn3m
# 615                     [3.8]         nb003
# 616      [15.709999999999999]         nb003
# 653                   [-3.01]         ad5pu
# 728      [3.0200000000000005]         0hxtm
# 741                    [1.34]         0hxtm
# 763                    [4.76]         nb005
# 764                   [20.02]         nb005
# 793                    [3.79]         nb004
# 794      [15.639999999999999]         nb004
# 830       [1.629999999999999]         w4iyd
# 891      [0.8300000000000001]         yc70m
# 920                    [1.92]         ryzue
# 934                     [3.0]         q3pfp

# %%
# Why is nb006 SM14_pKa2 matched to a very different number?

# These are submitted SM14 predictions
# SM14, -1.77, 1.77
# SM14,  3.38, 1.77
# SM14, 24.63, 1.77


# SM14 Experimental values
# 2.58 ± 0.01
# 5.30 ± 0.01


df_nb006 = df_closest[df_closest['receipt_id']=='nb006']
df_nb006_SM14 = df_nb006[df_nb006['Molecule ID']=='SM14']
df_nb006_SM14
# Out:
#      $\Delta$pKa error (calc - exp) Molecule ID  \
# 553                            0.80        SM14
# 554                           19.33        SM14
#
#                                            name  pKa (calc)  pKa (exp)  \
# 553  EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        3.38       2.58
# 554  EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par       24.63       5.30
#
#         pKa ID  pKa SEM (calc)  pKa SEM (exp)  participant receipt_id
# 553  SM14_pKa1            1.77           0.01  Stefan Kast      nb006
# 554  SM14_pKa2            1.77           0.01  Stefan Kast      nb006

# %%
df_nb006 = df_hungarian[df_hungarian['receipt_id']=='nb006']
df_nb006_SM14 = df_nb006[df_nb006['Molecule ID']=='SM14']
df_nb006_SM14
# Out:
#      $\Delta$pKa error (calc - exp) Molecule ID  \
# 507                           -4.35        SM14
# 508                           -1.92        SM14
#
#                                            name  pKa (calc)  pKa (exp)  \
# 507  EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par       -1.77       2.58
# 508  EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        3.38       5.30
#
#         pKa ID  pKa SEM (calc)  pKa SEM (exp)  participant receipt_id
# 507  SM14_pKa1            1.77           0.01  Stefan Kast      nb006
# 508  SM14_pKa2            1.77           0.01  Stefan Kast      nb006

# %% [markdown]
# ### Experimental pKas of molecules with pKas differently matched
# SM06
# 3.03 ± 0.04
# 11.74 ± 0.01
#
# SM14
# 2.58 ± 0.01
# 5.30 ± 0.01
#
# SM18
# 2.15 ± 0.02
# 9.58 ± 0.03
# 11.02 ± 0.04
#
# SM22
# 2.40 ± 0.02
# 7.43 ± 0.01
#
# ### Experimental pKas of molecules with pKas equally matched even thought they have multiple pKas
# SM15
# 4.70 ± 0.01
# 8.94 ± 0.01
#
# SM16
# 5.37 ± 0.01
# 10.65 ± 0.01

# %% [markdown]
# ## How many pKa predictions are matched without conserving the sequence with Hungarian method?

# %%
# Test for comparing rank orders - ORDERED MATCH
exp_pKas = np.array([2.4, 4.3, 7.0])
pred_pKas = np.array([2.5, 4.2, 7.2])

#exp_pKa_ranks = list(np.array([1, 3, 2]))
#pred_pKa_ranks = list(np.array([1, 3, 2]))

exp_pKa_ranks = ss.rankdata(exp_pKas)
print("exp ranks:", exp_pKa_ranks)
pred_pKa_ranks = ss.rankdata(pred_pKas)
print("pred ranks:", pred_pKa_ranks)

# Is rank order the same?
if list(exp_pKa_ranks) == list(pred_pKa_ranks):
    ordered_match = True
else:
    ordered_match = False
    
ordered_match
# Out:
# exp ranks: [1. 2. 3.]
# pred ranks: [1. 2. 3.]
# True

# %%
# Test for comparing rank orders - UNORDERED MATCH
exp_pKas = np.array([2.4, 4.3, 7.0])
pred_pKas = np.array([2.5, 7.0, 4.5])

#exp_pKa_ranks = list(np.array([1, 3, 2]))
#pred_pKa_ranks = list(np.array([1, 3, 2]))

exp_pKa_ranks = ss.rankdata(exp_pKas)
print("exp ranks:", exp_pKa_ranks)
pred_pKa_ranks = ss.rankdata(pred_pKas)
print("pred ranks:", pred_pKa_ranks)

# Is rank order the same?
if list(exp_pKa_ranks) == list(pred_pKa_ranks):
    ordered_match = True
else:
    ordered_match = False
    
ordered_match
# Out:
# exp ranks: [1. 2. 3.]
# pred ranks: [1. 3. 2.]
# False

# %%
df_hungarian.head()
# Out:
#    $\Delta$pKa error (calc - exp) Molecule ID  \
# 0                            0.61        SM01
# 1                           -0.10        SM02
# 2                            0.50        SM03
# 3                           -0.85        SM04
# 4                           -0.23        SM05
#
#                                                 name  pKa (calc)  pKa (exp)  \
# 0  Full quantum chemical calculation of free ener...       10.14       9.53
# 1  Full quantum chemical calculation of free ener...        4.93       5.03
# 2  Full quantum chemical calculation of free ener...        7.52       7.02
# 3  Full quantum chemical calculation of free ener...        5.17       6.02
# 4  Full quantum chemical calculation of free ener...        4.36       4.59
#
#       pKa ID  pKa SEM (calc)  pKa SEM (exp)     participant receipt_id
# 0  SM01_pKa1            0.35           0.01  Philipp Pracht      xvxzd
# 1  SM02_pKa1            0.27           0.01  Philipp Pracht      xvxzd
# 2  SM03_pKa1            0.31           0.01  Philipp Pracht      xvxzd
# 3  SM04_pKa1            0.28           0.01  Philipp Pracht      xvxzd
# 4  SM05_pKa1            0.27           0.01  Philipp Pracht      xvxzd

# %%
pKa_rank_comparison_list =[]

# Iterate through methods
for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:

    submission_ID = set(df_hungarian[df_hungarian["name"] == method]["receipt_id"].values)
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    mol_IDs = list(df_hungarian_1method["Molecule ID"])

    #Iterate through molecules
    for mol_ID in mol_IDs:
        df_hungarian_1method_1mol = df_hungarian_1method[df_hungarian_1method["Molecule ID"] == mol_ID].reset_index(drop=True)
        
        pKa_IDs = df_hungarian_1method_1mol['pKa ID'].values
        
        #Assign Rank order of experimental and predicted pKa.
        exp_pKas = df_hungarian_1method_1mol['pKa (exp)'].values 
        exp_pKa_ranks = ss.rankdata(exp_pKas )
        
        
        pred_pKas = df_hungarian_1method_1mol['pKa (calc)'].values
        pred_pKa_ranks = ss.rankdata(pred_pKas) # rank is given to only matched pred pKas

    
        # Is rank order the same?
        if list(exp_pKa_ranks) == list(pred_pKa_ranks):
            ordered_match = True
        else:
            ordered_match = False

        
        pKa_rank_comparison_list.append([mol_ID, ordered_match, pKa_IDs, exp_pKas, pred_pKas, exp_pKa_ranks, pred_pKa_ranks, submission_ID])
    
    
# Convert to pandas dataframe
df_compare_ranks_hungarian = pd.DataFrame(pKa_rank_comparison_list, columns = ['mol ID', 'ordered match', 'pKa IDs', 'pKa (exp)', 
                                               'pKa (pred)', 'pKa rank (exp)', 'pKa rank (pred)', 'submission ID'])
df_compare_ranks_hungarian = df_compare_ranks_hungarian.astype(str)
df_compare_ranks_hungarian = df_compare_ranks_hungarian.drop_duplicates()
df_compare_ranks_hungarian
# Out:
#     mol ID ordered match                                pKa IDs  \
# 0     SM01          True                          ['SM01_pKa1']
# 1     SM02          True                          ['SM02_pKa1']
# 2     SM03          True                          ['SM03_pKa1']
# 3     SM04          True                          ['SM04_pKa1']
# 4     SM05          True                          ['SM05_pKa1']
# 5     SM06          True              ['SM06_pKa1' 'SM06_pKa2']
# 7     SM07          True                          ['SM07_pKa1']
# 8     SM08          True                          ['SM08_pKa1']
# 9     SM09          True                          ['SM09_pKa1']
# 10    SM10          True                          ['SM10_pKa1']
# 11    SM11          True                          ['SM11_pKa1']
# 12    SM12          True                          ['SM12_pKa1']
# 13    SM13          True                          ['SM13_pKa1']
# 14    SM14          True              ['SM14_pKa1' 'SM14_pKa2']
# 16    SM15          True              ['SM15_pKa1' 'SM15_pKa2']
# 18    SM16          True              ['SM16_pKa1' 'SM16_pKa2']
# 20    SM17          True                          ['SM17_pKa1']
# 21    SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 24    SM19          True                          ['SM19_pKa1']
# 25    SM20          True                          ['SM20_pKa1']
# 26    SM21          True                          ['SM21_pKa1']
# 27    SM22          True              ['SM22_pKa1' 'SM22_pKa2']
# 29    SM23          True                          ['SM23_pKa1']
# 30    SM24          True                          ['SM24_pKa1']
# 31    SM01          True                          ['SM01_pKa1']
# 32    SM02          True                          ['SM02_pKa1']
# 33    SM03          True                          ['SM03_pKa1']
# 34    SM04          True                          ['SM04_pKa1']
# 35    SM05          True                          ['SM05_pKa1']
# 36    SM06          True              ['SM06_pKa1' 'SM06_pKa2']
# ..     ...           ...                                    ...
# 917   SM19          True                          ['SM19_pKa1']
# 918   SM20          True                          ['SM20_pKa1']
# 919   SM21          True                          ['SM21_pKa1']
# 920   SM22          True              ['SM22_pKa2' 'SM22_pKa1']
# 922   SM23          True                          ['SM23_pKa1']
# 923   SM24          True                          ['SM24_pKa1']
# 924   SM01          True                          ['SM01_pKa1']
# 925   SM02          True                          ['SM02_pKa1']
# 926   SM03          True                          ['SM03_pKa1']
# 927   SM04          True                          ['SM04_pKa1']
# 928   SM05          True                          ['SM05_pKa1']
# 929   SM06          True              ['SM06_pKa1' 'SM06_pKa2']
# 931   SM07          True                          ['SM07_pKa1']
# 932   SM08          True                          ['SM08_pKa1']
# 933   SM09          True                          ['SM09_pKa1']
# 934   SM10          True                          ['SM10_pKa1']
# 935   SM11          True                          ['SM11_pKa1']
# 936   SM12          True                          ['SM12_pKa1']
# 937   SM13          True                          ['SM13_pKa1']
# 938   SM14          True              ['SM14_pKa1' 'SM14_pKa2']
# 940   SM15          True              ['SM15_pKa1' 'SM15_pKa2']
# 942   SM16          True                          ['SM16_pKa1']
# 943   SM17          True                          ['SM17_pKa1']
# 944   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 947   SM19          True                          ['SM19_pKa1']
# 948   SM20          True                          ['SM20_pKa1']
# 949   SM21          True                          ['SM21_pKa1']
# 950   SM22          True              ['SM22_pKa1' 'SM22_pKa2']
# 952   SM23          True                          ['SM23_pKa1']
# 953   SM24          True                          ['SM24_pKa1']
#
#                pKa (exp)           pKa (pred) pKa rank (exp) pKa rank (pred)  \
# 0                 [9.53]              [10.01]           [1.]            [1.]
# 1                 [5.03]               [5.71]           [1.]            [1.]
# 2                 [7.02]              [11.55]           [1.]            [1.]
# 3                 [6.02]               [6.43]           [1.]            [1.]
# 4                 [4.59]               [7.32]           [1.]            [1.]
# 5          [ 3.03 11.74]        [ 2.55 12.97]        [1. 2.]         [1. 2.]
# 7                 [6.08]               [4.96]           [1.]            [1.]
# 8                 [4.22]               [5.97]           [1.]            [1.]
# 9                 [5.37]               [6.09]           [1.]            [1.]
# 10                [9.02]              [12.38]           [1.]            [1.]
# 11                [3.89]               [4.64]           [1.]            [1.]
# 12                [5.28]               [5.62]           [1.]            [1.]
# 13                [5.77]               [6.92]           [1.]            [1.]
# 14           [2.58 5.3 ]          [2.1  5.69]        [1. 2.]         [1. 2.]
# 16           [4.7  8.94]          [5.24 9.69]        [1. 2.]         [1. 2.]
# 18         [ 5.37 10.65]        [ 6.37 11.98]        [1. 2.]         [1. 2.]
# 20                [3.16]               [4.65]           [1.]            [1.]
# 21   [ 2.15  9.58 11.02]  [ 3.15  9.66 11.63]     [1. 2. 3.]      [1. 2. 3.]
# 24                [9.56]              [12.77]           [1.]            [1.]
# 25                 [5.7]               [8.11]           [1.]            [1.]
# 26                 [4.1]               [2.62]           [1.]            [1.]
# 27           [2.4  7.43]        [-1.34  4.82]        [1. 2.]         [1. 2.]
# 29                [5.45]               [5.36]           [1.]            [1.]
# 30                 [2.6]               [4.72]           [1.]            [1.]
# 31                [9.53]                [8.7]           [1.]            [1.]
# 32                [5.03]               [4.14]           [1.]            [1.]
# 33                [7.02]               [9.26]           [1.]            [1.]
# 34                [6.02]               [4.75]           [1.]            [1.]
# 35                [4.59]               [6.57]           [1.]            [1.]
# 36         [ 3.03 11.74]          [2.17 9.98]        [1. 2.]         [1. 2.]
# ..                   ...                  ...            ...             ...
# 917               [9.56]               [8.97]           [1.]            [1.]
# 918                [5.7]               [3.18]           [1.]            [1.]
# 919                [4.1]               [1.38]           [1.]            [1.]
# 920          [7.43 2.4 ]          [7.56 1.66]        [2. 1.]         [2. 1.]
# 922               [5.45]               [4.83]           [1.]            [1.]
# 923                [2.6]               [2.25]           [1.]            [1.]
# 924               [9.53]               [9.27]           [1.]            [1.]
# 925               [5.03]               [5.94]           [1.]            [1.]
# 926               [7.02]               [5.79]           [1.]            [1.]
# 927               [6.02]               [7.02]           [1.]            [1.]
# 928               [4.59]               [7.62]           [1.]            [1.]
# 929        [ 3.03 11.74]          [0.98 3.98]        [1. 2.]         [1. 2.]
# 931               [6.08]               [4.78]           [1.]            [1.]
# 932               [4.22]                [4.6]           [1.]            [1.]
# 933               [5.37]               [4.21]           [1.]            [1.]
# 934               [9.02]               [6.45]           [1.]            [1.]
# 935               [3.89]                [4.2]           [1.]            [1.]
# 936               [5.28]               [6.35]           [1.]            [1.]
# 937               [5.77]               [7.21]           [1.]            [1.]
# 938          [2.58 5.3 ]        [-0.14  6.49]        [1. 2.]         [1. 2.]
# 940          [4.7  8.94]          [5.42 8.71]        [1. 2.]         [1. 2.]
# 942               [5.37]               [5.91]           [1.]            [1.]
# 943               [3.16]               [2.87]           [1.]            [1.]
# 944  [ 2.15  9.58 11.02]  [-0.72  5.21 11.1 ]     [1. 2. 3.]      [1. 2. 3.]
# 947               [9.56]               [6.05]           [1.]            [1.]
# 948                [5.7]               [7.29]           [1.]            [1.]
# 949                [4.1]               [4.07]           [1.]            [1.]
# 950          [2.4  7.43]          [2.73 6.6 ]        [1. 2.]         [1. 2.]
# 952               [5.45]               [6.61]           [1.]            [1.]
# 953                [2.6]               [2.37]           [1.]            [1.]
#
#     submission ID
# 0       {'2ii2g'}
# 1       {'2ii2g'}
# 2       {'2ii2g'}
# 3       {'2ii2g'}
# 4       {'2ii2g'}
# 5       {'2ii2g'}
# 7       {'2ii2g'}
# 8       {'2ii2g'}
# 9       {'2ii2g'}
# 10      {'2ii2g'}
# 11      {'2ii2g'}
# 12      {'2ii2g'}
# 13      {'2ii2g'}
# 14      {'2ii2g'}
# 16      {'2ii2g'}
# 18      {'2ii2g'}
# 20      {'2ii2g'}
# 21      {'2ii2g'}
# 24      {'2ii2g'}
# 25      {'2ii2g'}
# 26      {'2ii2g'}
# 27      {'2ii2g'}
# 29      {'2ii2g'}
# 30      {'2ii2g'}
# 31      {'nb002'}
# 32      {'nb002'}
# 33      {'nb002'}
# 34      {'nb002'}
# 35      {'nb002'}
# 36      {'nb002'}
# ..            ...
# 917     {'ryzue'}
# 918     {'ryzue'}
# 919     {'ryzue'}
# 920     {'ryzue'}
# 922     {'ryzue'}
# 923     {'ryzue'}
# 924     {'q3pfp'}
# 925     {'q3pfp'}
# 926     {'q3pfp'}
# 927     {'q3pfp'}
# 928     {'q3pfp'}
# 929     {'q3pfp'}
# 931     {'q3pfp'}
# 932     {'q3pfp'}
# 933     {'q3pfp'}
# 934     {'q3pfp'}
# 935     {'q3pfp'}
# 936     {'q3pfp'}
# 937     {'q3pfp'}
# 938     {'q3pfp'}
# 940     {'q3pfp'}
# 942     {'q3pfp'}
# 943     {'q3pfp'}
# 944     {'q3pfp'}
# 947     {'q3pfp'}
# 948     {'q3pfp'}
# 949     {'q3pfp'}
# 950     {'q3pfp'}
# 952     {'q3pfp'}
# 953     {'q3pfp'}
#
# [749 rows x 8 columns]

# %%
# Print out pKas that don't preserve increasing order when matched my Hungarian algorithm
df_unordered_matching_hungarian = df_compare_ranks_hungarian[df_compare_ranks_hungarian["ordered match"] == False]
df_unordered_matching_hungarian
# Out:
# Empty DataFrame
# Columns: [mol ID, ordered match, pKa IDs, pKa (exp), pKa (pred), pKa rank (exp), pKa rank (pred), submission ID]
# Index: []

# %%
# Just SM18
df_unordered_matching_hungarian_SM18 = df_compare_ranks_hungarian[df_compare_ranks_hungarian["mol ID"] == 'SM18']
df_unordered_matching_hungarian_SM18
# Out:
#     mol ID ordered match                                pKa IDs  \
# 21    SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 52    SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 87    SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 118   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 149   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 180   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 211   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 242   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 273   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 303   SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 333   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 364   SM18          True  ['SM18_pKa2' 'SM18_pKa3' 'SM18_pKa1']
# 394   SM18          True              ['SM18_pKa1' 'SM18_pKa2']
# 423   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 451   SM18          True              ['SM18_pKa1' 'SM18_pKa2']
# 481   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 512   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 548   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 578   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 607   SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 638   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 669   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 700   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 729   SM18          True              ['SM18_pKa2' 'SM18_pKa1']
# 759   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 790   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 821   SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 852   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 883   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 914   SM18          True  ['SM18_pKa2' 'SM18_pKa3' 'SM18_pKa1']
# 944   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
#
#                pKa (exp)           pKa (pred) pKa rank (exp) pKa rank (pred)  \
# 21   [ 2.15  9.58 11.02]  [ 3.15  9.66 11.63]     [1. 2. 3.]      [1. 2. 3.]
# 52   [ 2.15 11.02  9.58]     [1.81 9.91 9.24]     [1. 3. 2.]      [1. 3. 2.]
# 87   [11.02  9.58  2.15]  [13.45 10.56  0.1 ]     [3. 2. 1.]      [3. 2. 1.]
# 118  [ 2.15  9.58 11.02]     [2.34 9.39 9.92]     [1. 2. 3.]      [1. 2. 3.]
# 149  [ 2.15  9.58 11.02]     [2.14 7.53 9.26]     [1. 2. 3.]      [1. 2. 3.]
# 180  [ 2.15 11.02  9.58]  [ 3.38 11.15  9.95]     [1. 3. 2.]      [1. 3. 2.]
# 211  [ 2.15 11.02  9.58]     [1.82 9.97 9.3 ]     [1. 3. 2.]      [1. 3. 2.]
# 242  [ 2.15  9.58 11.02]  [ 2.    9.73 10.23]     [1. 2. 3.]      [1. 2. 3.]
# 273  [ 2.15  9.58 11.02]  [ 2.05  9.7  10.39]     [1. 2. 3.]      [1. 2. 3.]
# 303  [11.02  9.58  2.15]  [12.61  8.94  0.67]     [3. 2. 1.]      [3. 2. 1.]
# 333  [ 2.15  9.58 11.02]  [-0.26  5.   10.98]     [1. 2. 3.]      [1. 2. 3.]
# 364  [ 9.58 11.02  2.15]     [8.38 9.59 1.11]     [2. 3. 1.]      [2. 3. 1.]
# 394          [2.15 9.58]          [2.08 8.52]        [1. 2.]         [1. 2.]
# 423  [ 2.15  9.58 11.02]  [ 2.29  9.71 10.61]     [1. 2. 3.]      [1. 2. 3.]
# 451          [2.15 9.58]            [2.1 9.9]        [1. 2.]         [1. 2.]
# 481  [ 2.15 11.02  9.58]  [ 0.95 10.91  9.5 ]     [1. 3. 2.]      [1. 3. 2.]
# 512  [ 2.15 11.02  9.58]  [ 0.18 11.75 11.53]     [1. 3. 2.]      [1. 3. 2.]
# 548  [ 2.15  9.58 11.02]  [ 0.95  9.43 12.75]     [1. 2. 3.]      [1. 2. 3.]
# 578  [ 2.15  9.58 11.02]     [2.   3.35 9.87]     [1. 2. 3.]      [1. 2. 3.]
# 607  [11.02  9.58  2.15]  [10.23  9.21  2.02]     [3. 2. 1.]      [3. 2. 1.]
# 638  [ 2.15 11.02  9.58]  [ 1.58 10.13  9.97]     [1. 3. 2.]      [1. 3. 2.]
# 669  [ 2.15  9.58 11.02]  [ 2.59 10.97 13.98]     [1. 2. 3.]      [1. 2. 3.]
# 700  [ 2.15  9.58 11.02]  [ 2.12  8.74 10.54]     [1. 2. 3.]      [1. 2. 3.]
# 729          [9.58 2.15]          [1.84 0.5 ]        [2. 1.]         [2. 1.]
# 759  [ 2.15 11.02  9.58]  [ 0.57 11.46 10.57]     [1. 3. 2.]      [1. 3. 2.]
# 790  [ 2.15 11.02  9.58]  [ 1.58 10.1   9.94]     [1. 3. 2.]      [1. 3. 2.]
# 821  [11.02  9.58  2.15]  [10.02  8.39  1.82]     [3. 2. 1.]      [3. 2. 1.]
# 852  [ 2.15  9.58 11.02]  [ 2.2   9.92 10.42]     [1. 2. 3.]      [1. 2. 3.]
# 883  [ 2.15  9.58 11.02]     [4.29 6.6  7.43]     [1. 2. 3.]      [1. 2. 3.]
# 914  [ 9.58 11.02  2.15]     [7.59 9.51 1.41]     [2. 3. 1.]      [2. 3. 1.]
# 944  [ 2.15  9.58 11.02]  [-0.72  5.21 11.1 ]     [1. 2. 3.]      [1. 2. 3.]
#
#     submission ID
# 21      {'2ii2g'}
# 52      {'nb002'}
# 87      {'xikp8'}
# 118     {'xmyhm'}
# 149     {'yqkga'}
# 180     {'f0gew'}
# 211     {'nb001'}
# 242     {'ttjd0'}
# 273     {'mpwiy'}
# 303     {'y75vj'}
# 333     {'hytjn'}
# 364     {'5byn6'}
# 394     {'xvxzd'}
# 423     {'37xm8'}
# 451     {'5nm4j'}
# 481     {'np6b4'}
# 512     {'nb006'}
# 548     {'ds62k'}
# 578     {'pwn3m'}
# 607     {'gyuhx'}
# 638     {'nb003'}
# 669     {'ad5pu'}
# 700     {'8xt50'}
# 729     {'0hxtm'}
# 759     {'nb005'}
# 790     {'nb004'}
# 821     {'w4iyd'}
# 852     {'mkhqa'}
# 883     {'yc70m'}
# 914     {'ryzue'}
# 944     {'q3pfp'}

# %%
# SM18 prediction of 0hxtm method was also matched in expected order.
df_unordered_matching_hungarian_SM18_0hxtm = df_unordered_matching_hungarian_SM18[df_compare_ranks_hungarian["submission ID"] == '0hxtm']
df_unordered_matching_hungarian_SM18_0hxtm
# Out:
# /Users/isikm/opt/anaconda/envs/sampl6_pKa/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# Empty DataFrame
# Columns: [mol ID, ordered match, pKa IDs, pKa (exp), pKa (pred), pKa rank (exp), pKa rank (pred), submission ID]
# Index: []

# %% [markdown]
# There isn't any matches out of order in this set.
#
# ### Was there a out of order match in the past for Hungarian matching? Is it random for SM18 in 0hxtm submission?

# %%
# SAMPL6 repository branch pKa_typeIII_analysis3_hungarian
# https://github.com/MobleyLab/SAMPL6/blob/pKa_typeIII_analysis3_hungarian/physical_properties/pKa/analysis/analysis_of_typeIII_predictions/analysis_outputs_hungarian/typeIII_submission_collection.csv
hungarian_collection_a3 = 'typeIII_submission_collection_hungarian_analysis3.csv'
df_hungarian = pd.read_csv(hungarian_collection_a3, index_col=0)


pKa_rank_comparison_list =[]

# Iterate through methods
for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:

    submission_ID = df_hungarian[df_hungarian["name"] == method]["receipt_id"].values[0]
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    mol_IDs = list(df_hungarian_1method["Molecule ID"])

    #Iterate through molecules
    for mol_ID in mol_IDs:
        df_hungarian_1method_1mol = df_hungarian_1method[df_hungarian_1method["Molecule ID"] == mol_ID].reset_index(drop=True)
        
        pKa_IDs = df_hungarian_1method_1mol['pKa ID'].values
        
        #Assign Rank order of experimental and predicted pKa.
        exp_pKas = df_hungarian_1method_1mol['pKa (exp)'].values 
        exp_pKa_ranks = ss.rankdata(exp_pKas )
        
        
        pred_pKas = df_hungarian_1method_1mol['pKa (calc)'].values
        pred_pKa_ranks = ss.rankdata(pred_pKas) # rank is given to only matched pred pKas

    
        # Is rank order the same?
        if list(exp_pKa_ranks) == list(pred_pKa_ranks):
            ordered_match = True
        else:
            ordered_match = False

        
        pKa_rank_comparison_list.append([mol_ID, ordered_match, pKa_IDs, exp_pKas, pred_pKas, exp_pKa_ranks, pred_pKa_ranks, submission_ID])
    
    
# Convert to pandas dataframe
df_compare_ranks_hungarian = pd.DataFrame(pKa_rank_comparison_list, columns = ['mol ID', 'ordered match', 'pKa IDs', 'pKa (exp)', 
                                               'pKa (pred)', 'pKa rank (exp)', 'pKa rank (pred)', 'submission ID'])

# Print out pKas that don't preserve increasing order when matched my Hungarian algorithm
df_unordered_matching_hungarian = df_compare_ranks_hungarian[df_compare_ranks_hungarian["ordered match"] == False]
df_unordered_matching_hungarian = df_unordered_matching_hungarian.astype(str)
df_unordered_matching_hungarian = df_unordered_matching_hungarian.drop_duplicates()
df_unordered_matching_hungarian
# Out:
#     mol ID ordered match                                pKa IDs  \
# 149   SM18         False  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 760   SM18         False              ['SM18_pKa1' 'SM18_pKa2']
# 914   SM18         False  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 945   SM18         False  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
#
#                pKa (exp)        pKa (pred) pKa rank (exp) pKa rank (pred)  \
# 149  [ 2.15 11.02  9.58]  [2.14 7.53 9.26]     [1. 3. 2.]      [1. 2. 3.]
# 760          [2.15 9.58]       [1.84 0.5 ]        [1. 2.]         [2. 1.]
# 914  [ 2.15 11.02  9.58]  [4.29 6.6  7.43]     [1. 3. 2.]      [1. 2. 3.]
# 945  [11.02  9.58  2.15]  [7.59 9.51 1.41]     [3. 2. 1.]      [2. 3. 1.]
#
#     submission ID
# 149         yqkga
# 760         0hxtm
# 914         yc70m
# 945         ryzue

# %%
# SAMPL6 repository branch pKa_typeIII_analysis5_hungarian
# https://github.com/MobleyLab/SAMPL6/blob/pKa_typeIII_analysis5/physical_properties/pKa/analysis/analysis_of_typeIII_predictions/analysis_outputs_hungarian/typeIII_submission_collection.csv
hungarian_collection_a5 = 'typeIII_submission_collection_hungarian_analysis5.csv'
df_hungarian = pd.read_csv(hungarian_collection_a5, index_col=0)


pKa_rank_comparison_list =[]

# Iterate through methods
for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:

    submission_ID = df_hungarian[df_hungarian["name"] == method]["receipt_id"].values[0]
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    mol_IDs = list(df_hungarian_1method["Molecule ID"])

    #Iterate through molecules
    for mol_ID in mol_IDs:
        df_hungarian_1method_1mol = df_hungarian_1method[df_hungarian_1method["Molecule ID"] == mol_ID].reset_index(drop=True)
        
        pKa_IDs = df_hungarian_1method_1mol['pKa ID'].values
        
        #Assign Rank order of experimental and predicted pKa.
        exp_pKas = df_hungarian_1method_1mol['pKa (exp)'].values 
        exp_pKa_ranks = ss.rankdata(exp_pKas )
        
        
        pred_pKas = df_hungarian_1method_1mol['pKa (calc)'].values
        pred_pKa_ranks = ss.rankdata(pred_pKas) # rank is given to only matched pred pKas

    
        # Is rank order the same?
        if list(exp_pKa_ranks) == list(pred_pKa_ranks):
            ordered_match = True
        else:
            ordered_match = False

        
        pKa_rank_comparison_list.append([mol_ID, ordered_match, pKa_IDs, exp_pKas, pred_pKas, exp_pKa_ranks, pred_pKa_ranks, submission_ID])
    
    
# Convert to pandas dataframe
df_compare_ranks_hungarian = pd.DataFrame(pKa_rank_comparison_list, columns = ['mol ID', 'ordered match', 'pKa IDs', 'pKa (exp)', 
                                               'pKa (pred)', 'pKa rank (exp)', 'pKa rank (pred)', 'submission ID'])

# Print out pKas that don't preserve increasing order when matched my Hungarian algorithm
df_unordered_matching_hungarian = df_compare_ranks_hungarian[df_compare_ranks_hungarian["ordered match"] == False]
df_unordered_matching_hungarian
# Out:
# Empty DataFrame
# Columns: [mol ID, ordered match, pKa IDs, pKa (exp), pKa (pred), pKa rank (exp), pKa rank (pred), submission ID]
# Index: []

# %%
# Just SM18
df_unordered_matching_hungarian_SM18 = df_compare_ranks_hungarian[df_compare_ranks_hungarian["mol ID"] == 'SM18']

# SM18 prediction of yqkga method 
df_unordered_matching_hungarian_SM18_yqkga = df_unordered_matching_hungarian_SM18[df_compare_ranks_hungarian["submission ID"] == 'yqkga']
df_unordered_matching_hungarian_SM18_yqkga
# Out:
# /Users/isikm/opt/anaconda/envs/sampl6_pKa/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#     mol ID  ordered match                            pKa IDs  \
# 149   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
# 150   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
# 151   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
#
#                pKa (exp)          pKa (pred)   pKa rank (exp)  \
# 149  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
# 150  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
# 151  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
#
#      pKa rank (pred) submission ID
# 149  [1.0, 2.0, 3.0]         yqkga
# 150  [1.0, 2.0, 3.0]         yqkga
# 151  [1.0, 2.0, 3.0]         yqkga

# %% [markdown]
# Hungarian matching algorithm doesn't always make matches that break the natural order of pKa values.
# Only in cases where the order preserving match and the unordered match have the same cost value, then the results are random.
#
# The hungarian collection set of branch `pKa_typeIII_analysis5` (commit b1bef28) doesn't have any unordered matches.
# The hungarian collection set of branch `pKa_typeIII_analysis3` (commit 70d828e) has unordered matched for SM18 pKas for the following submission files:
# 0hxtm, yqkga, ryzue, yc70m

# %% [markdown]
# ### Was there a out of order match in the latest type III analysis run?
#  sampl6-physicochemical-properties reporistory
#  commit 389a9540 "Rerun type III analysis 20190913."

# %%
#https://github.com/choderalab/sampl6-physicochemical-properties/blob/master/analysis_of_pKa_predictions/analysis_of_typeIII_predictions/analysis_outputs_hungarian/typeIII_submission_collection.csv
hungarian_collection = "typeIII_submission_collection_hungarian_3891954.csv"

df_hungarian = pd.read_csv(hungarian_collection, index_col=0)

df_hungarian.head()
# Out:
#    $\Delta$pKa error (calc - exp) Molecule ID  \
# 0                            0.61        SM01
# 1                           -0.10        SM02
# 2                            0.50        SM03
# 3                           -0.85        SM04
# 4                           -0.23        SM05
#
#                                                 name  pKa (calc)  pKa (exp)  \
# 0  Full quantum chemical calculation of free ener...       10.14       9.53
# 1  Full quantum chemical calculation of free ener...        4.93       5.03
# 2  Full quantum chemical calculation of free ener...        7.52       7.02
# 3  Full quantum chemical calculation of free ener...        5.17       6.02
# 4  Full quantum chemical calculation of free ener...        4.36       4.59
#
#       pKa ID  pKa SEM (calc)  pKa SEM (exp)     participant receipt_id
# 0  SM01_pKa1            0.35           0.01  Philipp Pracht      xvxzd
# 1  SM02_pKa1            0.27           0.01  Philipp Pracht      xvxzd
# 2  SM03_pKa1            0.31           0.01  Philipp Pracht      xvxzd
# 3  SM04_pKa1            0.28           0.01  Philipp Pracht      xvxzd
# 4  SM05_pKa1            0.27           0.01  Philipp Pracht      xvxzd

# %%
prediction_methods = set(df_hungarian["name"])

pKa_rank_comparison_list =[]

# Iterate through methods
for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:

    submission_ID = df_hungarian[df_hungarian["name"] == method]["receipt_id"].values[0]
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    mol_IDs = list(df_hungarian_1method["Molecule ID"])

    #Iterate through molecules
    for mol_ID in mol_IDs:
        df_hungarian_1method_1mol = df_hungarian_1method[df_hungarian_1method["Molecule ID"] == mol_ID].reset_index(drop=True)
        
        pKa_IDs = df_hungarian_1method_1mol['pKa ID'].values
        
        #Assign Rank order of experimental and predicted pKa.
        exp_pKas = df_hungarian_1method_1mol['pKa (exp)'].values 
        exp_pKa_ranks = ss.rankdata(exp_pKas )
        
        
        pred_pKas = df_hungarian_1method_1mol['pKa (calc)'].values
        pred_pKa_ranks = ss.rankdata(pred_pKas) # rank is given to only matched pred pKas

    
        # Is rank order the same?
        if list(exp_pKa_ranks) == list(pred_pKa_ranks):
            ordered_match = True
        else:
            ordered_match = False

        
        pKa_rank_comparison_list.append([mol_ID, ordered_match, pKa_IDs, exp_pKas, pred_pKas, exp_pKa_ranks, pred_pKa_ranks, submission_ID])
    
    
# Convert to pandas dataframe
df_compare_ranks_hungarian = pd.DataFrame(pKa_rank_comparison_list, columns = ['mol ID', 'ordered match', 'pKa IDs', 'pKa (exp)', 
                                               'pKa (pred)', 'pKa rank (exp)', 'pKa rank (pred)', 'submission ID'])

# Print out pKas that don't preserve increasing order when matched my Hungarian algorithm
df_unordered_matching_hungarian = df_compare_ranks_hungarian[df_compare_ranks_hungarian["ordered match"] == False]
df_unordered_matching_hungarian
# Out:
# Empty DataFrame
# Columns: [mol ID, ordered match, pKa IDs, pKa (exp), pKa (pred), pKa rank (exp), pKa rank (pred), submission ID]
# Index: []

# %%
# Just SM18
df_unordered_matching_hungarian_SM18 = df_compare_ranks_hungarian[df_compare_ranks_hungarian["mol ID"] == 'SM18']

# SM18 prediction of yqkga method 
df_unordered_matching_hungarian_SM18_yqkga = df_unordered_matching_hungarian_SM18[df_compare_ranks_hungarian["submission ID"] == 'yqkga']
df_unordered_matching_hungarian_SM18_yqkga
# Out:
# /Users/isikm/opt/anaconda/envs/sampl6_pKa/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#     mol ID  ordered match                            pKa IDs  \
# 149   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
# 150   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
# 151   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
#
#                pKa (exp)          pKa (pred)   pKa rank (exp)  \
# 149  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
# 150  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
# 151  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
#
#      pKa rank (pred) submission ID
# 149  [1.0, 2.0, 3.0]         yqkga
# 150  [1.0, 2.0, 3.0]         yqkga
# 151  [1.0, 2.0, 3.0]         yqkga

# %% [markdown]
# Still, Hungarian matching doesn't produce any non-sequencial matches.
