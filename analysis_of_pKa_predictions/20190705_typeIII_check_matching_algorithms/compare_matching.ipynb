# %%
import numpy as np
import pandas as pd
import scipy.stats as ss

# %%
closest_collection = "typeIII_submission_collection_closest.csv"
hungarian_collection = "typeIII_submission_collection_hungarian.csv"

# %% [markdown]
# ## How many predicted pKas are matched differently between closest and hungarian algorithms?

# %%
df_closest = pd.read_csv(closest_collection,index_col=0)
df_closest.head()
# Out:
#    $\Delta$pKa error (calc - exp) Molecule ID               name  pKa (calc)  \
# 0                            0.18        SM01  COSMOtherm_FINE17        9.71
# 1                            1.18        SM02  COSMOtherm_FINE17        6.21
# 2                           -6.39        SM03  COSMOtherm_FINE17        0.63
# 3                           -0.61        SM04  COSMOtherm_FINE17        5.41
# 4                           -0.06        SM05  COSMOtherm_FINE17        4.53
#
#    pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)    participant  \
# 0       9.53  SM01_pKa1            0.65           0.01  Chris Loschen
# 1       5.03  SM02_pKa1            0.65           0.01  Chris Loschen
# 2       7.02  SM03_pKa1            0.65           0.01  Chris Loschen
# 3       6.02  SM04_pKa1            0.65           0.01  Chris Loschen
# 4       4.59  SM05_pKa1            0.65           0.01  Chris Loschen
#
#   receipt_id
# 0      0hxtm
# 1      0hxtm
# 2      0hxtm
# 3      0hxtm
# 4      0hxtm

# %%
df_hungarian = pd.read_csv(hungarian_collection, index_col=0)
df_hungarian.head()
# Out:
#    $\Delta$pKa error (calc - exp) Molecule ID               name  pKa (calc)  \
# 0                            0.18        SM01  COSMOtherm_FINE17        9.71
# 1                            1.18        SM02  COSMOtherm_FINE17        6.21
# 2                           -6.39        SM03  COSMOtherm_FINE17        0.63
# 3                           -0.61        SM04  COSMOtherm_FINE17        5.41
# 4                           -0.06        SM05  COSMOtherm_FINE17        4.53
#
#    pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)    participant  \
# 0       9.53  SM01_pKa1            0.65           0.01  Chris Loschen
# 1       5.03  SM02_pKa1            0.65           0.01  Chris Loschen
# 2       7.02  SM03_pKa1            0.65           0.01  Chris Loschen
# 3       6.02  SM04_pKa1            0.65           0.01  Chris Loschen
# 4       4.59  SM05_pKa1            0.65           0.01  Chris Loschen
#
#   receipt_id
# 0      0hxtm
# 1      0hxtm
# 2      0hxtm
# 3      0hxtm
# 4      0hxtm

# %%
prediction_methods = set(df_closest["name"])
len(prediction_methods)
# Out:
# 34

# %%
# Iterate through prediction methods and create a database that compares hunagarian and closest matching

matched_pKa_list = []

for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:
    
    submission_id = df_closest[df_closest["name"] == method]["receipt_id"].values[0]
    
    df_closest_1method = df_closest[df_closest["name"] == method].reset_index(drop=True)    
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    pKa_IDs = list(df_closest_1method["pKa ID"])
  
    # Iterate through pKa_IDs to check if predicted pKas match
    for pKa_ID in pKa_IDs:
        pKa_exp = df_closest_1method[df_closest_1method["pKa ID"] == pKa_ID]["pKa (exp)"].values[0]
        pKa_pred_closest = df_closest_1method[df_closest_1method["pKa ID"] == pKa_ID]["pKa (calc)"].values[0]
        pKa_pred_hungarian = df_hungarian_1method[df_hungarian_1method["pKa ID"] == pKa_ID]["pKa (calc)"].values[0]
        closest_hungarian_diff = pKa_pred_closest - pKa_pred_hungarian
                
        matched_pKa_row = [pKa_ID, pKa_exp, pKa_pred_closest, pKa_pred_hungarian, closest_hungarian_diff, submission_id]
        matched_pKa_list.append(matched_pKa_row)
        #print(matched_pKa_row)

# Convert to pandas dataframe
df_compare_matching = pd.DataFrame(matched_pKa_list, columns = ['pKa ID', 'pKa (exp)', 
                                               'pKa (pred, closest)', 'pKa (pred, hungarian)',
                                              'closest - hungarian diff.', 'submission ID'])
df_compare_matching.head()
# Out:
#       pKa ID  pKa (exp)  pKa (pred, closest)  pKa (pred, hungarian)  \
# 0  SM01_pKa1       9.53                13.34                  13.34
# 1  SM02_pKa1       5.03                 3.43                   3.43
# 2  SM03_pKa1       7.02                 7.49                   7.49
# 3  SM04_pKa1       6.02                 4.69                   4.69
# 4  SM05_pKa1       4.59                 1.39                   1.39
#
#    closest - hungarian diff. submission ID
# 0                        0.0         xikp8
# 1                        0.0         xikp8
# 2                        0.0         xikp8
# 3                        0.0         xikp8
# 4                        0.0         xikp8

# %%
# Print out pKas that have different matching between hungarian and closest
df_difference_in_matching = df_compare_matching[df_compare_matching["closest - hungarian diff."] != 0]
df_difference_in_matching
# Out:
#         pKa ID  pKa (exp)  pKa (pred, closest)  pKa (pred, hungarian)  \
# 20   SM18_pKa3      11.02                10.56                  13.45
# 43   SM14_pKa1       2.58                 3.38                  -1.77
# 44   SM14_pKa2       5.30                24.63                   3.38
# 51   SM18_pKa3      11.02                11.53                  11.75
# 141  SM18_pKa2       9.58                 9.59                   8.38
# 155  SM06_pKa1       3.03                 3.98                   0.98
# 183  SM06_pKa1       3.03                 4.40                   1.38
# 196  SM18_pKa1       2.15                 1.84                   0.50
# 248  SM14_pKa1       2.58                 3.81                   0.42
# 249  SM14_pKa2       5.30                18.84                   3.81
# 285  SM18_pKa2       9.58                 9.87                   3.35
# 305  SM14_pKa1       2.58                 3.94                   0.14
# 306  SM14_pKa2       5.30                19.65                   3.94
# 342  SM18_pKa2       9.58                 7.43                   6.60
# 391  SM14_pKa1       2.58                 3.94                   0.15
# 392  SM14_pKa2       5.30                19.58                   3.94
# 465  SM22_pKa1       2.40                 4.82                  -1.34
# 495  SM18_pKa2       9.58                 9.91                   9.24
# 525  SM18_pKa2       9.58                 9.26                   7.53
# 547  SM14_pKa1       2.58                 3.84                   0.47
# 548  SM14_pKa2       5.30                19.09                   3.84
# 638  SM14_pKa1       2.58                 3.74                  -1.40
# 639  SM14_pKa2       5.30                18.61                   3.74
# 651  SM22_pKa1       2.40                 4.23                  -3.77
# 688  SM06_pKa1       3.03                 3.94                   1.77
# 732  SM18_pKa2       9.58                10.02                   8.39
# 768  SM18_pKa3      11.02                10.97                  13.98
# 887  SM18_pKa2       9.58                 9.51                   7.59
# 941  SM14_pKa1       2.58                 3.86                  -0.90
# 942  SM14_pKa2       5.30                23.88                   3.86
#
#      closest - hungarian diff. submission ID
# 20                       -2.89         xikp8
# 43                        5.15         nb006
# 44                       21.25         nb006
# 51                       -0.22         nb006
# 141                       1.21         5byn6
# 155                       3.00         q3pfp
# 183                       3.02         0hxtm
# 196                       1.34         0hxtm
# 248                       3.39         mpwiy
# 249                      15.03         mpwiy
# 285                       6.52         pwn3m
# 305                       3.80         nb003
# 306                      15.71         nb003
# 342                       0.83         yc70m
# 391                       3.79         nb004
# 392                      15.64         nb004
# 465                       6.16         2ii2g
# 495                       0.67         nb002
# 525                       1.73         yqkga
# 547                       3.37         ttjd0
# 548                      15.25         ttjd0
# 638                       5.14         ds62k
# 639                      14.87         ds62k
# 651                       8.00         ds62k
# 688                       2.17         hytjn
# 732                       1.63         w4iyd
# 768                      -3.01         ad5pu
# 887                       1.92         ryzue
# 941                       4.76         nb005
# 942                      20.02         nb005

# %%
# Why is nb006 SM14_pKa2 matched to a very different number?

# These are submitted SM14 predictions
# SM14, -1.77, 1.77
# SM14,  3.38, 1.77
# SM14, 24.63, 1.77


# SM14 Experimental values
# 2.58 ± 0.01
# 5.30 ± 0.01


df_nb006 = df_closest[df_closest['receipt_id']=='nb006']
df_nb006_SM14 = df_nb006[df_nb006['Molecule ID']=='SM14']
df_nb006_SM14
# Out:
#      $\Delta$pKa error (calc - exp) Molecule ID  \
# 553                            0.80        SM14
# 554                           19.33        SM14
#
#                                            name  pKa (calc)  pKa (exp)  \
# 553  EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        3.38       2.58
# 554  EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par       24.63       5.30
#
#         pKa ID  pKa SEM (calc)  pKa SEM (exp)  participant receipt_id
# 553  SM14_pKa1            1.77           0.01  Stefan Kast      nb006
# 554  SM14_pKa2            1.77           0.01  Stefan Kast      nb006

# %%
df_nb006 = df_hungarian[df_hungarian['receipt_id']=='nb006']
df_nb006_SM14 = df_nb006[df_nb006['Molecule ID']=='SM14']
df_nb006_SM14
# Out:
#      $\Delta$pKa error (calc - exp) Molecule ID  \
# 568                           -4.35        SM14
# 569                           -1.92        SM14
#
#                                            name  pKa (calc)  pKa (exp)  \
# 568  EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par       -1.77       2.58
# 569  EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        3.38       5.30
#
#         pKa ID  pKa SEM (calc)  pKa SEM (exp)  participant receipt_id
# 568  SM14_pKa1            1.77           0.01  Stefan Kast      nb006
# 569  SM14_pKa2            1.77           0.01  Stefan Kast      nb006

# %% [markdown]
# ### Experimental pKas of molecules with pKas differently matched
# SM06
# 3.03 ± 0.04
# 11.74 ± 0.01
#
# SM14
# 2.58 ± 0.01
# 5.30 ± 0.01
#
# SM18
# 2.15 ± 0.02
# 9.58 ± 0.03
# 11.02 ± 0.04
#
# SM22
# 2.40 ± 0.02
# 7.43 ± 0.01
#
# ### Experimental pKas of molecules with pKas equally matched even thought they have multiple pKas
# SM15
# 4.70 ± 0.01
# 8.94 ± 0.01
#
# SM16
# 5.37 ± 0.01
# 10.65 ± 0.01

# %% [markdown]
# ## How many pKa predictions are matched without conserving the sequence with Hungarian method?

# %%
# Test for comparing rank orders - ORDERED MATCH
exp_pKas = np.array([2.4, 4.3, 7.0])
pred_pKas = np.array([2.5, 4.2, 7.2])

#exp_pKa_ranks = list(np.array([1, 3, 2]))
#pred_pKa_ranks = list(np.array([1, 3, 2]))

exp_pKa_ranks = ss.rankdata(exp_pKas)
print("exp ranks:", exp_pKa_ranks)
pred_pKa_ranks = ss.rankdata(pred_pKas)
print("pred ranks:", pred_pKa_ranks)

# Is rank order the same?
if list(exp_pKa_ranks) == list(pred_pKa_ranks):
    ordered_match = True
else:
    ordered_match = False
    
ordered_match
# Out:
# exp ranks: [ 1.  2.  3.]
# pred ranks: [ 1.  2.  3.]
# True

# %%
# Test for comparing rank orders - UNORDERED MATCH
exp_pKas = np.array([2.4, 4.3, 7.0])
pred_pKas = np.array([2.5, 7.0, 4.5])

#exp_pKa_ranks = list(np.array([1, 3, 2]))
#pred_pKa_ranks = list(np.array([1, 3, 2]))

exp_pKa_ranks = ss.rankdata(exp_pKas)
print("exp ranks:", exp_pKa_ranks)
pred_pKa_ranks = ss.rankdata(pred_pKas)
print("pred ranks:", pred_pKa_ranks)

# Is rank order the same?
if list(exp_pKa_ranks) == list(pred_pKa_ranks):
    ordered_match = True
else:
    ordered_match = False
    
ordered_match
# Out:
# exp ranks: [ 1.  2.  3.]
# pred ranks: [ 1.  3.  2.]
# False

# %%
df_hungarian.head()
# Out:
#    $\Delta$pKa error (calc - exp) Molecule ID               name  pKa (calc)  \
# 0                            0.18        SM01  COSMOtherm_FINE17        9.71
# 1                            1.18        SM02  COSMOtherm_FINE17        6.21
# 2                           -6.39        SM03  COSMOtherm_FINE17        0.63
# 3                           -0.61        SM04  COSMOtherm_FINE17        5.41
# 4                           -0.06        SM05  COSMOtherm_FINE17        4.53
#
#    pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)    participant  \
# 0       9.53  SM01_pKa1            0.65           0.01  Chris Loschen
# 1       5.03  SM02_pKa1            0.65           0.01  Chris Loschen
# 2       7.02  SM03_pKa1            0.65           0.01  Chris Loschen
# 3       6.02  SM04_pKa1            0.65           0.01  Chris Loschen
# 4       4.59  SM05_pKa1            0.65           0.01  Chris Loschen
#
#   receipt_id
# 0      0hxtm
# 1      0hxtm
# 2      0hxtm
# 3      0hxtm
# 4      0hxtm

# %%
pKa_rank_comparison_list =[]

# Iterate through methods
for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:

    submission_ID = df_hungarian[df_hungarian["name"] == method]["receipt_id"].values[0]
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    mol_IDs = list(df_hungarian_1method["Molecule ID"])

    #Iterate through molecules
    for mol_ID in mol_IDs:
        df_hungarian_1method_1mol = df_hungarian_1method[df_hungarian_1method["Molecule ID"] == mol_ID].reset_index(drop=True)
        
        pKa_IDs = df_hungarian_1method_1mol['pKa ID'].values
        
        #Assign Rank order of experimental and predicted pKa.
        exp_pKas = df_hungarian_1method_1mol['pKa (exp)'].values 
        exp_pKa_ranks = ss.rankdata(exp_pKas )
        
        
        pred_pKas = df_hungarian_1method_1mol['pKa (calc)'].values
        pred_pKa_ranks = ss.rankdata(pred_pKas) # rank is given to only matched pred pKas

    
        # Is rank order the same?
        if list(exp_pKa_ranks) == list(pred_pKa_ranks):
            ordered_match = True
        else:
            ordered_match = False

        
        pKa_rank_comparison_list.append([mol_ID, ordered_match, pKa_IDs, exp_pKas, pred_pKas, exp_pKa_ranks, pred_pKa_ranks, submission_ID])
    
    
# Convert to pandas dataframe
df_compare_ranks_hungarian = pd.DataFrame(pKa_rank_comparison_list, columns = ['mol ID', 'ordered match', 'pKa IDs', 'pKa (exp)', 
                                               'pKa (pred)', 'pKa rank (exp)', 'pKa rank (pred)', 'submission ID'])
df_compare_ranks_hungarian = df_compare_ranks_hungarian.astype(str)
df_compare_ranks_hungarian = df_compare_ranks_hungarian.drop_duplicates()
df_compare_ranks_hungarian
# Out:
#     mol ID ordered match                                pKa IDs  \
# 0     SM01          True                          ['SM01_pKa1']
# 1     SM02          True                          ['SM02_pKa1']
# 2     SM03          True                          ['SM03_pKa1']
# 3     SM04          True                          ['SM04_pKa1']
# 4     SM05          True                          ['SM05_pKa1']
# 5     SM06          True              ['SM06_pKa2' 'SM06_pKa1']
# 7     SM07          True                          ['SM07_pKa1']
# 8     SM08          True                          ['SM08_pKa1']
# 9     SM09          True                          ['SM09_pKa1']
# 10    SM10          True                          ['SM10_pKa1']
# 11    SM11          True                          ['SM11_pKa1']
# 12    SM12          True                          ['SM12_pKa1']
# 13    SM13          True                          ['SM13_pKa1']
# 14    SM14          True                          ['SM14_pKa1']
# 15    SM15          True              ['SM15_pKa2' 'SM15_pKa1']
# 17    SM16          True              ['SM16_pKa2' 'SM16_pKa1']
# 19    SM17          True                          ['SM17_pKa1']
# 20    SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 23    SM19          True                          ['SM19_pKa1']
# 24    SM20          True                          ['SM20_pKa1']
# 25    SM21          True                          ['SM21_pKa1']
# 26    SM22          True              ['SM22_pKa2' 'SM22_pKa1']
# 28    SM23          True                          ['SM23_pKa1']
# 29    SM24          True                          ['SM24_pKa1']
# 30    SM01          True                          ['SM01_pKa1']
# 31    SM02          True                          ['SM02_pKa1']
# 32    SM03          True                          ['SM03_pKa1']
# 33    SM04          True                          ['SM04_pKa1']
# 34    SM05          True                          ['SM05_pKa1']
# 35    SM06          True              ['SM06_pKa1' 'SM06_pKa2']
# ..     ...           ...                                    ...
# 947   SM19          True                          ['SM19_pKa1']
# 948   SM20          True                          ['SM20_pKa1']
# 949   SM21          True                          ['SM21_pKa1']
# 950   SM22          True              ['SM22_pKa1' 'SM22_pKa2']
# 952   SM23          True                          ['SM23_pKa1']
# 953   SM24          True                          ['SM24_pKa1']
# 954   SM01          True                          ['SM01_pKa1']
# 955   SM02          True                          ['SM02_pKa1']
# 956   SM03          True                          ['SM03_pKa1']
# 957   SM04          True                          ['SM04_pKa1']
# 958   SM05          True                          ['SM05_pKa1']
# 959   SM06          True              ['SM06_pKa1' 'SM06_pKa2']
# 961   SM07          True                          ['SM07_pKa1']
# 962   SM08          True                          ['SM08_pKa1']
# 963   SM09          True                          ['SM09_pKa1']
# 964   SM10          True                          ['SM10_pKa1']
# 965   SM11          True                          ['SM11_pKa1']
# 966   SM12          True                          ['SM12_pKa1']
# 967   SM13          True                          ['SM13_pKa1']
# 968   SM14          True              ['SM14_pKa1' 'SM14_pKa2']
# 970   SM15          True              ['SM15_pKa1' 'SM15_pKa2']
# 972   SM16          True              ['SM16_pKa1' 'SM16_pKa2']
# 974   SM17          True                          ['SM17_pKa1']
# 975   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 978   SM19          True                          ['SM19_pKa1']
# 979   SM20          True                          ['SM20_pKa1']
# 980   SM21          True                          ['SM21_pKa1']
# 981   SM22          True              ['SM22_pKa1' 'SM22_pKa2']
# 983   SM23          True                          ['SM23_pKa1']
# 984   SM24          True                          ['SM24_pKa1']
#
#                   pKa (exp)              pKa (pred) pKa rank (exp)  \
# 0                   [ 9.53]                [ 13.34]          [ 1.]
# 1                   [ 5.03]                 [ 3.43]          [ 1.]
# 2                   [ 7.02]                 [ 7.49]          [ 1.]
# 3                   [ 6.02]                 [ 4.69]          [ 1.]
# 4                   [ 4.59]                 [ 1.39]          [ 1.]
# 5           [ 11.74   3.03]         [ 14.52  -1.29]      [ 2.  1.]
# 7                   [ 6.08]                 [ 5.44]          [ 1.]
# 8                   [ 4.22]                 [ 5.13]          [ 1.]
# 9                   [ 5.37]                 [ 3.63]          [ 1.]
# 10                  [ 9.02]                 [ 9.58]          [ 1.]
# 11                  [ 3.89]                  [ 1.2]          [ 1.]
# 12                  [ 5.28]                 [ 3.08]          [ 1.]
# 13                  [ 5.77]                 [ 3.02]          [ 1.]
# 14                  [ 2.58]                 [ 3.15]          [ 1.]
# 15            [ 8.94  4.7 ]         [ 11.9    2.06]      [ 2.  1.]
# 17          [ 10.65   5.37]         [ 12.16   2.13]      [ 2.  1.]
# 19                  [ 3.16]                 [ 0.11]          [ 1.]
# 20   [ 11.02   9.58   2.15]  [ 13.45  10.56   0.1 ]  [ 3.  2.  1.]
# 23                  [ 9.56]                [ 10.52]          [ 1.]
# 24                   [ 5.7]                 [ 4.01]          [ 1.]
# 25                   [ 4.1]                  [ 0.2]          [ 1.]
# 26            [ 7.43  2.4 ]           [ 8.74  1.49]      [ 2.  1.]
# 28                  [ 5.45]                 [ 1.68]          [ 1.]
# 29                   [ 2.6]                 [ 1.88]          [ 1.]
# 30                  [ 9.53]                [ 10.38]          [ 1.]
# 31                  [ 5.03]                  [ 3.3]          [ 1.]
# 32                  [ 7.02]                [ 11.08]          [ 1.]
# 33                  [ 6.02]                 [ 4.18]          [ 1.]
# 34                  [ 4.59]                 [ 6.62]          [ 1.]
# 35          [  3.03  11.74]         [ -1.31  15.19]      [ 1.  2.]
# ..                      ...                     ...            ...
# 947                 [ 9.56]                 [ 12.4]          [ 1.]
# 948                  [ 5.7]                 [ 7.34]          [ 1.]
# 949                  [ 4.1]                 [ 3.45]          [ 1.]
# 950           [ 2.4   7.43]           [ 1.72  8.46]      [ 1.  2.]
# 952                 [ 5.45]                 [ 5.76]          [ 1.]
# 953                  [ 2.6]                 [ 5.22]          [ 1.]
# 954                 [ 9.53]                 [ 9.83]          [ 1.]
# 955                 [ 5.03]                  [ 3.7]          [ 1.]
# 956                 [ 7.02]                [ 10.58]          [ 1.]
# 957                 [ 6.02]                 [ 4.53]          [ 1.]
# 958                 [ 4.59]                 [ 6.97]          [ 1.]
# 959         [  3.03  11.74]         [  0.62  12.89]      [ 1.  2.]
# 961                 [ 6.08]                 [ 2.01]          [ 1.]
# 962                 [ 4.22]                  [ 4.4]          [ 1.]
# 963                 [ 5.37]                 [ 4.75]          [ 1.]
# 964                 [ 9.02]                [ 11.16]          [ 1.]
# 965                 [ 3.89]                 [ 2.89]          [ 1.]
# 966                 [ 5.28]                 [ 4.92]          [ 1.]
# 967                 [ 5.77]                 [ 6.07]          [ 1.]
# 968           [ 2.58  5.3 ]           [-0.9   3.86]      [ 1.  2.]
# 970           [ 4.7   8.94]         [  2.44  11.29]      [ 1.  2.]
# 972         [  5.37  10.65]         [  4.81  13.82]      [ 1.  2.]
# 974                 [ 3.16]                 [ 3.63]          [ 1.]
# 975  [  2.15  11.02   9.58]  [  0.57  11.46  10.57]  [ 1.  3.  2.]
# 978                 [ 9.56]                [ 13.33]          [ 1.]
# 979                  [ 5.7]                 [ 7.68]          [ 1.]
# 980                  [ 4.1]                 [-0.27]          [ 1.]
# 981           [ 2.4   7.43]           [-3.77  9.08]      [ 1.  2.]
# 983                 [ 5.45]                 [ 3.46]          [ 1.]
# 984                  [ 2.6]                 [ 1.21]          [ 1.]
#
#     pKa rank (pred) submission ID
# 0             [ 1.]         xikp8
# 1             [ 1.]         xikp8
# 2             [ 1.]         xikp8
# 3             [ 1.]         xikp8
# 4             [ 1.]         xikp8
# 5         [ 2.  1.]         xikp8
# 7             [ 1.]         xikp8
# 8             [ 1.]         xikp8
# 9             [ 1.]         xikp8
# 10            [ 1.]         xikp8
# 11            [ 1.]         xikp8
# 12            [ 1.]         xikp8
# 13            [ 1.]         xikp8
# 14            [ 1.]         xikp8
# 15        [ 2.  1.]         xikp8
# 17        [ 2.  1.]         xikp8
# 19            [ 1.]         xikp8
# 20    [ 3.  2.  1.]         xikp8
# 23            [ 1.]         xikp8
# 24            [ 1.]         xikp8
# 25            [ 1.]         xikp8
# 26        [ 2.  1.]         xikp8
# 28            [ 1.]         xikp8
# 29            [ 1.]         xikp8
# 30            [ 1.]         nb006
# 31            [ 1.]         nb006
# 32            [ 1.]         nb006
# 33            [ 1.]         nb006
# 34            [ 1.]         nb006
# 35        [ 1.  2.]         nb006
# ..              ...           ...
# 947           [ 1.]         mkhqa
# 948           [ 1.]         mkhqa
# 949           [ 1.]         mkhqa
# 950       [ 1.  2.]         mkhqa
# 952           [ 1.]         mkhqa
# 953           [ 1.]         mkhqa
# 954           [ 1.]         nb005
# 955           [ 1.]         nb005
# 956           [ 1.]         nb005
# 957           [ 1.]         nb005
# 958           [ 1.]         nb005
# 959       [ 1.  2.]         nb005
# 961           [ 1.]         nb005
# 962           [ 1.]         nb005
# 963           [ 1.]         nb005
# 964           [ 1.]         nb005
# 965           [ 1.]         nb005
# 966           [ 1.]         nb005
# 967           [ 1.]         nb005
# 968       [ 1.  2.]         nb005
# 970       [ 1.  2.]         nb005
# 972       [ 1.  2.]         nb005
# 974           [ 1.]         nb005
# 975   [ 1.  3.  2.]         nb005
# 978           [ 1.]         nb005
# 979           [ 1.]         nb005
# 980           [ 1.]         nb005
# 981       [ 1.  2.]         nb005
# 983           [ 1.]         nb005
# 984           [ 1.]         nb005
#
# [773 rows x 8 columns]

# %%
# Print out pKas that don't preserve increasing order when matched my Hungarian algorithm
df_unordered_matching_hungarian = df_compare_ranks_hungarian[df_compare_ranks_hungarian["ordered match"] == False]
df_unordered_matching_hungarian
# Out:
# Empty DataFrame
# Columns: [mol ID, ordered match, pKa IDs, pKa (exp), pKa (pred), pKa rank (exp), pKa rank (pred), submission ID]
# Index: []

# %%
# Just SM18
df_unordered_matching_hungarian_SM18 = df_compare_ranks_hungarian[df_compare_ranks_hungarian["mol ID"] == 'SM18']
df_unordered_matching_hungarian_SM18
# Out:
#     mol ID ordered match                                pKa IDs  \
# 20    SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 51    SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 82    SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 113   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 144   SM18          True  ['SM18_pKa2' 'SM18_pKa3' 'SM18_pKa1']
# 174   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 203   SM18          True              ['SM18_pKa2' 'SM18_pKa1']
# 233   SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 264   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 294   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 323   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 354   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 382   SM18          True              ['SM18_pKa1' 'SM18_pKa2']
# 412   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 443   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 474   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 510   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 541   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 572   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 603   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 634   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 665   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 695   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 725   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 756   SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 792   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 823   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 853   SM18          True              ['SM18_pKa1' 'SM18_pKa2']
# 882   SM18          True  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
# 913   SM18          True  ['SM18_pKa2' 'SM18_pKa3' 'SM18_pKa1']
# 944   SM18          True  ['SM18_pKa1' 'SM18_pKa2' 'SM18_pKa3']
# 975   SM18          True  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
#
#                   pKa (exp)              pKa (pred) pKa rank (exp)  \
# 20   [ 11.02   9.58   2.15]  [ 13.45  10.56   0.1 ]  [ 3.  2.  1.]
# 51   [  2.15  11.02   9.58]  [  0.18  11.75  11.53]  [ 1.  3.  2.]
# 82   [  2.15  11.02   9.58]     [ 1.82  9.97  9.3 ]  [ 1.  3.  2.]
# 113  [  2.15  11.02   9.58]  [  0.95  10.91   9.5 ]  [ 1.  3.  2.]
# 144  [  9.58  11.02   2.15]     [ 8.38  9.59  1.11]  [ 2.  3.  1.]
# 174  [  2.15   9.58  11.02]  [ -0.72   5.21  11.1 ]  [ 1.  2.  3.]
# 203           [ 9.58  2.15]           [ 1.84  0.5 ]      [ 2.  1.]
# 233  [ 11.02   9.58   2.15]  [ 10.23   9.21   2.02]  [ 3.  2.  1.]
# 264  [  2.15   9.58  11.02]  [  2.05   9.7   10.39]  [ 1.  2.  3.]
# 294  [  2.15   9.58  11.02]     [ 2.    3.35  9.87]  [ 1.  2.  3.]
# 323  [  2.15  11.02   9.58]  [  1.58  10.13   9.97]  [ 1.  3.  2.]
# 354  [  2.15   9.58  11.02]     [ 4.29  6.6   7.43]  [ 1.  2.  3.]
# 382           [ 2.15  9.58]             [ 2.1  9.9]      [ 1.  2.]
# 412  [  2.15  11.02   9.58]  [  1.58  10.1    9.94]  [ 1.  3.  2.]
# 443  [  2.15  11.02   9.58]  [  3.38  11.15   9.95]  [ 1.  3.  2.]
# 474  [  2.15   9.58  11.02]  [  3.15   9.66  11.63]  [ 1.  2.  3.]
# 510  [  2.15  11.02   9.58]     [ 1.81  9.91  9.24]  [ 1.  3.  2.]
# 541  [  2.15   9.58  11.02]     [ 2.14  7.53  9.26]  [ 1.  2.  3.]
# 572  [  2.15   9.58  11.02]  [  2.     9.73  10.23]  [ 1.  2.  3.]
# 603  [  2.15   9.58  11.02]     [ 2.34  9.39  9.92]  [ 1.  2.  3.]
# 634  [  2.15   9.58  11.02]  [  2.12   8.74  10.54]  [ 1.  2.  3.]
# 665  [  2.15   9.58  11.02]  [  0.95   9.43  12.75]  [ 1.  2.  3.]
# 695  [  2.15   9.58  11.02]  [  2.29   9.71  10.61]  [ 1.  2.  3.]
# 725  [  2.15   9.58  11.02]  [ -0.26   5.    10.98]  [ 1.  2.  3.]
# 756  [ 11.02   9.58   2.15]  [ 10.02   8.39   1.82]  [ 3.  2.  1.]
# 792  [  2.15   9.58  11.02]  [  2.59  10.97  13.98]  [ 1.  2.  3.]
# 823  [  2.15   9.58  11.02]  [  2.48   9.38  10.5 ]  [ 1.  2.  3.]
# 853           [ 2.15  9.58]           [ 2.08  8.52]      [ 1.  2.]
# 882  [ 11.02   9.58   2.15]  [ 12.61   8.94   0.67]  [ 3.  2.  1.]
# 913  [  9.58  11.02   2.15]     [ 7.59  9.51  1.41]  [ 2.  3.  1.]
# 944  [  2.15   9.58  11.02]  [  2.2    9.92  10.42]  [ 1.  2.  3.]
# 975  [  2.15  11.02   9.58]  [  0.57  11.46  10.57]  [ 1.  3.  2.]
#
#     pKa rank (pred) submission ID
# 20    [ 3.  2.  1.]         xikp8
# 51    [ 1.  3.  2.]         nb006
# 82    [ 1.  3.  2.]         nb001
# 113   [ 1.  3.  2.]         np6b4
# 144   [ 2.  3.  1.]         5byn6
# 174   [ 1.  2.  3.]         q3pfp
# 203       [ 2.  1.]         0hxtm
# 233   [ 3.  2.  1.]         gyuhx
# 264   [ 1.  2.  3.]         mpwiy
# 294   [ 1.  2.  3.]         pwn3m
# 323   [ 1.  3.  2.]         nb003
# 354   [ 1.  2.  3.]         yc70m
# 382       [ 1.  2.]         5nm4j
# 412   [ 1.  3.  2.]         nb004
# 443   [ 1.  3.  2.]         f0gew
# 474   [ 1.  2.  3.]         2ii2g
# 510   [ 1.  3.  2.]         nb002
# 541   [ 1.  2.  3.]         yqkga
# 572   [ 1.  2.  3.]         ttjd0
# 603   [ 1.  2.  3.]         xmyhm
# 634   [ 1.  2.  3.]         8xt50
# 665   [ 1.  2.  3.]         ds62k
# 695   [ 1.  2.  3.]         37xm8
# 725   [ 1.  2.  3.]         hytjn
# 756   [ 3.  2.  1.]         w4iyd
# 792   [ 1.  2.  3.]         ad5pu
# 823   [ 1.  2.  3.]         nb007
# 853       [ 1.  2.]         xvxzd
# 882   [ 3.  2.  1.]         y75vj
# 913   [ 2.  3.  1.]         ryzue
# 944   [ 1.  2.  3.]         mkhqa
# 975   [ 1.  3.  2.]         nb005

# %%
# SM18 prediction of 0hxtm method was also matched in expected order.
df_unordered_matching_hungarian_SM18_0hxtm = df_unordered_matching_hungarian_SM18[df_compare_ranks_hungarian["submission ID"] == '0hxtm']
df_unordered_matching_hungarian_SM18_0hxtm
# Out:
# /Users/isikm/opt/anaconda/envs/sampl6_pKa/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     mol ID ordered match                    pKa IDs      pKa (exp)  \
# 203   SM18          True  ['SM18_pKa2' 'SM18_pKa1']  [ 9.58  2.15]
#
#         pKa (pred) pKa rank (exp) pKa rank (pred) submission ID
# 203  [ 1.84  0.5 ]      [ 2.  1.]       [ 2.  1.]         0hxtm

# %% [markdown]
# There isn't any matches out of order in this set.
#
# ### Was there a out of order match in the past for Hungarian matching? Is it random for SM18 in 0hxtm submission?

# %%
# SAMPL6 repository branch pKa_typeIII_analysis3_hungarian
# https://github.com/MobleyLab/SAMPL6/blob/pKa_typeIII_analysis3_hungarian/physical_properties/pKa/analysis/analysis_of_typeIII_predictions/analysis_outputs_hungarian/typeIII_submission_collection.csv
hungarian_collection_a3 = 'typeIII_submission_collection_hungarian_analysis3.csv'
df_hungarian = pd.read_csv(hungarian_collection_a3, index_col=0)


pKa_rank_comparison_list =[]

# Iterate through methods
for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:

    submission_ID = df_hungarian[df_hungarian["name"] == method]["receipt_id"].values[0]
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    mol_IDs = list(df_hungarian_1method["Molecule ID"])

    #Iterate through molecules
    for mol_ID in mol_IDs:
        df_hungarian_1method_1mol = df_hungarian_1method[df_hungarian_1method["Molecule ID"] == mol_ID].reset_index(drop=True)
        
        pKa_IDs = df_hungarian_1method_1mol['pKa ID'].values
        
        #Assign Rank order of experimental and predicted pKa.
        exp_pKas = df_hungarian_1method_1mol['pKa (exp)'].values 
        exp_pKa_ranks = ss.rankdata(exp_pKas )
        
        
        pred_pKas = df_hungarian_1method_1mol['pKa (calc)'].values
        pred_pKa_ranks = ss.rankdata(pred_pKas) # rank is given to only matched pred pKas

    
        # Is rank order the same?
        if list(exp_pKa_ranks) == list(pred_pKa_ranks):
            ordered_match = True
        else:
            ordered_match = False

        
        pKa_rank_comparison_list.append([mol_ID, ordered_match, pKa_IDs, exp_pKas, pred_pKas, exp_pKa_ranks, pred_pKa_ranks, submission_ID])
    
    
# Convert to pandas dataframe
df_compare_ranks_hungarian = pd.DataFrame(pKa_rank_comparison_list, columns = ['mol ID', 'ordered match', 'pKa IDs', 'pKa (exp)', 
                                               'pKa (pred)', 'pKa rank (exp)', 'pKa rank (pred)', 'submission ID'])

# Print out pKas that don't preserve increasing order when matched my Hungarian algorithm
df_unordered_matching_hungarian = df_compare_ranks_hungarian[df_compare_ranks_hungarian["ordered match"] == False]
df_unordered_matching_hungarian = df_unordered_matching_hungarian.astype(str)
df_unordered_matching_hungarian = df_unordered_matching_hungarian.drop_duplicates()
df_unordered_matching_hungarian
# Out:
#     mol ID ordered match                                pKa IDs  \
# 203   SM18         False              ['SM18_pKa1' 'SM18_pKa2']
# 354   SM18         False  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 541   SM18         False  ['SM18_pKa1' 'SM18_pKa3' 'SM18_pKa2']
# 913   SM18         False  ['SM18_pKa3' 'SM18_pKa2' 'SM18_pKa1']
#
#                   pKa (exp)           pKa (pred) pKa rank (exp)  \
# 203           [ 2.15  9.58]        [ 1.84  0.5 ]      [ 1.  2.]
# 354  [  2.15  11.02   9.58]  [ 4.29  6.6   7.43]  [ 1.  3.  2.]
# 541  [  2.15  11.02   9.58]  [ 2.14  7.53  9.26]  [ 1.  3.  2.]
# 913  [ 11.02   9.58   2.15]  [ 7.59  9.51  1.41]  [ 3.  2.  1.]
#
#     pKa rank (pred) submission ID
# 203       [ 2.  1.]         0hxtm
# 354   [ 1.  2.  3.]         yc70m
# 541   [ 1.  2.  3.]         yqkga
# 913   [ 2.  3.  1.]         ryzue

# %%
# SAMPL6 repository branch pKa_typeIII_analysis5_hungarian
# https://github.com/MobleyLab/SAMPL6/blob/pKa_typeIII_analysis5/physical_properties/pKa/analysis/analysis_of_typeIII_predictions/analysis_outputs_hungarian/typeIII_submission_collection.csv
hungarian_collection_a5 = 'typeIII_submission_collection_hungarian_analysis5.csv'
df_hungarian = pd.read_csv(hungarian_collection_a5, index_col=0)


pKa_rank_comparison_list =[]

# Iterate through methods
for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:

    submission_ID = df_hungarian[df_hungarian["name"] == method]["receipt_id"].values[0]
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    mol_IDs = list(df_hungarian_1method["Molecule ID"])

    #Iterate through molecules
    for mol_ID in mol_IDs:
        df_hungarian_1method_1mol = df_hungarian_1method[df_hungarian_1method["Molecule ID"] == mol_ID].reset_index(drop=True)
        
        pKa_IDs = df_hungarian_1method_1mol['pKa ID'].values
        
        #Assign Rank order of experimental and predicted pKa.
        exp_pKas = df_hungarian_1method_1mol['pKa (exp)'].values 
        exp_pKa_ranks = ss.rankdata(exp_pKas )
        
        
        pred_pKas = df_hungarian_1method_1mol['pKa (calc)'].values
        pred_pKa_ranks = ss.rankdata(pred_pKas) # rank is given to only matched pred pKas

    
        # Is rank order the same?
        if list(exp_pKa_ranks) == list(pred_pKa_ranks):
            ordered_match = True
        else:
            ordered_match = False

        
        pKa_rank_comparison_list.append([mol_ID, ordered_match, pKa_IDs, exp_pKas, pred_pKas, exp_pKa_ranks, pred_pKa_ranks, submission_ID])
    
    
# Convert to pandas dataframe
df_compare_ranks_hungarian = pd.DataFrame(pKa_rank_comparison_list, columns = ['mol ID', 'ordered match', 'pKa IDs', 'pKa (exp)', 
                                               'pKa (pred)', 'pKa rank (exp)', 'pKa rank (pred)', 'submission ID'])

# Print out pKas that don't preserve increasing order when matched my Hungarian algorithm
df_unordered_matching_hungarian = df_compare_ranks_hungarian[df_compare_ranks_hungarian["ordered match"] == False]
df_unordered_matching_hungarian
# Out:
# Empty DataFrame
# Columns: [mol ID, ordered match, pKa IDs, pKa (exp), pKa (pred), pKa rank (exp), pKa rank (pred), submission ID]
# Index: []

# %%
# Just SM18
df_unordered_matching_hungarian_SM18 = df_compare_ranks_hungarian[df_compare_ranks_hungarian["mol ID"] == 'SM18']

# SM18 prediction of yqkga method 
df_unordered_matching_hungarian_SM18_yqkga = df_unordered_matching_hungarian_SM18[df_compare_ranks_hungarian["submission ID"] == 'yqkga']
df_unordered_matching_hungarian_SM18_yqkga
# Out:
# /Users/isikm/opt/anaconda/envs/sampl6_pKa/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#     mol ID  ordered match                            pKa IDs  \
# 541   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
# 542   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
# 543   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
#
#                pKa (exp)          pKa (pred)   pKa rank (exp)  \
# 541  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
# 542  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
# 543  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
#
#      pKa rank (pred) submission ID
# 541  [1.0, 2.0, 3.0]         yqkga
# 542  [1.0, 2.0, 3.0]         yqkga
# 543  [1.0, 2.0, 3.0]         yqkga

# %% [markdown]
# Hungarian matching algorithm doesn't always make matches that break the natural order of pKa values.
# Only in cases where the order preserving match and the unordered match have the same cost value, then the results are random.
#
# The hungarian collection set of branch `pKa_typeIII_analysis5` (commit b1bef28) doesn't have any unordered matches.
# The hungarian collection set of branch `pKa_typeIII_analysis3` (commit 70d828e) has unordered matched for SM18 pKas for the following submission files:
# 0hxtm, yqkga, ryzue, yc70m

# %% [markdown]
# ### Was there a out of order match in the latest type III analysis run?
#  sampl6-physicochemical-properties reporistory
#  commit 389a9540 "Rerun type III analysis 20190913."

# %%
#https://github.com/choderalab/sampl6-physicochemical-properties/blob/master/analysis_of_pKa_predictions/analysis_of_typeIII_predictions/analysis_outputs_hungarian/typeIII_submission_collection.csv
hungarian_collection = "typeIII_submission_collection_hungarian_3891954.csv"

df_hungarian = pd.read_csv(hungarian_collection, index_col=0)

df_hungarian.head()
# Out:
#    $\Delta$pKa error (calc - exp) Molecule ID  \
# 0                            0.61        SM01
# 1                           -0.10        SM02
# 2                            0.50        SM03
# 3                           -0.85        SM04
# 4                           -0.23        SM05
#
#                                                 name  pKa (calc)  pKa (exp)  \
# 0  Full quantum chemical calculation of free ener...       10.14       9.53
# 1  Full quantum chemical calculation of free ener...        4.93       5.03
# 2  Full quantum chemical calculation of free ener...        7.52       7.02
# 3  Full quantum chemical calculation of free ener...        5.17       6.02
# 4  Full quantum chemical calculation of free ener...        4.36       4.59
#
#       pKa ID  pKa SEM (calc)  pKa SEM (exp)     participant receipt_id
# 0  SM01_pKa1            0.35           0.01  Philipp Pracht      xvxzd
# 1  SM02_pKa1            0.27           0.01  Philipp Pracht      xvxzd
# 2  SM03_pKa1            0.31           0.01  Philipp Pracht      xvxzd
# 3  SM04_pKa1            0.28           0.01  Philipp Pracht      xvxzd
# 4  SM05_pKa1            0.27           0.01  Philipp Pracht      xvxzd

# %%
prediction_methods = set(df_hungarian["name"])

pKa_rank_comparison_list =[]

# Iterate through methods
for method in prediction_methods:
#for method in ["Full quantum chemical calculation of free energies and fit to experimental pKa"]:

    submission_ID = df_hungarian[df_hungarian["name"] == method]["receipt_id"].values[0]
    df_hungarian_1method = df_hungarian[df_hungarian["name"] == method].reset_index(drop=True)
     
    mol_IDs = list(df_hungarian_1method["Molecule ID"])

    #Iterate through molecules
    for mol_ID in mol_IDs:
        df_hungarian_1method_1mol = df_hungarian_1method[df_hungarian_1method["Molecule ID"] == mol_ID].reset_index(drop=True)
        
        pKa_IDs = df_hungarian_1method_1mol['pKa ID'].values
        
        #Assign Rank order of experimental and predicted pKa.
        exp_pKas = df_hungarian_1method_1mol['pKa (exp)'].values 
        exp_pKa_ranks = ss.rankdata(exp_pKas )
        
        
        pred_pKas = df_hungarian_1method_1mol['pKa (calc)'].values
        pred_pKa_ranks = ss.rankdata(pred_pKas) # rank is given to only matched pred pKas

    
        # Is rank order the same?
        if list(exp_pKa_ranks) == list(pred_pKa_ranks):
            ordered_match = True
        else:
            ordered_match = False

        
        pKa_rank_comparison_list.append([mol_ID, ordered_match, pKa_IDs, exp_pKas, pred_pKas, exp_pKa_ranks, pred_pKa_ranks, submission_ID])
    
    
# Convert to pandas dataframe
df_compare_ranks_hungarian = pd.DataFrame(pKa_rank_comparison_list, columns = ['mol ID', 'ordered match', 'pKa IDs', 'pKa (exp)', 
                                               'pKa (pred)', 'pKa rank (exp)', 'pKa rank (pred)', 'submission ID'])

# Print out pKas that don't preserve increasing order when matched my Hungarian algorithm
df_unordered_matching_hungarian = df_compare_ranks_hungarian[df_compare_ranks_hungarian["ordered match"] == False]
df_unordered_matching_hungarian
# Out:
# Empty DataFrame
# Columns: [mol ID, ordered match, pKa IDs, pKa (exp), pKa (pred), pKa rank (exp), pKa rank (pred), submission ID]
# Index: []

# %%
# Just SM18
df_unordered_matching_hungarian_SM18 = df_compare_ranks_hungarian[df_compare_ranks_hungarian["mol ID"] == 'SM18']

# SM18 prediction of yqkga method 
df_unordered_matching_hungarian_SM18_yqkga = df_unordered_matching_hungarian_SM18[df_compare_ranks_hungarian["submission ID"] == 'yqkga']
df_unordered_matching_hungarian_SM18_yqkga
# Out:
# /Users/isikm/opt/anaconda/envs/sampl6_pKa/lib/python3.6/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#     mol ID  ordered match                            pKa IDs  \
# 541   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
# 542   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
# 543   SM18           True  [SM18_pKa1, SM18_pKa2, SM18_pKa3]
#
#                pKa (exp)          pKa (pred)   pKa rank (exp)  \
# 541  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
# 542  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
# 543  [2.15, 9.58, 11.02]  [2.14, 7.53, 9.26]  [1.0, 2.0, 3.0]
#
#      pKa rank (pred) submission ID
# 541  [1.0, 2.0, 3.0]         yqkga
# 542  [1.0, 2.0, 3.0]         yqkga
# 543  [1.0, 2.0, 3.0]         yqkga

# %% [markdown]
# Still, Hungarian matching doesn't produce any non-sequencial matches.
