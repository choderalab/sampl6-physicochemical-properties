# %%
import pandas as pd
import numpy as np

# %%
df_exp = pd.read_csv("experimental_microstates.csv")
df_exp
# Out:
#   Microstate ID of A Microstate ID of HA Molecule ID  pKa (exp)  \
# 0      SM07_micro004       SM07_micro006        SM07       6.08
# 1      SM14_micro001       SM14_micro002        SM14       5.30
# 2      SM14_micro002       SM14_micro003        SM14       2.58
# 3      SM02_micro001       SM02_micro004        SM02       5.03
# 4      SM04_micro003       SM04_micro002        SM04       6.02
# 5      SM09_micro003       SM09_micro001        SM09       5.37
# 6      SM12_micro012       SM12_micro006        SM12       5.28
# 7      SM13_micro005       SM13_micro001        SM13       5.77
# 8      SM15_micro004       SM15_micro002        SM15       8.94
# 9      SM15_micro002       SM15_micro003        SM15       4.70
#
#    pKa SEM (exp)     pKa ID         Microstate identification source
# 0           0.01  SM07_pKa1                          NMR measurement
# 1           0.01  SM14_pKa2                          NMR measurement
# 2           0.01  SM14_pKa1                          NMR measurement
# 3           0.01  SM02_pKa1  Estimated based on SM07 NMR measurement
# 4           0.01  SM04_pKa1  Estimated based on SM07 NMR measurement
# 5           0.01  SM09_pKa1  Estimated based on SM07 NMR measurement
# 6           0.01  SM12_pKa1  Estimated based on SM07 NMR measurement
# 7           0.01  SM13_pKa1  Estimated based on SM07 NMR measurement
# 8           0.01  SM15_pKa2  Estimated based on SM14 NMR measurement
# 9           0.01  SM15_pKa1  Estimated based on SM14 NMR measurement

# %%
df_col = pd.read_csv("typeI_submission_collection.csv")
df_col.head()
# Out:
#    Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 0           0                            0.15      SM01_micro004
# 1           1                           -0.26      SM02_micro003
# 2           2                           -0.04      SM03_micro002
# 3           3                           -0.81      SM04_micro003
# 4           4                           -0.19      SM05_micro008
#
#   Microstate ID of HA Molecule ID    name  pKa (calc)  pKa (exp)     pKa ID  \
# 0       SM01_micro005        SM01  Jaguar        9.68       9.53  SM01_pKa1
# 1       SM02_micro005        SM02  Jaguar        4.77       5.03  SM02_pKa1
# 2       SM03_micro012        SM03  Jaguar        6.98       7.02  SM03_pKa1
# 3       SM04_micro002        SM04  Jaguar        5.21       6.02  SM04_pKa1
# 4       SM05_micro011        SM05  Jaguar        4.40       4.59  SM05_pKa1
#
#    pKa SEM (calc)  pKa SEM (exp)     participant receipt_id
# 0            0.77           0.01  Bas Rustenburg      nb011
# 1            2.00           0.01  Bas Rustenburg      nb011
# 2            1.62           0.01  Bas Rustenburg      nb011
# 3            2.26           0.01  Bas Rustenburg      nb011
# 4            0.52           0.01  Bas Rustenburg      nb011

# %%
df_col[df_col["Molecule ID"] == "SM14"]
# Out:
#       Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 14            14                            0.05      SM14_micro001
# 15            15                            0.22      SM14_micro002
# 45            45                            0.39      SM14_micro001
# 46            46                           -0.69      SM14_micro006
# 76            76                            0.13      SM14_micro006
# 106          106                            1.23      SM14_micro001
# 107          107                            0.12      SM14_micro006
# 136          136                            0.53      SM14_micro001
# 137          137                           -0.19      SM14_micro006
# 167          167                           -0.34      SM14_micro001
# 168          168                            0.05      SM14_micro006
# 196          196                            0.80      SM14_micro004
# 197          197                           -0.13      SM14_micro001
# 226          226                            0.80      SM14_micro004
# 227          227                           -0.13      SM14_micro001
# 257          257                            0.06      SM14_micro001
# 258          258                           -0.46      SM14_micro006
# 287          287                            0.53      SM14_micro001
# 288          288                            0.05      SM14_micro004
# 317          317                            1.03      SM14_micro001
# 318          318                           -0.07      SM14_micro006
# 352          352                            0.56      SM14_micro001
# 353          353                            0.97      SM14_micro006
# 383          383                            1.01      SM14_micro001
# 384          384                           -0.49      SM14_micro006
# 414          414                            0.02      SM14_micro001
# 415          415                           -0.15      SM14_micro004
# 445          445                            1.03      SM14_micro001
# 446          446                           -0.46      SM14_micro006
# 474          474                            0.15      SM14_micro002
# ...          ...                             ...                ...
# 563          563                           -0.29      SM14_micro006
# 592          592                            0.72      SM14_micro001
# 593          593                           -0.01      SM14_micro001
# 623          623                            0.37      SM14_micro001
# 624          624                           -0.46      SM14_micro002
# 652          652                           19.28      SM14_micro006
# 653          653                           -3.89      SM14_micro001
# 681          681                           12.97      SM14_micro006
# 682          682                           -9.63      SM14_micro001
# 710          710                           -0.51      SM14_micro002
# 711          711                            0.90      SM14_micro001
# 739          739                            0.02      SM14_micro001
# 740          740                            0.57      SM14_micro006
# 769          769                           23.88      SM14_micro006
# 770          770                            0.72      SM14_micro001
# 798          798                           -0.04      SM14_micro001
# 799          799                            0.90      SM14_micro002
# 828          828                            1.01      SM14_micro001
# 829          829                           -1.16      SM14_micro006
# 859          859                            0.22      SM14_micro001
# 860          860                            0.58      SM14_micro002
# 888          888                           17.57      SM14_micro006
# 889          889                           -5.02      SM14_micro001
# 917          917                            0.00      SM14_micro001
# 943          943                            1.04      SM14_micro001
# 944          944                            0.05      SM14_micro006
# 973          973                            0.44      SM14_micro001
# 974          974                           -0.30      SM14_micro004
# 1003        1003                            0.81      SM14_micro001
# 1004        1004                           -0.28      SM14_micro006
#
#      Microstate ID of HA Molecule ID  \
# 14         SM14_micro002        SM14
# 15         SM14_micro003        SM14
# 45         SM14_micro002        SM14
# 46         SM14_micro005        SM14
# 76         SM14_micro005        SM14
# 106        SM14_micro002        SM14
# 107        SM14_micro005        SM14
# 136        SM14_micro004        SM14
# 137        SM14_micro005        SM14
# 167        SM14_micro004        SM14
# 168        SM14_micro005        SM14
# 196        SM14_micro003        SM14
# 197        SM14_micro004        SM14
# 226        SM14_micro003        SM14
# 227        SM14_micro004        SM14
# 257        SM14_micro002        SM14
# 258        SM14_micro005        SM14
# 287        SM14_micro002        SM14
# 288        SM14_micro003        SM14
# 317        SM14_micro002        SM14
# 318        SM14_micro005        SM14
# 352        SM14_micro002        SM14
# 353        SM14_micro005        SM14
# 383        SM14_micro002        SM14
# 384        SM14_micro005        SM14
# 414        SM14_micro002        SM14
# 415        SM14_micro003        SM14
# 445        SM14_micro002        SM14
# 446        SM14_micro005        SM14
# 474        SM14_micro003        SM14
# ...                  ...         ...
# 563        SM14_micro005        SM14
# 592        SM14_micro002        SM14
# 593        SM14_micro004        SM14
# 623        SM14_micro002        SM14
# 624        SM14_micro003        SM14
# 652        SM14_micro001        SM14
# 653        SM14_micro004        SM14
# 681        SM14_micro001        SM14
# 682        SM14_micro004        SM14
# 710        SM14_micro003        SM14
# 711        SM14_micro002        SM14
# 739        SM14_micro004        SM14
# 740        SM14_micro005        SM14
# 769        SM14_micro001        SM14
# 770        SM14_micro004        SM14
# 798        SM14_micro002        SM14
# 799        SM14_micro003        SM14
# 828        SM14_micro004        SM14
# 829        SM14_micro005        SM14
# 859        SM14_micro004        SM14
# 860        SM14_micro003        SM14
# 888        SM14_micro001        SM14
# 889        SM14_micro004        SM14
# 917        SM14_micro002        SM14
# 943        SM14_micro002        SM14
# 944        SM14_micro005        SM14
# 973        SM14_micro002        SM14
# 974        SM14_micro003        SM14
# 1003       SM14_micro002        SM14
# 1004       SM14_micro005        SM14
#
#                                                    name  pKa (calc)  \
# 14                                               Jaguar        5.35
# 15                                               Jaguar        2.80
# 45             EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-1par        2.97
# 46             EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-1par        4.61
# 76               Adiabatic scheme for type I submission        5.43
# 106                 EC-RISM/MP2/cc-pVTZ-P2-phi-all-2par        3.81
# 107                 EC-RISM/MP2/cc-pVTZ-P2-phi-all-2par        5.42
# 136   Adiabatic scheme with single point correction ...        3.11
# 137   Adiabatic scheme with single point correction ...        5.11
# 167                 Direct scheme for type I submission        2.24
# 168                 Direct scheme for type I submission        5.35
# 196             ReSCoSS conformations // COSMOtherm pKa        3.38
# 197             ReSCoSS conformations // COSMOtherm pKa        5.17
# 226   ReSCoSS conformations // DSD-BLYP-D3 reranking...        3.38
# 227   ReSCoSS conformations // DSD-BLYP-D3 reranking...        5.17
# 257          EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        2.64
# 258          EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        4.84
# 287     EC-RISM/B3LYP/6-311+G(d,p)-P2-phi-noThiols-2par        5.83
# 288     EC-RISM/B3LYP/6-311+G(d,p)-P2-phi-noThiols-2par        2.63
# 317            EC-RISM/MP2/cc-pVTZ-P2-phi-noThiols-2par        3.61
# 318            EC-RISM/MP2/cc-pVTZ-P2-phi-noThiols-2par        5.23
# 352   Direct scheme with single point correction for...        3.14
# 353   Direct scheme with single point correction for...        6.27
# 383       EC-RISM/MP2/6-311+G(d,p)-P2-phi-noThiols-2par        3.59
# 384       EC-RISM/MP2/6-311+G(d,p)-P2-phi-noThiols-2par        4.81
# 414   microscopic pKa prediction with Gaussian and g...        5.32
# 415   microscopic pKa prediction with Gaussian and g...        2.43
# 445            EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-2par        3.61
# 446            EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-2par        4.84
# 474                                 OE Gaussian Process        2.73
# ...                                                 ...         ...
# 563     EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-noThiols-2par        5.01
# 592     EC-RISM/B3LYP/6-311+G(d,p)-P3NI-q-noThiols-2par        6.02
# 593     EC-RISM/B3LYP/6-311+G(d,p)-P3NI-q-noThiols-2par        2.57
# 623              EC-RISM/MP2/cc-pVTZ-P2-q-noThiols-2par        5.67
# 624              EC-RISM/MP2/cc-pVTZ-P2-q-noThiols-2par        2.12
# 652                       Explicit solvent submission 2       24.58
# 653                       Explicit solvent submission 2       -1.31
# 681                       Explicit solvent submission 4       18.27
# 682                       Explicit solvent submission 4       -7.05
# 710                                       ACD/pKa GALAS        2.07
# 711                                       ACD/pKa GALAS        6.20
# 739       EC-RISM/MP2/6-311+G(d,p)-P3NI-q-noThiols-2par        2.60
# 740       EC-RISM/MP2/6-311+G(d,p)-P3NI-q-noThiols-2par        5.87
# 769                       Explicit solvent submission 1       29.18
# 770                       Explicit solvent submission 1        3.30
# 798                                               S+pKa        5.26
# 799                                               S+pKa        3.48
# 828               Vertical scheme for type I submission        3.59
# 829               Vertical scheme for type I submission        4.14
# 859                              PCM/B3LYP/6-311+G(d,p)        5.52
# 860                              PCM/B3LYP/6-311+G(d,p)        3.16
# 888                       Explicit solvent submission 3       22.87
# 889                       Explicit solvent submission 3       -2.44
# 917                                   COSMOlogic_FINE17        5.30
# 943          EC-RISM/MP2/cc-pVTZ-P3NI-phi-noThiols-2par        3.62
# 944          EC-RISM/MP2/cc-pVTZ-P3NI-phi-noThiols-2par        5.35
# 973   EC-RISM/B3LYP/6-311+G(d,p)-P3NI-phi-noThiols-2par        5.74
# 974   EC-RISM/B3LYP/6-311+G(d,p)-P3NI-phi-noThiols-2par        2.28
# 1003         EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-2par        3.39
# 1004         EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-2par        5.02
#
#       pKa (exp)     pKa ID  pKa SEM (calc)  pKa SEM (exp)  \
# 14         5.30  SM14_pKa2            0.66           0.01
# 15         2.58  SM14_pKa1            0.14           0.01
# 45         2.58  SM14_pKa1            1.77           0.01
# 46         5.30  SM14_pKa2            1.77           0.01
# 76         5.30  SM14_pKa2             NaN           0.01
# 106        2.58  SM14_pKa1            1.77           0.01
# 107        5.30  SM14_pKa2            1.77           0.01
# 136        2.58  SM14_pKa1             NaN           0.01
# 137        5.30  SM14_pKa2             NaN           0.01
# 167        2.58  SM14_pKa1             NaN           0.01
# 168        5.30  SM14_pKa2             NaN           0.01
# 196        2.58  SM14_pKa1             NaN           0.01
# 197        5.30  SM14_pKa2             NaN           0.01
# 226        2.58  SM14_pKa1             NaN           0.01
# 227        5.30  SM14_pKa2             NaN           0.01
# 257        2.58  SM14_pKa1            1.77           0.01
# 258        5.30  SM14_pKa2            1.77           0.01
# 287        5.30  SM14_pKa2            1.77           0.01
# 288        2.58  SM14_pKa1            1.77           0.01
# 317        2.58  SM14_pKa1            1.77           0.01
# 318        5.30  SM14_pKa2            1.77           0.01
# 352        2.58  SM14_pKa1             NaN           0.01
# 353        5.30  SM14_pKa2             NaN           0.01
# 383        2.58  SM14_pKa1            1.77           0.01
# 384        5.30  SM14_pKa2            1.77           0.01
# 414        5.30  SM14_pKa2             NaN           0.01
# 415        2.58  SM14_pKa1             NaN           0.01
# 445        2.58  SM14_pKa1            1.77           0.01
# 446        5.30  SM14_pKa2            1.77           0.01
# 474        2.58  SM14_pKa1            3.66           0.01
# ...         ...        ...             ...            ...
# 563        5.30  SM14_pKa2            1.77           0.01
# 592        5.30  SM14_pKa2            1.77           0.01
# 593        2.58  SM14_pKa1            1.77           0.01
# 623        5.30  SM14_pKa2            1.77           0.01
# 624        2.58  SM14_pKa1            1.77           0.01
# 652        5.30  SM14_pKa2             NaN           0.01
# 653        2.58  SM14_pKa1             NaN           0.01
# 681        5.30  SM14_pKa2             NaN           0.01
# 682        2.58  SM14_pKa1             NaN           0.01
# 710        2.58  SM14_pKa1             NaN           0.01
# 711        5.30  SM14_pKa2             NaN           0.01
# 739        2.58  SM14_pKa1            1.77           0.01
# 740        5.30  SM14_pKa2            1.77           0.01
# 769        5.30  SM14_pKa2             NaN           0.01
# 770        2.58  SM14_pKa1             NaN           0.01
# 798        5.30  SM14_pKa2             NaN           0.01
# 799        2.58  SM14_pKa1             NaN           0.01
# 828        2.58  SM14_pKa1             NaN           0.01
# 829        5.30  SM14_pKa2             NaN           0.01
# 859        5.30  SM14_pKa2            2.58           0.01
# 860        2.58  SM14_pKa1            2.58           0.01
# 888        5.30  SM14_pKa2             NaN           0.01
# 889        2.58  SM14_pKa1             NaN           0.01
# 917        5.30  SM14_pKa2            0.65           0.01
# 943        2.58  SM14_pKa1            1.77           0.01
# 944        5.30  SM14_pKa2            1.77           0.01
# 973        5.30  SM14_pKa2            1.77           0.01
# 974        2.58  SM14_pKa1            1.77           0.01
# 1003       2.58  SM14_pKa1            1.77           0.01
# 1004       5.30  SM14_pKa2            1.77           0.01
#
#               participant receipt_id
# 14         Bas Rustenburg      nb011
# 15         Bas Rustenburg      nb011
# 45            Stefan Kast      z7fhp
# 46            Stefan Kast      z7fhp
# 76              Qiao Zeng      wcvnu
# 106           Stefan Kast      xnoe0
# 107           Stefan Kast      xnoe0
# 136             Qiao Zeng      ko8yx
# 137             Qiao Zeng      ko8yx
# 167             Qiao Zeng      wexjs
# 168             Qiao Zeng      wexjs
# 196        Rainer Wilcken      ccpmw
# 197        Rainer Wilcken      ccpmw
# 226        Rainer Wilcken      eyetm
# 227        Rainer Wilcken      eyetm
# 257           Stefan Kast      8toyp
# 258           Stefan Kast      8toyp
# 287           Stefan Kast      cywyk
# 288           Stefan Kast      cywyk
# 317           Stefan Kast      epvmk
# 318           Stefan Kast      epvmk
# 352             Qiao Zeng      w4z0e
# 353             Qiao Zeng      w4z0e
# 383           Stefan Kast      wuuvc
# 384           Stefan Kast      wuuvc
# 414          Bogdan Iorga      y4wws
# 415          Bogdan Iorga      y4wws
# 445           Stefan Kast      ktpj5
# 446           Stefan Kast      ktpj5
# 474        Caitlin Bannan      6tvf8
# ...                   ...        ...
# 563           Stefan Kast      cm2yq
# 592           Stefan Kast      nxaaw
# 593           Stefan Kast      nxaaw
# 623           Stefan Kast      ftc8w
# 624           Stefan Kast      ftc8w
# 652      Samarjeet Prasad      z3btx
# 653      Samarjeet Prasad      z3btx
# 681      Samarjeet Prasad      hgn83
# 682      Samarjeet Prasad      hgn83
# 710       Kiril Lanevskij      v8qph
# 711       Kiril Lanevskij      v8qph
# 739           Stefan Kast      kxztt
# 740           Stefan Kast      kxztt
# 769      Samarjeet Prasad      0wfzo
# 770      Samarjeet Prasad      0wfzo
# 798   Robert Fraczkiewicz      hdiyq
# 799   Robert Fraczkiewicz      hdiyq
# 828             Qiao Zeng      arcko
# 829             Qiao Zeng      arcko
# 859           Stefan Kast      gdqeg
# 860           Stefan Kast      gdqeg
# 888      Samarjeet Prasad      758j8
# 889      Samarjeet Prasad      758j8
# 917         Chris Loschen      t8ewk
# 943           Stefan Kast      4o0ia
# 944           Stefan Kast      4o0ia
# 973           Stefan Kast      0xi4b
# 974           Stefan Kast      0xi4b
# 1003          Stefan Kast      2umai
# 1004          Stefan Kast      2umai
#
# [66 rows x 13 columns]

# %%
df_exp_microstates = df_exp.rename(columns={'Microstate ID of A': 'Exp. Microstate ID of A', 'Microstate ID of HA': 'Exp. Microstate ID of HA'})
df_exp_microstates = df_exp_microstates.drop(columns=['Molecule ID', "pKa (exp)", 'pKa SEM (exp)'])
df_exp_microstates
# Out:
#   Exp. Microstate ID of A Exp. Microstate ID of HA     pKa ID  \
# 0           SM07_micro004            SM07_micro006  SM07_pKa1
# 1           SM14_micro001            SM14_micro002  SM14_pKa2
# 2           SM14_micro002            SM14_micro003  SM14_pKa1
# 3           SM02_micro001            SM02_micro004  SM02_pKa1
# 4           SM04_micro003            SM04_micro002  SM04_pKa1
# 5           SM09_micro003            SM09_micro001  SM09_pKa1
# 6           SM12_micro012            SM12_micro006  SM12_pKa1
# 7           SM13_micro005            SM13_micro001  SM13_pKa1
# 8           SM15_micro004            SM15_micro002  SM15_pKa2
# 9           SM15_micro002            SM15_micro003  SM15_pKa1
#
#           Microstate identification source
# 0                          NMR measurement
# 1                          NMR measurement
# 2                          NMR measurement
# 3  Estimated based on SM07 NMR measurement
# 4  Estimated based on SM07 NMR measurement
# 5  Estimated based on SM07 NMR measurement
# 6  Estimated based on SM07 NMR measurement
# 7  Estimated based on SM07 NMR measurement
# 8  Estimated based on SM14 NMR measurement
# 9  Estimated based on SM14 NMR measurement

# %% [markdown]
# 1. Add experimental microstates to collection
# 2. Drop entries of molecules with unknown experimental microstate
# 3. check for matches and give a score

# %%
df_col_ms = pd.merge(df_col, df_exp_microstates, on="pKa ID", how="outer" )
# Drop rows whose "Exp. Microstate ID of A" column has NaN value
df_col_ms = df_col_ms.dropna(subset=["Exp. Microstate ID of A"])
# Drop rows whose "receipt_id" column has NaN value
#df_col_ms = df_col_ms.dropna(subset=["receipt_id"])
df_col_ms = df_col_ms.reset_index()
df_col_ms = df_col_ms.drop(columns=['index'])
df_col_ms.tail()
# Out:
#      Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 329         891                            2.87      SM15_micro001
# 330         918                            0.28      SM15_micro004
# 331         945                            0.08      SM15_micro001
# 332         976                            0.13      SM15_micro004
# 333        1005                           -0.60      SM15_micro001
#
#     Microstate ID of HA Molecule ID  \
# 329       SM15_micro003        SM15
# 330       SM15_micro002        SM15
# 331       SM15_micro003        SM15
# 332       SM15_micro002        SM15
# 333       SM15_micro003        SM15
#
#                                                   name  pKa (calc)  pKa (exp)  \
# 329                      Explicit solvent submission 3       11.81       8.94
# 330                                  COSMOlogic_FINE17        9.22       8.94
# 331         EC-RISM/MP2/cc-pVTZ-P3NI-phi-noThiols-2par        9.02       8.94
# 332  EC-RISM/B3LYP/6-311+G(d,p)-P3NI-phi-noThiols-2par        9.07       8.94
# 333         EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-2par        8.34       8.94
#
#         pKa ID  pKa SEM (calc)  pKa SEM (exp)       participant receipt_id  \
# 329  SM15_pKa2             NaN           0.01  Samarjeet Prasad      758j8
# 330  SM15_pKa2            0.65           0.01     Chris Loschen      t8ewk
# 331  SM15_pKa2            1.77           0.01       Stefan Kast      4o0ia
# 332  SM15_pKa2            1.77           0.01       Stefan Kast      0xi4b
# 333  SM15_pKa2            1.77           0.01       Stefan Kast      2umai
#
#     Exp. Microstate ID of A Exp. Microstate ID of HA  \
# 329           SM15_micro004            SM15_micro002
# 330           SM15_micro004            SM15_micro002
# 331           SM15_micro004            SM15_micro002
# 332           SM15_micro004            SM15_micro002
# 333           SM15_micro004            SM15_micro002
#
#             Microstate identification source
# 329  Estimated based on SM14 NMR measurement
# 330  Estimated based on SM14 NMR measurement
# 331  Estimated based on SM14 NMR measurement
# 332  Estimated based on SM14 NMR measurement
# 333  Estimated based on SM14 NMR measurement

# %%
df_col_ms[df_col_ms["Molecule ID"] == "SM14"]
# Out:
#      Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 199          14                            0.05      SM14_micro001
# 200          46                           -0.69      SM14_micro006
# 201          76                            0.13      SM14_micro006
# 202         107                            0.12      SM14_micro006
# 203         137                           -0.19      SM14_micro006
# 204         168                            0.05      SM14_micro006
# 205         197                           -0.13      SM14_micro001
# 206         227                           -0.13      SM14_micro001
# 207         258                           -0.46      SM14_micro006
# 208         287                            0.53      SM14_micro001
# 209         318                           -0.07      SM14_micro006
# 210         353                            0.97      SM14_micro006
# 211         384                           -0.49      SM14_micro006
# 212         414                            0.02      SM14_micro001
# 213         446                           -0.46      SM14_micro006
# 214         475                           -0.47      SM14_micro001
# 215         503                           -0.19      SM14_micro004
# 216         531                            0.79      SM14_micro001
# 217         563                           -0.29      SM14_micro006
# 218         592                            0.72      SM14_micro001
# 219         623                            0.37      SM14_micro001
# 220         652                           19.28      SM14_micro006
# 221         681                           12.97      SM14_micro006
# 222         711                            0.90      SM14_micro001
# 223         740                            0.57      SM14_micro006
# 224         769                           23.88      SM14_micro006
# 225         798                           -0.04      SM14_micro001
# 226         829                           -1.16      SM14_micro006
# 227         859                            0.22      SM14_micro001
# 228         888                           17.57      SM14_micro006
# ..          ...                             ...                ...
# 235         106                            1.23      SM14_micro001
# 236         136                            0.53      SM14_micro001
# 237         167                           -0.34      SM14_micro001
# 238         196                            0.80      SM14_micro004
# 239         226                            0.80      SM14_micro004
# 240         257                            0.06      SM14_micro001
# 241         288                            0.05      SM14_micro004
# 242         317                            1.03      SM14_micro001
# 243         352                            0.56      SM14_micro001
# 244         383                            1.01      SM14_micro001
# 245         415                           -0.15      SM14_micro004
# 246         445                            1.03      SM14_micro001
# 247         474                            0.15      SM14_micro002
# 248         504                            0.79      SM14_micro001
# 249         532                            0.33      SM14_micro002
# 250         562                            0.81      SM14_micro001
# 251         593                           -0.01      SM14_micro001
# 252         624                           -0.46      SM14_micro002
# 253         653                           -3.89      SM14_micro001
# 254         682                           -9.63      SM14_micro001
# 255         710                           -0.51      SM14_micro002
# 256         739                            0.02      SM14_micro001
# 257         770                            0.72      SM14_micro001
# 258         799                            0.90      SM14_micro002
# 259         828                            1.01      SM14_micro001
# 260         860                            0.58      SM14_micro002
# 261         889                           -5.02      SM14_micro001
# 262         943                            1.04      SM14_micro001
# 263         974                           -0.30      SM14_micro004
# 264        1003                            0.81      SM14_micro001
#
#     Microstate ID of HA Molecule ID  \
# 199       SM14_micro002        SM14
# 200       SM14_micro005        SM14
# 201       SM14_micro005        SM14
# 202       SM14_micro005        SM14
# 203       SM14_micro005        SM14
# 204       SM14_micro005        SM14
# 205       SM14_micro004        SM14
# 206       SM14_micro004        SM14
# 207       SM14_micro005        SM14
# 208       SM14_micro002        SM14
# 209       SM14_micro005        SM14
# 210       SM14_micro005        SM14
# 211       SM14_micro005        SM14
# 212       SM14_micro002        SM14
# 213       SM14_micro005        SM14
# 214       SM14_micro004        SM14
# 215       SM14_micro003        SM14
# 216       SM14_micro002        SM14
# 217       SM14_micro005        SM14
# 218       SM14_micro002        SM14
# 219       SM14_micro002        SM14
# 220       SM14_micro001        SM14
# 221       SM14_micro001        SM14
# 222       SM14_micro002        SM14
# 223       SM14_micro005        SM14
# 224       SM14_micro001        SM14
# 225       SM14_micro002        SM14
# 226       SM14_micro005        SM14
# 227       SM14_micro004        SM14
# 228       SM14_micro001        SM14
# ..                  ...         ...
# 235       SM14_micro002        SM14
# 236       SM14_micro004        SM14
# 237       SM14_micro004        SM14
# 238       SM14_micro003        SM14
# 239       SM14_micro003        SM14
# 240       SM14_micro002        SM14
# 241       SM14_micro003        SM14
# 242       SM14_micro002        SM14
# 243       SM14_micro002        SM14
# 244       SM14_micro002        SM14
# 245       SM14_micro003        SM14
# 246       SM14_micro002        SM14
# 247       SM14_micro003        SM14
# 248       SM14_micro004        SM14
# 249       SM14_micro003        SM14
# 250       SM14_micro002        SM14
# 251       SM14_micro004        SM14
# 252       SM14_micro003        SM14
# 253       SM14_micro004        SM14
# 254       SM14_micro004        SM14
# 255       SM14_micro003        SM14
# 256       SM14_micro004        SM14
# 257       SM14_micro004        SM14
# 258       SM14_micro003        SM14
# 259       SM14_micro004        SM14
# 260       SM14_micro003        SM14
# 261       SM14_micro004        SM14
# 262       SM14_micro002        SM14
# 263       SM14_micro003        SM14
# 264       SM14_micro002        SM14
#
#                                                   name  pKa (calc)  pKa (exp)  \
# 199                                             Jaguar        5.35       5.30
# 200           EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-1par        4.61       5.30
# 201             Adiabatic scheme for type I submission        5.43       5.30
# 202                EC-RISM/MP2/cc-pVTZ-P2-phi-all-2par        5.42       5.30
# 203  Adiabatic scheme with single point correction ...        5.11       5.30
# 204                Direct scheme for type I submission        5.35       5.30
# 205            ReSCoSS conformations // COSMOtherm pKa        5.17       5.30
# 206  ReSCoSS conformations // DSD-BLYP-D3 reranking...        5.17       5.30
# 207         EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        4.84       5.30
# 208    EC-RISM/B3LYP/6-311+G(d,p)-P2-phi-noThiols-2par        5.83       5.30
# 209           EC-RISM/MP2/cc-pVTZ-P2-phi-noThiols-2par        5.23       5.30
# 210  Direct scheme with single point correction for...        6.27       5.30
# 211      EC-RISM/MP2/6-311+G(d,p)-P2-phi-noThiols-2par        4.81       5.30
# 212  microscopic pKa prediction with Gaussian and g...        5.32       5.30
# 213           EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-2par        4.84       5.30
# 214                                OE Gaussian Process        4.83       5.30
# 215                                   Epik Microscopic        5.11       5.30
# 216                                               MoKa        6.09       5.30
# 217    EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-noThiols-2par        5.01       5.30
# 218    EC-RISM/B3LYP/6-311+G(d,p)-P3NI-q-noThiols-2par        6.02       5.30
# 219             EC-RISM/MP2/cc-pVTZ-P2-q-noThiols-2par        5.67       5.30
# 220                      Explicit solvent submission 2       24.58       5.30
# 221                      Explicit solvent submission 4       18.27       5.30
# 222                                      ACD/pKa GALAS        6.20       5.30
# 223      EC-RISM/MP2/6-311+G(d,p)-P3NI-q-noThiols-2par        5.87       5.30
# 224                      Explicit solvent submission 1       29.18       5.30
# 225                                              S+pKa        5.26       5.30
# 226              Vertical scheme for type I submission        4.14       5.30
# 227                             PCM/B3LYP/6-311+G(d,p)        5.52       5.30
# 228                      Explicit solvent submission 3       22.87       5.30
# ..                                                 ...         ...        ...
# 235                EC-RISM/MP2/cc-pVTZ-P2-phi-all-2par        3.81       2.58
# 236  Adiabatic scheme with single point correction ...        3.11       2.58
# 237                Direct scheme for type I submission        2.24       2.58
# 238            ReSCoSS conformations // COSMOtherm pKa        3.38       2.58
# 239  ReSCoSS conformations // DSD-BLYP-D3 reranking...        3.38       2.58
# 240         EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-1par        2.64       2.58
# 241    EC-RISM/B3LYP/6-311+G(d,p)-P2-phi-noThiols-2par        2.63       2.58
# 242           EC-RISM/MP2/cc-pVTZ-P2-phi-noThiols-2par        3.61       2.58
# 243  Direct scheme with single point correction for...        3.14       2.58
# 244      EC-RISM/MP2/6-311+G(d,p)-P2-phi-noThiols-2par        3.59       2.58
# 245  microscopic pKa prediction with Gaussian and g...        2.43       2.58
# 246           EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-2par        3.61       2.58
# 247                                OE Gaussian Process        2.73       2.58
# 248                                   Epik Microscopic        3.37       2.58
# 249                                               MoKa        2.91       2.58
# 250    EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-noThiols-2par        3.39       2.58
# 251    EC-RISM/B3LYP/6-311+G(d,p)-P3NI-q-noThiols-2par        2.57       2.58
# 252             EC-RISM/MP2/cc-pVTZ-P2-q-noThiols-2par        2.12       2.58
# 253                      Explicit solvent submission 2       -1.31       2.58
# 254                      Explicit solvent submission 4       -7.05       2.58
# 255                                      ACD/pKa GALAS        2.07       2.58
# 256      EC-RISM/MP2/6-311+G(d,p)-P3NI-q-noThiols-2par        2.60       2.58
# 257                      Explicit solvent submission 1        3.30       2.58
# 258                                              S+pKa        3.48       2.58
# 259              Vertical scheme for type I submission        3.59       2.58
# 260                             PCM/B3LYP/6-311+G(d,p)        3.16       2.58
# 261                      Explicit solvent submission 3       -2.44       2.58
# 262         EC-RISM/MP2/cc-pVTZ-P3NI-phi-noThiols-2par        3.62       2.58
# 263  EC-RISM/B3LYP/6-311+G(d,p)-P3NI-phi-noThiols-2par        2.28       2.58
# 264         EC-RISM/MP2/6-311+G(d,p)-P3NI-phi-all-2par        3.39       2.58
#
#         pKa ID  pKa SEM (calc)  pKa SEM (exp)          participant receipt_id  \
# 199  SM14_pKa2            0.66           0.01       Bas Rustenburg      nb011
# 200  SM14_pKa2            1.77           0.01          Stefan Kast      z7fhp
# 201  SM14_pKa2             NaN           0.01            Qiao Zeng      wcvnu
# 202  SM14_pKa2            1.77           0.01          Stefan Kast      xnoe0
# 203  SM14_pKa2             NaN           0.01            Qiao Zeng      ko8yx
# 204  SM14_pKa2             NaN           0.01            Qiao Zeng      wexjs
# 205  SM14_pKa2             NaN           0.01       Rainer Wilcken      ccpmw
# 206  SM14_pKa2             NaN           0.01       Rainer Wilcken      eyetm
# 207  SM14_pKa2            1.77           0.01          Stefan Kast      8toyp
# 208  SM14_pKa2            1.77           0.01          Stefan Kast      cywyk
# 209  SM14_pKa2            1.77           0.01          Stefan Kast      epvmk
# 210  SM14_pKa2             NaN           0.01            Qiao Zeng      w4z0e
# 211  SM14_pKa2            1.77           0.01          Stefan Kast      wuuvc
# 212  SM14_pKa2             NaN           0.01         Bogdan Iorga      y4wws
# 213  SM14_pKa2            1.77           0.01          Stefan Kast      ktpj5
# 214  SM14_pKa2            0.22           0.01       Caitlin Bannan      6tvf8
# 215  SM14_pKa2            2.22           0.01       Bas Rustenburg      nb008
# 216  SM14_pKa2             NaN           0.01           Thomas Fox      nb016
# 217  SM14_pKa2            1.77           0.01          Stefan Kast      cm2yq
# 218  SM14_pKa2            1.77           0.01          Stefan Kast      nxaaw
# 219  SM14_pKa2            1.77           0.01          Stefan Kast      ftc8w
# 220  SM14_pKa2             NaN           0.01     Samarjeet Prasad      z3btx
# 221  SM14_pKa2             NaN           0.01     Samarjeet Prasad      hgn83
# 222  SM14_pKa2             NaN           0.01      Kiril Lanevskij      v8qph
# 223  SM14_pKa2            1.77           0.01          Stefan Kast      kxztt
# 224  SM14_pKa2             NaN           0.01     Samarjeet Prasad      0wfzo
# 225  SM14_pKa2             NaN           0.01  Robert Fraczkiewicz      hdiyq
# 226  SM14_pKa2             NaN           0.01            Qiao Zeng      arcko
# 227  SM14_pKa2            2.58           0.01          Stefan Kast      gdqeg
# 228  SM14_pKa2             NaN           0.01     Samarjeet Prasad      758j8
# ..         ...             ...            ...                  ...        ...
# 235  SM14_pKa1            1.77           0.01          Stefan Kast      xnoe0
# 236  SM14_pKa1             NaN           0.01            Qiao Zeng      ko8yx
# 237  SM14_pKa1             NaN           0.01            Qiao Zeng      wexjs
# 238  SM14_pKa1             NaN           0.01       Rainer Wilcken      ccpmw
# 239  SM14_pKa1             NaN           0.01       Rainer Wilcken      eyetm
# 240  SM14_pKa1            1.77           0.01          Stefan Kast      8toyp
# 241  SM14_pKa1            1.77           0.01          Stefan Kast      cywyk
# 242  SM14_pKa1            1.77           0.01          Stefan Kast      epvmk
# 243  SM14_pKa1             NaN           0.01            Qiao Zeng      w4z0e
# 244  SM14_pKa1            1.77           0.01          Stefan Kast      wuuvc
# 245  SM14_pKa1             NaN           0.01         Bogdan Iorga      y4wws
# 246  SM14_pKa1            1.77           0.01          Stefan Kast      ktpj5
# 247  SM14_pKa1            3.66           0.01       Caitlin Bannan      6tvf8
# 248  SM14_pKa1            2.22           0.01       Bas Rustenburg      nb008
# 249  SM14_pKa1             NaN           0.01           Thomas Fox      nb016
# 250  SM14_pKa1            1.77           0.01          Stefan Kast      cm2yq
# 251  SM14_pKa1            1.77           0.01          Stefan Kast      nxaaw
# 252  SM14_pKa1            1.77           0.01          Stefan Kast      ftc8w
# 253  SM14_pKa1             NaN           0.01     Samarjeet Prasad      z3btx
# 254  SM14_pKa1             NaN           0.01     Samarjeet Prasad      hgn83
# 255  SM14_pKa1             NaN           0.01      Kiril Lanevskij      v8qph
# 256  SM14_pKa1            1.77           0.01          Stefan Kast      kxztt
# 257  SM14_pKa1             NaN           0.01     Samarjeet Prasad      0wfzo
# 258  SM14_pKa1             NaN           0.01  Robert Fraczkiewicz      hdiyq
# 259  SM14_pKa1             NaN           0.01            Qiao Zeng      arcko
# 260  SM14_pKa1            2.58           0.01          Stefan Kast      gdqeg
# 261  SM14_pKa1             NaN           0.01     Samarjeet Prasad      758j8
# 262  SM14_pKa1            1.77           0.01          Stefan Kast      4o0ia
# 263  SM14_pKa1            1.77           0.01          Stefan Kast      0xi4b
# 264  SM14_pKa1            1.77           0.01          Stefan Kast      2umai
#
#     Exp. Microstate ID of A Exp. Microstate ID of HA  \
# 199           SM14_micro001            SM14_micro002
# 200           SM14_micro001            SM14_micro002
# 201           SM14_micro001            SM14_micro002
# 202           SM14_micro001            SM14_micro002
# 203           SM14_micro001            SM14_micro002
# 204           SM14_micro001            SM14_micro002
# 205           SM14_micro001            SM14_micro002
# 206           SM14_micro001            SM14_micro002
# 207           SM14_micro001            SM14_micro002
# 208           SM14_micro001            SM14_micro002
# 209           SM14_micro001            SM14_micro002
# 210           SM14_micro001            SM14_micro002
# 211           SM14_micro001            SM14_micro002
# 212           SM14_micro001            SM14_micro002
# 213           SM14_micro001            SM14_micro002
# 214           SM14_micro001            SM14_micro002
# 215           SM14_micro001            SM14_micro002
# 216           SM14_micro001            SM14_micro002
# 217           SM14_micro001            SM14_micro002
# 218           SM14_micro001            SM14_micro002
# 219           SM14_micro001            SM14_micro002
# 220           SM14_micro001            SM14_micro002
# 221           SM14_micro001            SM14_micro002
# 222           SM14_micro001            SM14_micro002
# 223           SM14_micro001            SM14_micro002
# 224           SM14_micro001            SM14_micro002
# 225           SM14_micro001            SM14_micro002
# 226           SM14_micro001            SM14_micro002
# 227           SM14_micro001            SM14_micro002
# 228           SM14_micro001            SM14_micro002
# ..                      ...                      ...
# 235           SM14_micro002            SM14_micro003
# 236           SM14_micro002            SM14_micro003
# 237           SM14_micro002            SM14_micro003
# 238           SM14_micro002            SM14_micro003
# 239           SM14_micro002            SM14_micro003
# 240           SM14_micro002            SM14_micro003
# 241           SM14_micro002            SM14_micro003
# 242           SM14_micro002            SM14_micro003
# 243           SM14_micro002            SM14_micro003
# 244           SM14_micro002            SM14_micro003
# 245           SM14_micro002            SM14_micro003
# 246           SM14_micro002            SM14_micro003
# 247           SM14_micro002            SM14_micro003
# 248           SM14_micro002            SM14_micro003
# 249           SM14_micro002            SM14_micro003
# 250           SM14_micro002            SM14_micro003
# 251           SM14_micro002            SM14_micro003
# 252           SM14_micro002            SM14_micro003
# 253           SM14_micro002            SM14_micro003
# 254           SM14_micro002            SM14_micro003
# 255           SM14_micro002            SM14_micro003
# 256           SM14_micro002            SM14_micro003
# 257           SM14_micro002            SM14_micro003
# 258           SM14_micro002            SM14_micro003
# 259           SM14_micro002            SM14_micro003
# 260           SM14_micro002            SM14_micro003
# 261           SM14_micro002            SM14_micro003
# 262           SM14_micro002            SM14_micro003
# 263           SM14_micro002            SM14_micro003
# 264           SM14_micro002            SM14_micro003
#
#     Microstate identification source
# 199                  NMR measurement
# 200                  NMR measurement
# 201                  NMR measurement
# 202                  NMR measurement
# 203                  NMR measurement
# 204                  NMR measurement
# 205                  NMR measurement
# 206                  NMR measurement
# 207                  NMR measurement
# 208                  NMR measurement
# 209                  NMR measurement
# 210                  NMR measurement
# 211                  NMR measurement
# 212                  NMR measurement
# 213                  NMR measurement
# 214                  NMR measurement
# 215                  NMR measurement
# 216                  NMR measurement
# 217                  NMR measurement
# 218                  NMR measurement
# 219                  NMR measurement
# 220                  NMR measurement
# 221                  NMR measurement
# 222                  NMR measurement
# 223                  NMR measurement
# 224                  NMR measurement
# 225                  NMR measurement
# 226                  NMR measurement
# 227                  NMR measurement
# 228                  NMR measurement
# ..                               ...
# 235                  NMR measurement
# 236                  NMR measurement
# 237                  NMR measurement
# 238                  NMR measurement
# 239                  NMR measurement
# 240                  NMR measurement
# 241                  NMR measurement
# 242                  NMR measurement
# 243                  NMR measurement
# 244                  NMR measurement
# 245                  NMR measurement
# 246                  NMR measurement
# 247                  NMR measurement
# 248                  NMR measurement
# 249                  NMR measurement
# 250                  NMR measurement
# 251                  NMR measurement
# 252                  NMR measurement
# 253                  NMR measurement
# 254                  NMR measurement
# 255                  NMR measurement
# 256                  NMR measurement
# 257                  NMR measurement
# 258                  NMR measurement
# 259                  NMR measurement
# 260                  NMR measurement
# 261                  NMR measurement
# 262                  NMR measurement
# 263                  NMR measurement
# 264                  NMR measurement
#
# [66 rows x 16 columns]

# %%
# Add a score column based on microstate ID match

df_col_ms["Microstate pair match"] = None

for i, row in enumerate(df_col_ms.iterrows()):
    pred_ms_A = row[1]["Microstate ID of A"]
    pred_ms_HA = row[1]["Microstate ID of HA"]
    #print("{} and {}".format(exp_ms_A, exp_ms_HA))
    pred_ms_pair = str(pred_ms_A) + " " + str(pred_ms_HA)
    
    exp_ms_A = row[1]["Exp. Microstate ID of A"]
    exp_ms_HA = row[1]["Exp. Microstate ID of HA"]
    exp_ms_pair = str(exp_ms_A) + " " + str(exp_ms_HA)
    
    if pred_ms_pair == exp_ms_pair:
        df_col_ms.loc[i,"Microstate pair match"] = 1
        print(pred_ms_pair )
        print(exp_ms_pair)
        print("1")
    else:
        df_col_ms.loc[i,"Microstate pair match"] = 0    
        print(pred_ms_pair )
        print(exp_ms_pair)
        print("0")
# Out:
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro007
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro002
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro002
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro002
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro003
# SM02_micro001 SM02_micro004
# 0
# SM02_micro011 SM02_micro002
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro004
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro002 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM02_micro003 SM02_micro005
# SM02_micro001 SM02_micro004
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro009 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro005 SM04_micro009
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro005 SM04_micro003
# SM04_micro003 SM04_micro002
# 0
# SM04_micro009 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro004 SM04_micro002
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro005 SM04_micro004
# SM04_micro003 SM04_micro002
# 0
# SM04_micro005 SM04_micro003
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro006
# SM04_micro003 SM04_micro002
# 0
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM04_micro003 SM04_micro002
# SM04_micro003 SM04_micro002
# 1
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro014 SM07_micro016
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro012 SM07_micro004
# SM07_micro004 SM07_micro006
# 0
# SM07_micro012 SM07_micro004
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro002 SM07_micro006
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro012 SM07_micro002
# SM07_micro004 SM07_micro006
# 0
# SM07_micro012 SM07_micro004
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM07_micro004 SM07_micro006
# SM07_micro004 SM07_micro006
# 1
# SM07_micro003 SM07_micro007
# SM07_micro004 SM07_micro006
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro014 SM09_micro015
# SM09_micro003 SM09_micro001
# 0
# SM09_micro009 SM09_micro002
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro009 SM09_micro003
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro009 SM09_micro011
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro001
# SM09_micro003 SM09_micro001
# 1
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro003 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM09_micro011 SM09_micro005
# SM09_micro003 SM09_micro001
# 0
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro014 SM12_micro015
# SM12_micro012 SM12_micro006
# 0
# SM12_micro009 SM12_micro011
# SM12_micro012 SM12_micro006
# 0
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro009 SM12_micro012
# SM12_micro012 SM12_micro006
# 0
# SM12_micro009 SM12_micro012
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro009 SM12_micro002
# SM12_micro012 SM12_micro006
# 0
# SM12_micro009 SM12_micro012
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro002 SM12_micro001
# SM12_micro012 SM12_micro006
# 0
# SM12_micro012 SM12_micro006
# SM12_micro012 SM12_micro006
# 1
# SM12_micro011 SM12_micro006
# SM12_micro012 SM12_micro006
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro007 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro007 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro007 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro003 SM13_micro015
# SM13_micro005 SM13_micro001
# 0
# SM13_micro004 SM13_micro009
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro004 SM13_micro009
# SM13_micro005 SM13_micro001
# 0
# SM13_micro004 SM13_micro005
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro004 SM13_micro007
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM13_micro009 SM13_micro001
# SM13_micro005 SM13_micro001
# 0
# SM13_micro004 SM13_micro007
# SM13_micro005 SM13_micro001
# 0
# SM13_micro004 SM13_micro009
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro007 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro012
# SM13_micro005 SM13_micro001
# 0
# SM13_micro005 SM13_micro001
# SM13_micro005 SM13_micro001
# 1
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro004
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro004
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro004
# SM14_micro001 SM14_micro002
# 0
# SM14_micro004 SM14_micro003
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro001
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro001
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro001
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro004
# SM14_micro001 SM14_micro002
# 0
# SM14_micro006 SM14_micro001
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro001 SM14_micro002
# SM14_micro001 SM14_micro002
# 1
# SM14_micro006 SM14_micro005
# SM14_micro001 SM14_micro002
# 0
# SM14_micro002 SM14_micro003
# SM14_micro002 SM14_micro003
# 1
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro004 SM14_micro003
# SM14_micro002 SM14_micro003
# 0
# SM14_micro004 SM14_micro003
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro004 SM14_micro003
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro004 SM14_micro003
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro002 SM14_micro003
# SM14_micro002 SM14_micro003
# 1
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro002 SM14_micro003
# SM14_micro002 SM14_micro003
# 1
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro002 SM14_micro003
# SM14_micro002 SM14_micro003
# 1
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro002 SM14_micro003
# SM14_micro002 SM14_micro003
# 1
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro002 SM14_micro003
# SM14_micro002 SM14_micro003
# 1
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro002 SM14_micro003
# SM14_micro002 SM14_micro003
# 1
# SM14_micro001 SM14_micro004
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM14_micro004 SM14_micro003
# SM14_micro002 SM14_micro003
# 0
# SM14_micro001 SM14_micro002
# SM14_micro002 SM14_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro002
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro002
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro002
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro002 SM15_micro003
# SM15_micro002 SM15_micro003
# 1
# SM15_micro004 SM15_micro001
# SM15_micro002 SM15_micro003
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro002 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0
# SM15_micro004 SM15_micro002
# SM15_micro004 SM15_micro002
# 1
# SM15_micro001 SM15_micro003
# SM15_micro004 SM15_micro002
# 0

# %%
df_col_ms.head()
# Out:
#    Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 0           1                           -0.26      SM02_micro003
# 1          32                           -0.60      SM02_micro003
# 2          63                           -1.21      SM02_micro003
# 3          93                           -0.38      SM02_micro003
# 4         123                           -0.75      SM02_micro003
#
#   Microstate ID of HA Molecule ID  \
# 0       SM02_micro005        SM02
# 1       SM02_micro005        SM02
# 2       SM02_micro005        SM02
# 3       SM02_micro005        SM02
# 4       SM02_micro005        SM02
#
#                                                 name  pKa (calc)  pKa (exp)  \
# 0                                             Jaguar        4.77       5.03
# 1           EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-1par        4.43       5.03
# 2             Adiabatic scheme for type I submission        3.82       5.03
# 3                EC-RISM/MP2/cc-pVTZ-P2-phi-all-2par        4.65       5.03
# 4  Adiabatic scheme with single point correction ...        4.28       5.03
#
#       pKa ID  pKa SEM (calc)  pKa SEM (exp)     participant receipt_id  \
# 0  SM02_pKa1            2.00           0.01  Bas Rustenburg      nb011
# 1  SM02_pKa1            1.77           0.01     Stefan Kast      z7fhp
# 2  SM02_pKa1             NaN           0.01       Qiao Zeng      wcvnu
# 3  SM02_pKa1            1.77           0.01     Stefan Kast      xnoe0
# 4  SM02_pKa1             NaN           0.01       Qiao Zeng      ko8yx
#
#   Exp. Microstate ID of A Exp. Microstate ID of HA  \
# 0           SM02_micro001            SM02_micro004
# 1           SM02_micro001            SM02_micro004
# 2           SM02_micro001            SM02_micro004
# 3           SM02_micro001            SM02_micro004
# 4           SM02_micro001            SM02_micro004
#
#           Microstate identification source  Microstate pair match
# 0  Estimated based on SM07 NMR measurement                      0
# 1  Estimated based on SM07 NMR measurement                      0
# 2  Estimated based on SM07 NMR measurement                      0
# 3  Estimated based on SM07 NMR measurement                      0
# 4  Estimated based on SM07 NMR measurement                      0

# %%
submission_IDs = list(set(df_col_ms["receipt_id"].values))
#submission_IDs = list(set(df_col_ms["receipt_id"].to_list()))

submission_IDs
# Out:
# ['eyetm',
#  'epvmk',
#  'y4wws',
#  '0xi4b',
#  'xnoe0',
#  'kxztt',
#  'v8qph',
#  'cm2yq',
#  'z3btx',
#  't8ewk',
#  '6tvf8',
#  '2umai',
#  'gdqeg',
#  'hdiyq',
#  '4o0ia',
#  'nb008',
#  'hgn83',
#  'ktpj5',
#  'ccpmw',
#  'wuuvc',
#  'nb011',
#  'nb016',
#  '758j8',
#  'z7fhp',
#  'arcko',
#  'ko8yx',
#  'ftc8w',
#  'wexjs',
#  '8toyp',
#  'cywyk',
#  'w4z0e',
#  'qsicn',
#  'nxaaw',
#  '0wfzo',
#  'wcvnu']

# %%
microstate_pair_relative_accuracy = []
number_of_known_microstate_pairs = 10

for submission_ID in submission_IDs:
    # Take subset of df_col_ms based on submission ID
    df_submission = df_col_ms[df_col_ms["receipt_id"] == submission_ID]
    # Count how many times "Microstate pair match" column has value 1
    pair_match = df_submission["Microstate pair match"].values
    relative_accuracy = (np.sum(pair_match)/number_of_known_microstate_pairs)*100
    print("Relative accuracy of {}:".format(submission_ID), relative_accuracy)
    microstate_pair_relative_accuracy.append(relative_accuracy)
   
microstate_pair_relative_accuracy
# Out:
# Relative accuracy of eyetm: 40.0
# Relative accuracy of epvmk: 20.0
# Relative accuracy of y4wws: 40.0
# Relative accuracy of 0xi4b: 60.0
# Relative accuracy of xnoe0: 30.0
# Relative accuracy of kxztt: 30.0
# Relative accuracy of v8qph: 60.0
# Relative accuracy of cm2yq: 20.0
# Relative accuracy of z3btx: 20.0
# Relative accuracy of t8ewk: 50.0
# Relative accuracy of 6tvf8: 40.0
# Relative accuracy of 2umai: 20.0
# Relative accuracy of gdqeg: 10.0
# Relative accuracy of hdiyq: 70.0
# Relative accuracy of 4o0ia: 10.0
# Relative accuracy of nb008: 10.0
# Relative accuracy of hgn83: 0.0
# Relative accuracy of ktpj5: 40.0
# Relative accuracy of ccpmw: 50.0
# Relative accuracy of wuuvc: 40.0
# Relative accuracy of nb011: 70.0
# Relative accuracy of nb016: 60.0
# Relative accuracy of 758j8: 0.0
# Relative accuracy of z7fhp: 30.0
# Relative accuracy of arcko: 40.0
# Relative accuracy of ko8yx: 40.0
# Relative accuracy of ftc8w: 50.0
# Relative accuracy of wexjs: 60.0
# Relative accuracy of 8toyp: 20.0
# Relative accuracy of cywyk: 50.0
# Relative accuracy of w4z0e: 30.0
# Relative accuracy of qsicn: 10.0
# Relative accuracy of nxaaw: 60.0
# Relative accuracy of 0wfzo: 20.0
# Relative accuracy of wcvnu: 50.0
# [40.0,
#  20.0,
#  40.0,
#  60.0,
#  30.0,
#  30.0,
#  60.0,
#  20.0,
#  20.0,
#  50.0,
#  40.0,
#  20.0,
#  10.0,
#  70.0,
#  10.0,
#  10.0,
#  0.0,
#  40.0,
#  50.0,
#  40.0,
#  70.0,
#  60.0,
#  0.0,
#  30.0,
#  40.0,
#  40.0,
#  50.0,
#  60.0,
#  20.0,
#  50.0,
#  30.0,
#  10.0,
#  60.0,
#  20.0,
#  50.0]

# %%
data = {'Submission ID': submission_IDs, 'Relative accuracy of microstate pairs(%)': microstate_pair_relative_accuracy}
df_rel_acc = pd.DataFrame.from_dict(data)

df_rel_acc = df_rel_acc.sort_values(by="Relative accuracy of microstate pairs(%)", ascending=False) #.reset_index(inplace=True)
df_rel_acc
# Out:
#    Submission ID  Relative accuracy of microstate pairs(%)
# 20         nb011                                      70.0
# 13         hdiyq                                      70.0
# 32         nxaaw                                      60.0
# 3          0xi4b                                      60.0
# 27         wexjs                                      60.0
# 6          v8qph                                      60.0
# 21         nb016                                      60.0
# 34         wcvnu                                      50.0
# 18         ccpmw                                      50.0
# 29         cywyk                                      50.0
# 26         ftc8w                                      50.0
# 9          t8ewk                                      50.0
# 25         ko8yx                                      40.0
# 24         arcko                                      40.0
# 19         wuuvc                                      40.0
# 0          eyetm                                      40.0
# 17         ktpj5                                      40.0
# 2          y4wws                                      40.0
# 10         6tvf8                                      40.0
# 30         w4z0e                                      30.0
# 4          xnoe0                                      30.0
# 23         z7fhp                                      30.0
# 5          kxztt                                      30.0
# 7          cm2yq                                      20.0
# 33         0wfzo                                      20.0
# 28         8toyp                                      20.0
# 8          z3btx                                      20.0
# 1          epvmk                                      20.0
# 11         2umai                                      20.0
# 12         gdqeg                                      10.0
# 31         qsicn                                      10.0
# 14         4o0ia                                      10.0
# 15         nb008                                      10.0
# 22         758j8                                       0.0
# 16         hgn83                                       0.0

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams["figure.figsize"] = [4,4]

# %%
def barplot(df, x_label, y_label, title):
    """Creates bar plot of a given dataframe.

    Args:
        df: Pandas Dataframe that should have columns with columnnames specified in other arguments.
        x_label: str, column name of x axis categories
        y_label: str, column name of y axis values
        title: str, the title of the plot

    """
    # Plot style
    plt.close()
    plt.style.use(["seaborn-talk", "seaborn-whitegrid"])
    plt.rcParams['axes.labelsize'] = 18
    plt.rcParams['xtick.labelsize'] = 14
    plt.rcParams['ytick.labelsize'] = 16
    plt.ylim(0,100)
    #plt.tight_layout()

    # Plot
    data = df
    x = range(len(data[y_label]))
    y = data[y_label]
    plt.bar(x, y)
    plt.xticks(x, data[x_label], rotation=90)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    if len(title) > 70:
        plt.title(title[:70]+"...")
    else:
        plt.title(title)
    plt.tight_layout()

# %%
barplot(df = df_rel_acc, 
        x_label = "Submission ID", 
        y_label = "Relative accuracy of microstate pairs(%)", 
        title = "Relative accuracy of microstate pairs in Type I submissions" )
plt.savefig("TypeI_microstate_pair_relative_accuracy.pdf")

# %% [markdown]
# ## Analyze relative microstate pair accuracy for each molecule

# %%
df_col_ms.head()
# Out:
#    Unnamed: 0  $\Delta$pKa error (calc - exp) Microstate ID of A  \
# 0           1                           -0.26      SM02_micro003
# 1          32                           -0.60      SM02_micro003
# 2          63                           -1.21      SM02_micro003
# 3          93                           -0.38      SM02_micro003
# 4         123                           -0.75      SM02_micro003
#
#   Microstate ID of HA Molecule ID  \
# 0       SM02_micro005        SM02
# 1       SM02_micro005        SM02
# 2       SM02_micro005        SM02
# 3       SM02_micro005        SM02
# 4       SM02_micro005        SM02
#
#                                                 name  pKa (calc)  pKa (exp)  \
# 0                                             Jaguar        4.77       5.03
# 1           EC-RISM/MP2/6-311+G(d,p)-P2-phi-all-1par        4.43       5.03
# 2             Adiabatic scheme for type I submission        3.82       5.03
# 3                EC-RISM/MP2/cc-pVTZ-P2-phi-all-2par        4.65       5.03
# 4  Adiabatic scheme with single point correction ...        4.28       5.03
#
#       pKa ID  pKa SEM (calc)  pKa SEM (exp)     participant receipt_id  \
# 0  SM02_pKa1            2.00           0.01  Bas Rustenburg      nb011
# 1  SM02_pKa1            1.77           0.01     Stefan Kast      z7fhp
# 2  SM02_pKa1             NaN           0.01       Qiao Zeng      wcvnu
# 3  SM02_pKa1            1.77           0.01     Stefan Kast      xnoe0
# 4  SM02_pKa1             NaN           0.01       Qiao Zeng      ko8yx
#
#   Exp. Microstate ID of A Exp. Microstate ID of HA  \
# 0           SM02_micro001            SM02_micro004
# 1           SM02_micro001            SM02_micro004
# 2           SM02_micro001            SM02_micro004
# 3           SM02_micro001            SM02_micro004
# 4           SM02_micro001            SM02_micro004
#
#           Microstate identification source  Microstate pair match
# 0  Estimated based on SM07 NMR measurement                      0
# 1  Estimated based on SM07 NMR measurement                      0
# 2  Estimated based on SM07 NMR measurement                      0
# 3  Estimated based on SM07 NMR measurement                      0
# 4  Estimated based on SM07 NMR measurement                      0

# %%
mol_IDs = list(set(df_col_ms["Molecule ID"].values))
mol_IDs
# Out:
# ['SM14', 'SM04', 'SM12', 'SM07', 'SM09', 'SM02', 'SM15', 'SM13']
